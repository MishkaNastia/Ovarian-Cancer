# %% [markdown]
# # Libraries

# %%
import pandas as pd
from cobra.io.json import load_json_model
import numpy as np
from cobra.flux_analysis import flux_variability_analysis
import math
from tqdm import tqdm

# %% [markdown]
# # Model

# %%
model = load_json_model('./data/Recon3D.json')
model.solver = 'gurobi' #you can use cplex or glpk as you whish, but gurobi and cplex are usually faster
model
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2731476
# Academic license - for non-commercial use only - expires 2026-11-01
# <Model Recon3D at 0x70e41c9c1ab0>

# %%
model.slim_optimize()
# Out:
# 755.003215550663

# %% [markdown]
# # Exofluxomics data

# %% [markdown]
# - We are using Exofluxomics of 7 ovarian cancer cell lines of NCI60 (https://dctd.cancer.gov/data-tools-biospecimens/data and https://www.revvity.com/ask/nci-60-cancer-cell-lines#kb-section-0).
#
# - The Exofluxomics analysis was published in: "Metabolite profiling identifies a key role for glycine in rapid cancer cell proliferation" -  Jain et. al 2012
#
# - NCI60 used the RPMI-1640 as growth medium
#
# - Your paper uses 5 ovarian cancer cell lines from CCLE that are different from the ones we're going to use to define the exofluxomics (NCI60 cells). We just need an approximation of the extracellular fluxes. Keep in mind that not all cells of your paper were growing into RPMI-1640 (It's okay for this project to not care about that).
#
# - Your paper uses HUMAN1 as GEM, while we are going to use RECON 3D for easier integration with Jain metabolites IDs

# %%
df_jain = pd.read_excel('./data/1218595databases1_corrected.xls', sheet_name='CORE data', index_col=1) #exoflux of NCI60
df_jain = df_jain[df_jain['Calibrated (e)']==1]
df_jain
# Out:
#                       Method (a)  Calibrated (e)  UACC-257  UACC-257.1  \
# Metabolite (b)
# 2-phosphoglycerate           IPR               1  0.010891    0.012313
# OH-phenylpyruvate            IPR               1  0.006489    0.006301
# aminoisobutyrate           HILIC               1 -0.000996   -0.001030
# 3-hydroxyanthranilate      HILIC               1  0.000004   -0.000009
# 3-phosphoglycerate           IPR               1  0.011295    0.009672
# ...                          ...             ...       ...         ...
# uridine                      IPR               1 -0.001730   -0.002408
# valine                     HILIC               1 -2.289535   -2.289212
# xanthine                     IPR               1  0.010001    0.007740
# XMP                          IPR               1  0.000982   -0.000302
# xanthosine                 HILIC               1 -0.000048    0.000297
#
#                         OVCAR-8  OVCAR-8.1   OVCAR-5  OVCAR-5.1     SF-295  \
# Metabolite (b)
# 2-phosphoglycerate     0.001671   0.002037  0.004495   0.003178   0.046393
# OH-phenylpyruvate      0.003754   0.004093  0.004945   0.002575   0.061102
# aminoisobutyrate      -0.000922  -0.003205 -0.009112  -0.003275  -0.007030
# 3-hydroxyanthranilate -0.000003  -0.000006 -0.000006  -0.000028   0.000012
# 3-phosphoglycerate     0.002216   0.001839  0.005351   0.004794   0.029259
# ...                         ...        ...       ...        ...        ...
# uridine               -0.004089  -0.004404 -0.006982  -0.006946   0.075043
# valine                -1.779011  -1.790573 -2.103658  -2.020315 -15.016188
# xanthine               0.007553   0.007257  0.048450   0.052410   0.156952
# XMP                   -0.000055  -0.000207  0.000268   0.000118   0.000766
# xanthosine            -0.001084  -0.001204 -0.000113   0.000681  -0.005822
#
#                         SF-295.1  ...     SN12C   SN12C.1  MDA-MB-231/ATCC  \
# Metabolite (b)                    ...
# 2-phosphoglycerate      0.041708  ...  0.000799  0.003414         0.003347
# OH-phenylpyruvate       0.071014  ...  0.004449  0.004086        -0.000016
# aminoisobutyrate       -0.006882  ...  0.000038 -0.002188        -0.001644
# 3-hydroxyanthranilate   0.000995  ...  0.000049  0.000049         0.000025
# 3-phosphoglycerate      0.027037  ...  0.003098  0.002399         0.003040
# ...                          ...  ...       ...       ...              ...
# uridine                 0.056388  ... -0.026612 -0.026042        -0.001166
# valine                -15.760112  ... -4.109991 -3.608674        -2.811156
# xanthine                0.117376  ...  0.052171  0.051318         0.019527
# XMP                     0.001146  ...  0.000395  0.000303        -0.000093
# xanthosine             -0.002704  ...  0.009422  0.006828         0.002594
#
#                        MDA-MB-231/ATCC.1  CCRF-CEM  CCRF-CEM.1  RPMI 8226  \
# Metabolite (b)
# 2-phosphoglycerate              0.004058  0.000048    0.000353   0.003970
# OH-phenylpyruvate               0.000997  0.000274   -0.000045   0.005093
# aminoisobutyrate               -0.001411 -0.004358   -0.004011  -0.000541
# 3-hydroxyanthranilate           0.000068  0.000083    0.000024   0.000104
# 3-phosphoglycerate              0.003676  0.001776   -0.000262   0.006900
# ...                                  ...       ...         ...        ...
# uridine                        -0.000968 -0.013973   -0.013942  -0.029317
# valine                         -3.146968 -3.286169   -3.439844  -9.662331
# xanthine                        0.018116  0.022432    0.023292   0.088359
# XMP                             0.000649  0.003888    0.003521   0.003966
# xanthosine                      0.001620  0.001371    0.001990   0.002848
#
#                        RPMI 8226.1        SR      SR.1
# Metabolite (b)
# 2-phosphoglycerate        0.004046  0.004946  0.006281
# OH-phenylpyruvate         0.002148  0.000366  0.000388
# aminoisobutyrate         -0.004851 -0.002008 -0.001844
# 3-hydroxyanthranilate     0.000138  0.000038 -0.000011
# 3-phosphoglycerate       -0.001072  0.000831  0.003157
# ...                            ...       ...       ...
# uridine                  -0.026703 -0.012063 -0.011686
# valine                   -8.993947 -3.089847 -3.137293
# xanthine                  0.086740  0.035188  0.039231
# XMP                       0.006606  0.001118  0.001443
# xanthosine                0.003604  0.003443  0.003289
#
# [115 rows x 122 columns]

# %%
df_jain.rename(columns={'IGROV1':'IGR-OV1', 'IGROV1.1':'IGR-OV1.1'}, inplace=True)

# %%
cell_ids = ['IGR-OV1','IGR-OV1.1', 'OVCAR-3', 'OVCAR-3.1', 'OVCAR-4',  'OVCAR-4.1', 
            'OVCAR-5','OVCAR-5.1', 'OVCAR-8', 'OVCAR-8.1', 'SK-OV-3', 'SK-OV-3.1', 'NCI/ADR-RES', 'NCI/ADR-RES.1'] #NCI60 ovarian cancer cell lines

# %%
cell_ids
# Out:
# ['IGR-OV1',
#  'IGR-OV1.1',
#  'OVCAR-3',
#  'OVCAR-3.1',
#  'OVCAR-4',
#  'OVCAR-4.1',
#  'OVCAR-5',
#  'OVCAR-5.1',
#  'OVCAR-8',
#  'OVCAR-8.1',
#  'SK-OV-3',
#  'SK-OV-3.1',
#  'NCI/ADR-RES',
#  'NCI/ADR-RES.1']

# %%
df_jain = df_jain[cell_ids]
df_jain
# Out:
#                         IGR-OV1  IGR-OV1.1   OVCAR-3  OVCAR-3.1   OVCAR-4  \
# Metabolite (b)
# 2-phosphoglycerate     0.004024   0.004238  0.003641   0.002481  0.008432
# OH-phenylpyruvate      0.011052   0.016182  0.006976   0.005363  0.010825
# aminoisobutyrate      -0.000353   0.001802  0.001429   0.000837  0.001697
# 3-hydroxyanthranilate -0.000048  -0.000027 -0.000020  -0.000023 -0.000015
# 3-phosphoglycerate    -0.000419   0.005083  0.000907  -0.000375  0.011112
# ...                         ...        ...       ...        ...       ...
# uridine                0.006014   0.010471 -0.002425  -0.000642  0.001338
# valine                -7.349679  -7.461049 -3.392893  -3.415313 -3.804516
# xanthine               0.161968   0.161236  0.037498   0.038947  0.024761
# XMP                    0.011492   0.013016  0.003105   0.001852  0.000055
# xanthosine             0.007490   0.007292 -0.000334  -0.000316  0.001777
#
#                        OVCAR-4.1   OVCAR-5  OVCAR-5.1   OVCAR-8  OVCAR-8.1  \
# Metabolite (b)
# 2-phosphoglycerate      0.012999  0.004495   0.003178  0.001671   0.002037
# OH-phenylpyruvate       0.007354  0.004945   0.002575  0.003754   0.004093
# aminoisobutyrate        0.001087 -0.009112  -0.003275 -0.000922  -0.003205
# 3-hydroxyanthranilate  -0.000028 -0.000006  -0.000028 -0.000003  -0.000006
# 3-phosphoglycerate      0.007249  0.005351   0.004794  0.002216   0.001839
# ...                          ...       ...        ...       ...        ...
# uridine                 0.001505 -0.006982  -0.006946 -0.004089  -0.004404
# valine                 -3.714310 -2.103658  -2.020315 -1.779011  -1.790573
# xanthine                0.024642  0.048450   0.052410  0.007553   0.007257
# XMP                     0.000199  0.000268   0.000118 -0.000055  -0.000207
# xanthosine              0.002120 -0.000113   0.000681 -0.001084  -0.001204
#
#                         SK-OV-3  SK-OV-3.1  NCI/ADR-RES  NCI/ADR-RES.1
# Metabolite (b)
# 2-phosphoglycerate    -0.000364   0.000310     0.000970       0.000666
# OH-phenylpyruvate      0.011270   0.007094     0.001803       0.004855
# aminoisobutyrate      -0.001814   0.001540    -0.001321      -0.003875
# 3-hydroxyanthranilate -0.000037   0.000169    -0.000008      -0.000007
# 3-phosphoglycerate     0.001217   0.000808     0.000989       0.003787
# ...                         ...        ...          ...            ...
# uridine                0.281732   0.296405    -0.015892      -0.016018
# valine                -3.698666  -3.069079    -2.852274      -2.792150
# xanthine               0.027664   0.030031     0.023520       0.024672
# XMP                   -0.000260  -0.001320    -0.001069      -0.000187
# xanthosine            -0.001479   0.001163    -0.001257      -0.001055
#
# [115 rows x 14 columns]

# %%
# CCLE https://sites.broadinstitute.org/ccle/ contains more than 1K human cancer cell lines with associated RNA-seq data
# Meeson et al. (your paper) used 5 of this cell lines for ovarian cancer clusterized in low and high grade based on literature)
CCLE_annotation = pd.read_csv('./data/Cell_lines_annotations_20181226.txt', index_col=0, sep='\t')
CCLE_annotation
# Out:
#                                             depMapID       Name   Pathology  \
# CCLE_ID
# DMS53_LUNG                                ACH-000698     DMS 53     primary
# SW1116_LARGE_INTESTINE                    ACH-000489     SW1116     primary
# NCIH1694_LUNG                             ACH-000431  NCI-H1694  metastasis
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000707     P3HR-1  metastasis
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000509     HuT 78     primary
# ...                                              ...        ...         ...
# GEO_LARGE_INTESTINE                       ACH-002394        NaN         NaN
# NCIH2330_LUNG                                    NaN        NaN         NaN
# LP6_SOFT_TISSUE                           ACH-001116        NaN         NaN
# HS578BST_BREAST                                  NaN        NaN         NaN
# LC1SQ_LUNG                                ACH-002156        NaN         NaN
#
#                                                                 Site_Primary  \
# CCLE_ID
# DMS53_LUNG                                                              lung
# SW1116_LARGE_INTESTINE                                       large_intestine
# NCIH1694_LUNG                                                           lung
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  haematopoietic_and_lymphoid_tissue
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  haematopoietic_and_lymphoid_tissue
# ...                                                                      ...
# GEO_LARGE_INTESTINE                                                      NaN
# NCIH2330_LUNG                                                            NaN
# LP6_SOFT_TISSUE                                                          NaN
# HS578BST_BREAST                                                          NaN
# LC1SQ_LUNG                                                               NaN
#
#                                          Site_Subtype1 Site_Subtype2  \
# CCLE_ID
# DMS53_LUNG                                          NS            NS
# SW1116_LARGE_INTESTINE                           colon            NS
# NCIH1694_LUNG                                       NS            NS
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS            NS
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE          skin            NS
# ...                                                ...           ...
# GEO_LARGE_INTESTINE                                NaN           NaN
# NCIH2330_LUNG                                      NaN           NaN
# LP6_SOFT_TISSUE                                    NaN           NaN
# HS578BST_BREAST                                    NaN           NaN
# LC1SQ_LUNG                                         NaN           NaN
#
#                                          Site_Subtype3          Histology  \
# CCLE_ID
# DMS53_LUNG                                          NS          carcinoma
# SW1116_LARGE_INTESTINE                              NS          carcinoma
# NCIH1694_LUNG                                       NS          carcinoma
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  lymphoid_neoplasm
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  lymphoid_neoplasm
# ...                                                ...                ...
# GEO_LARGE_INTESTINE                                NaN                NaN
# NCIH2330_LUNG                                      NaN                NaN
# LP6_SOFT_TISSUE                                    NaN                NaN
# HS578BST_BREAST                                    NaN                NaN
# LC1SQ_LUNG                                         NaN                NaN
#
#                                                               Hist_Subtype1  \
# CCLE_ID
# DMS53_LUNG                                             small_cell_carcinoma
# SW1116_LARGE_INTESTINE                                       adenocarcinoma
# NCIH1694_LUNG                                          small_cell_carcinoma
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                   Burkitt_lymphoma
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  mycosis_fungoides-Sezary_syndrome
# ...                                                                     ...
# GEO_LARGE_INTESTINE                                                     NaN
# NCIH2330_LUNG                                                           NaN
# LP6_SOFT_TISSUE                                                         NaN
# HS578BST_BREAST                                                         NaN
# LC1SQ_LUNG                                                              NaN
#
#                                          Hist_Subtype2  ...  \
# CCLE_ID                                                 ...
# DMS53_LUNG                                          NS  ...
# SW1116_LARGE_INTESTINE                              NS  ...
# NCIH1694_LUNG                                       NS  ...
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  ...
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  ...
# ...                                                ...  ...
# GEO_LARGE_INTESTINE                                NaN  ...
# NCIH2330_LUNG                                      NaN  ...
# LP6_SOFT_TISSUE                                    NaN  ...
# HS578BST_BREAST                                    NaN  ...
# LC1SQ_LUNG                                         NaN  ...
#
#                                               Growth.Medium  \
# CCLE_ID
# DMS53_LUNG                                Waymouth's+10%FBS
# SW1116_LARGE_INTESTINE                           L15+10%FBS
# NCIH1694_LUNG                                DMEM:F12+5%FBS
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                NaN
# ...                                                     ...
# GEO_LARGE_INTESTINE                                     NaN
# NCIH2330_LUNG                                           NaN
# LP6_SOFT_TISSUE                                         NaN
# HS578BST_BREAST                                         NaN
# LC1SQ_LUNG                                              NaN
#
#                                                                                 Supplements  \
# CCLE_ID
# DMS53_LUNG                                                                              NaN
# SW1116_LARGE_INTESTINE                                                                  NaN
# NCIH1694_LUNG                             005 mg/ml insulin, 01 mg/ml transferrin, 30nM ...
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                                                NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                                                NaN
# ...                                                                                     ...
# GEO_LARGE_INTESTINE                                                                     NaN
# NCIH2330_LUNG                                                                           NaN
# LP6_SOFT_TISSUE                                                                         NaN
# HS578BST_BREAST                                                                         NaN
# LC1SQ_LUNG                                                                              NaN
#
#                                          FreezingMedium  \
# CCLE_ID
# DMS53_LUNG                                       5%DMSO
# SW1116_LARGE_INTESTINE                           5%DMSO
# NCIH1694_LUNG                                   5% DMSO
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NaN
# ...                                                 ...
# GEO_LARGE_INTESTINE                                 NaN
# NCIH2330_LUNG                                       NaN
# LP6_SOFT_TISSUE                                     NaN
# HS578BST_BREAST                                     NaN
# LC1SQ_LUNG                                          NaN
#
#                                           DoublingTimefromVendor  \
# CCLE_ID
# DMS53_LUNG                                                   NaN
# SW1116_LARGE_INTESTINE                                       NaN
# NCIH1694_LUNG                                                NaN
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                     NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                     NaN
# ...                                                          ...
# GEO_LARGE_INTESTINE                                          NaN
# NCIH2330_LUNG                                                NaN
# LP6_SOFT_TISSUE                                              NaN
# HS578BST_BREAST                                              NaN
# LC1SQ_LUNG                                                   NaN
#
#                                          DoublingTimeCalculatedhrs  \
# CCLE_ID
# DMS53_LUNG                                                   450.0
# SW1116_LARGE_INTESTINE                                      1232.0
# NCIH1694_LUNG                                                812.0
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                       NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                       NaN
# ...                                                            ...
# GEO_LARGE_INTESTINE                                            NaN
# NCIH2330_LUNG                                                  NaN
# LP6_SOFT_TISSUE                                                NaN
# HS578BST_BREAST                                                NaN
# LC1SQ_LUNG                                                     NaN
#
#                                                       type  \
# CCLE_ID
# DMS53_LUNG                                 lung_small_cell
# SW1116_LARGE_INTESTINE                          colorectal
# NCIH1694_LUNG                              lung_small_cell
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  lymphoma_Burkitt
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    lymphoma_other
# ...                                                    ...
# GEO_LARGE_INTESTINE                                    NaN
# NCIH2330_LUNG                                          NaN
# LP6_SOFT_TISSUE                                        NaN
# HS578BST_BREAST                                        NaN
# LC1SQ_LUNG                                             NaN
#
#                                                    type_refined  \
# CCLE_ID
# DMS53_LUNG                                      lung_small_cell
# SW1116_LARGE_INTESTINE                               colorectal
# NCIH1694_LUNG                                   lung_small_cell
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       lymphoma_Burkitt
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  T-cell_lymphoma_other
# ...                                                         ...
# GEO_LARGE_INTESTINE                                  colorectal
# NCIH2330_LUNG                                               NaN
# LP6_SOFT_TISSUE                                             NaN
# HS578BST_BREAST                                             NaN
# LC1SQ_LUNG                                             lung_NSC
#
#                                          PATHOLOGIST_ANNOTATION       mutRate  \
# CCLE_ID
# DMS53_LUNG                                            Lung:SCLC  1.572416e+09
# SW1116_LARGE_INTESTINE                     Colorectal:Carcinoma  9.437319e+09
# NCIH1694_LUNG                                         Lung:SCLC  1.095350e+08
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Lymphoma:NH_B_cell  1.664564e+09
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Lymphoma:NH_T_cell  1.182176e+09
# ...                                                         ...           ...
# GEO_LARGE_INTESTINE                                         NaN           NaN
# NCIH2330_LUNG                                               NaN           NaN
# LP6_SOFT_TISSUE                                             NaN           NaN
# HS578BST_BREAST                                             NaN           NaN
# LC1SQ_LUNG                                                  NaN           NaN
#
#                                           tcga_code
# CCLE_ID
# DMS53_LUNG                                     SCLC
# SW1116_LARGE_INTESTINE                    COAD/READ
# NCIH1694_LUNG                                  SCLC
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       DLBC
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        NaN
# ...                                             ...
# GEO_LARGE_INTESTINE                       COAD/READ
# NCIH2330_LUNG                                   NaN
# LP6_SOFT_TISSUE                                 NaN
# HS578BST_BREAST                                 NaN
# LC1SQ_LUNG                                     LUSC
#
# [1461 rows x 32 columns]

# %%
dict_meeson={
    'COV318':'high_grade',
    'CAOV3':'high_grade',
    'OAW28':'high_grade',
    '59M':'low_grade',
    'HEYA8':'low_grade',
}
for cell_id, type in dict_meeson.items():
    print(CCLE_annotation.loc[f'{cell_id}_OVARY'].Name)
    
# all cell lines of your paper are found in this CCLE annotation dataset as 'name+_OVARY'
# Out:
# COV318
# Caov-3
# OAW28
# 59M
# Hey-A8

# %%
df_jain
# Out:
#                         IGR-OV1  IGR-OV1.1   OVCAR-3  OVCAR-3.1   OVCAR-4  \
# Metabolite (b)
# 2-phosphoglycerate     0.004024   0.004238  0.003641   0.002481  0.008432
# OH-phenylpyruvate      0.011052   0.016182  0.006976   0.005363  0.010825
# aminoisobutyrate      -0.000353   0.001802  0.001429   0.000837  0.001697
# 3-hydroxyanthranilate -0.000048  -0.000027 -0.000020  -0.000023 -0.000015
# 3-phosphoglycerate    -0.000419   0.005083  0.000907  -0.000375  0.011112
# ...                         ...        ...       ...        ...       ...
# uridine                0.006014   0.010471 -0.002425  -0.000642  0.001338
# valine                -7.349679  -7.461049 -3.392893  -3.415313 -3.804516
# xanthine               0.161968   0.161236  0.037498   0.038947  0.024761
# XMP                    0.011492   0.013016  0.003105   0.001852  0.000055
# xanthosine             0.007490   0.007292 -0.000334  -0.000316  0.001777
#
#                        OVCAR-4.1   OVCAR-5  OVCAR-5.1   OVCAR-8  OVCAR-8.1  \
# Metabolite (b)
# 2-phosphoglycerate      0.012999  0.004495   0.003178  0.001671   0.002037
# OH-phenylpyruvate       0.007354  0.004945   0.002575  0.003754   0.004093
# aminoisobutyrate        0.001087 -0.009112  -0.003275 -0.000922  -0.003205
# 3-hydroxyanthranilate  -0.000028 -0.000006  -0.000028 -0.000003  -0.000006
# 3-phosphoglycerate      0.007249  0.005351   0.004794  0.002216   0.001839
# ...                          ...       ...        ...       ...        ...
# uridine                 0.001505 -0.006982  -0.006946 -0.004089  -0.004404
# valine                 -3.714310 -2.103658  -2.020315 -1.779011  -1.790573
# xanthine                0.024642  0.048450   0.052410  0.007553   0.007257
# XMP                     0.000199  0.000268   0.000118 -0.000055  -0.000207
# xanthosine              0.002120 -0.000113   0.000681 -0.001084  -0.001204
#
#                         SK-OV-3  SK-OV-3.1  NCI/ADR-RES  NCI/ADR-RES.1
# Metabolite (b)
# 2-phosphoglycerate    -0.000364   0.000310     0.000970       0.000666
# OH-phenylpyruvate      0.011270   0.007094     0.001803       0.004855
# aminoisobutyrate      -0.001814   0.001540    -0.001321      -0.003875
# 3-hydroxyanthranilate -0.000037   0.000169    -0.000008      -0.000007
# 3-phosphoglycerate     0.001217   0.000808     0.000989       0.003787
# ...                         ...        ...          ...            ...
# uridine                0.281732   0.296405    -0.015892      -0.016018
# valine                -3.698666  -3.069079    -2.852274      -2.792150
# xanthine               0.027664   0.030031     0.023520       0.024672
# XMP                   -0.000260  -0.001320    -0.001069      -0.000187
# xanthosine            -0.001479   0.001163    -0.001257      -0.001055
#
# [115 rows x 14 columns]

# %%
# we now look at the fluxes from Jain and take, for each metabolite, the min and max fluxes across the ovarian cancer cell lines only
# in this way we have a unique profile for ovarian cancer extracellualr fluxes
# We expect the cells to differentiate once we integrate RNA-seq data

# Relaxation 0.5 and 1.5

df_jain = df_jain * 5e-3 # convert fmol/cell*h to mmol/gdw*h (flux) assuming cell_volume = 2e-10
df_exo_flux = pd.DataFrame(columns=['Min', 'Max', 'relaxed_Min', 'relaxed_Max'], index=df_jain.index)
for met_name_jain, row in df_jain.iterrows():
    min_ = row.min()
    max_ = row.max()
    df_exo_flux.at[met_name_jain, 'Min'] = min_
    df_exo_flux.at[met_name_jain, 'Max'] = max_
    if (min_ < 0 and max_ > 0):
        df_exo_flux.at[met_name_jain, 'relaxed_Min'] = min_ * 1.5
        df_exo_flux.at[met_name_jain, 'relaxed_Max'] = max_ * 1.5
    elif(min_ < 0 and max_ < 0):
        df_exo_flux.at[met_name_jain, 'relaxed_Min'] = min_ * 1.5
        df_exo_flux.at[met_name_jain, 'relaxed_Max'] = max_ * 0.5
    else:
        df_exo_flux.at[met_name_jain, 'relaxed_Min'] = min_ * 0.5
        df_exo_flux.at[met_name_jain, 'relaxed_Max'] = max_ * 1.5
df_exo_flux
# Out:
#                             Min       Max relaxed_Min relaxed_Max
# Metabolite (b)
# 2-phosphoglycerate    -0.000002  0.000065   -0.000003    0.000097
# OH-phenylpyruvate      0.000009  0.000081    0.000005    0.000121
# aminoisobutyrate      -0.000046  0.000009   -0.000068    0.000014
# 3-hydroxyanthranilate      -0.0  0.000001        -0.0    0.000001
# 3-phosphoglycerate    -0.000002  0.000056   -0.000003    0.000083
# ...                         ...       ...         ...         ...
# uridine                -0.00008  0.001482    -0.00012    0.002223
# valine                -0.037305 -0.008895   -0.055958   -0.004448
# xanthine               0.000036   0.00081    0.000018    0.001215
# XMP                   -0.000007  0.000065    -0.00001    0.000098
# xanthosine            -0.000007  0.000037   -0.000011    0.000056
#
# [115 rows x 4 columns]

# %%
df_dict_met_rxn = pd.read_excel('./data/Liaskos_et_al.xlsx', sheet_name='Mapping_mets_IDs', index_col=0)
df_dict_met_rxn
# Out:
#                        Metabolite ID Recon3D
# Metabolite Jain et al.
# 2-phosphoglycerate                     2pg_e
# OH-phenylpyruvate                    34hpp_e
# aminoisobutyrate                      3aib_e
# 3-hydroxyanthranilate             3hanthrn_e
# 3-phosphoglycerate                     3pg_e
# ...                                      ...
# uridine                                uri_e
# valine                               val_L_e
# xanthine                               xan_e
# XMP                                    xmp_e
# xanthosine                            xtsn_e
#
# [115 rows x 1 columns]

# %%
df_exo_flux = df_exo_flux.join(df_dict_met_rxn, how='left')
df_exo_flux
# Out:
#                             Min       Max relaxed_Min relaxed_Max  \
# Metabolite (b)
# 2-phosphoglycerate    -0.000002  0.000065   -0.000003    0.000097
# OH-phenylpyruvate      0.000009  0.000081    0.000005    0.000121
# aminoisobutyrate      -0.000046  0.000009   -0.000068    0.000014
# 3-hydroxyanthranilate      -0.0  0.000001        -0.0    0.000001
# 3-phosphoglycerate    -0.000002  0.000056   -0.000003    0.000083
# ...                         ...       ...         ...         ...
# uridine                -0.00008  0.001482    -0.00012    0.002223
# valine                -0.037305 -0.008895   -0.055958   -0.004448
# xanthine               0.000036   0.00081    0.000018    0.001215
# XMP                   -0.000007  0.000065    -0.00001    0.000098
# xanthosine            -0.000007  0.000037   -0.000011    0.000056
#
#                       Metabolite ID Recon3D
# Metabolite (b)
# 2-phosphoglycerate                    2pg_e
# OH-phenylpyruvate                   34hpp_e
# aminoisobutyrate                     3aib_e
# 3-hydroxyanthranilate            3hanthrn_e
# 3-phosphoglycerate                    3pg_e
# ...                                     ...
# uridine                               uri_e
# valine                              val_L_e
# xanthine                              xan_e
# XMP                                   xmp_e
# xanthosine                           xtsn_e
#
# [115 rows x 5 columns]

# %%
df_exo_flux.loc[df_exo_flux['Metabolite ID Recon3D']=='tdechola_e/tdchola_e']
df_exo_flux.at['glycodeoxycholate/glycochenodeoxycholate', 'Metabolite ID Recon3D'] = 'dgchol_e'
df_exo_flux.at['taurodeoxycholate/taurochenodeoxycholate', 'Metabolite ID Recon3D'] = 'tdchola_e'

# %%
def double_nth_underscore(text, n=2):
    underscores = 0
    result = []
    for char in text:
        if char == '_':
            underscores += 1
            if underscores == n:
                result.append('__')
            else:
                result.append('_')
        else:
            result.append(char)
    return ''.join(result)

model_met_ids = [met.id for met in model.metabolites]
for index, row in df_exo_flux.iterrows():
    if(row['Metabolite ID Recon3D'] in model_met_ids):
        continue
    else:
        print(row['Metabolite ID Recon3D'])
        df_exo_flux.at[index, 'Metabolite ID Recon3D'] = double_nth_underscore(row['Metabolite ID Recon3D'], n=1)

print("##################################################")

model_met_ids = [met.id for met in model.metabolites]
for index, row in df_exo_flux.iterrows():
    if(row['Metabolite ID Recon3D'] in model_met_ids):
        continue
    else:
        print(row['Metabolite ID Recon3D'])
# Out:
# ala_L_e
# arg_L_e
# asn_L_e
# asp_L_e
# citr_L_e
# cyst_L_e
# glc_D_e
# gln_L_e
# glu_L_e
# hcys_L_e
# hom_L_e
# ile_L_e
# lac_L_e
# leu_L_e
# lys_L_e
# mal_L_e
# met_L_e
# phe_L_e
# pnto_R_e
# pro_L_e
# sbt_D_e
# ser_L_e
# thr_L_e
# thyox_L_e
# trp_L_e
# tyr_L_e
# val_L_e
# ##################################################

# %%
def double_nth_underscore(text, n=2):
    underscores = 0
    result = []
    for char in text:
        if char == '_':
            underscores += 1
            if underscores == n:
                result.append('__')
            else:
                result.append('_')
        else:
            result.append(char)
    return ''.join(result)

for index, row in df_exo_flux.iterrows():
    found_id = None
    for rxn in model.reactions:
        if(rxn.id.startswith('EX_') and len(rxn.metabolites) == 1):
            for met in rxn.metabolites:
                if(met.id == row['Metabolite ID Recon3D']):
                    found_id = rxn.id
    df_exo_flux.at[index, 'Reaction'] = found_id
df_exo_flux.loc[df_exo_flux['Reaction'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Min, Max, relaxed_Min, relaxed_Max, Metabolite ID Recon3D, Reaction]
# Index: []

# %%
df_exo_flux
# Out:
#                             Min       Max relaxed_Min relaxed_Max  \
# Metabolite (b)
# 2-phosphoglycerate    -0.000002  0.000065   -0.000003    0.000097
# OH-phenylpyruvate      0.000009  0.000081    0.000005    0.000121
# aminoisobutyrate      -0.000046  0.000009   -0.000068    0.000014
# 3-hydroxyanthranilate      -0.0  0.000001        -0.0    0.000001
# 3-phosphoglycerate    -0.000002  0.000056   -0.000003    0.000083
# ...                         ...       ...         ...         ...
# uridine                -0.00008  0.001482    -0.00012    0.002223
# valine                -0.037305 -0.008895   -0.055958   -0.004448
# xanthine               0.000036   0.00081    0.000018    0.001215
# XMP                   -0.000007  0.000065    -0.00001    0.000098
# xanthosine            -0.000007  0.000037   -0.000011    0.000056
#
#                       Metabolite ID Recon3D       Reaction
# Metabolite (b)
# 2-phosphoglycerate                    2pg_e       EX_2pg_e
# OH-phenylpyruvate                   34hpp_e     EX_34hpp_e
# aminoisobutyrate                     3aib_e      EX_3aib_e
# 3-hydroxyanthranilate            3hanthrn_e  EX_3hanthrn_e
# 3-phosphoglycerate                    3pg_e       EX_3pg_e
# ...                                     ...            ...
# uridine                               uri_e       EX_uri_e
# valine                             val__L_e    EX_val__L_e
# xanthine                              xan_e       EX_xan_e
# XMP                                   xmp_e       EX_xmp_e
# xanthosine                           xtsn_e      EX_xtsn_e
#
# [115 rows x 6 columns]

# %%
medium_df = pd.read_excel('./data/Liaskos_et_al.xlsx', sheet_name='RPMI1640_medium_EX_rxns', index_col=0)
medium_df.loc['L-Hydroxyproline'] = ['EX_4hpro_LT_e'] 
#drop row Chloride
medium_df = medium_df.drop('Chloride', axis=0)
medium_df
# Out:
#                              Reaction
# RPMI 1640 medium NCI60
# Glycine                      EX_gly_e
# L-Arginine                 EX_arg_L_e
# L-Asparagine               EX_asn_L_e
# L-Aspartic acid            EX_asp_L_e
# L-Cystine                  EX_cys_L_e
# L-Glutamic Acid            EX_glu_L_e
# L-Glutamine                EX_gln_L_e
# L-Histidine                EX_his_L_e
# L-Hydroxyproline        EX_4hpro_LT_e
# L-Isoleucine               EX_ile_L_e
# L-Leucine                  EX_leu_L_e
# L-Lysine                   EX_lys_L_e
# L-Methionine               EX_met_L_e
# L-Phenylalanine            EX_phe_L_e
# L-Proline                  EX_pro_L_e
# L-Serine                   EX_ser_L_e
# L-Threonine                EX_thr_L_e
# L-Tryptophan               EX_trp_L_e
# L-Tyrosine                 EX_tyr_L_e
# L-Valine                   EX_val_L_e
# Biotin                       EX_btn_e
# Choline                     EX_chol_e
# Pantothenate              EX_pnto_R_e
# Folic Acid                   EX_fol_e
# Niacinamide                 EX_ncam_e
# Pyridoxine                 EX_pydxn_e
# Riboflavin                EX_ribflv_e
# Thiamine                     EX_thm_e
# i-Inositol                 EX_inost_e
# D-Glucose                  EX_glc_D_e
# Glutathione reduced        EX_gthrd_e
# H+                             EX_h_e
# Sodium                       EX_na1_e
# H2O                          EX_h2o_e
# Sulfate                      EX_so4_e
# Potassium                      EX_k_e
# Bicarbonate                 EX_hco3_e
# Phosphate                     EX_pi_e
# CO2                          EX_co2_e
# O2                            EX_o2_e

# %%
def double_nth_underscore(text, n=2):
    underscores = 0
    result = []
    for char in text:
        if char == '_':
            underscores += 1
            if underscores == n:
                result.append('__')
            else:
                result.append('_')
        else:
            result.append(char)
    return ''.join(result)

for index, row in medium_df.iterrows():
    rxn_id = row['Reaction']
    if rxn_id in model.reactions:
        continue
    else:
        medium_df.at[index, 'Reaction'] = double_nth_underscore(medium_df.at[index, 'Reaction'], 2)

# %%
medium_df
# Out:
#                              Reaction
# RPMI 1640 medium NCI60
# Glycine                      EX_gly_e
# L-Arginine                EX_arg__L_e
# L-Asparagine              EX_asn__L_e
# L-Aspartic acid           EX_asp__L_e
# L-Cystine                 EX_cys__L_e
# L-Glutamic Acid           EX_glu__L_e
# L-Glutamine               EX_gln__L_e
# L-Histidine               EX_his__L_e
# L-Hydroxyproline        EX_4hpro_LT_e
# L-Isoleucine              EX_ile__L_e
# L-Leucine                 EX_leu__L_e
# L-Lysine                  EX_lys__L_e
# L-Methionine              EX_met__L_e
# L-Phenylalanine           EX_phe__L_e
# L-Proline                 EX_pro__L_e
# L-Serine                  EX_ser__L_e
# L-Threonine               EX_thr__L_e
# L-Tryptophan              EX_trp__L_e
# L-Tyrosine                EX_tyr__L_e
# L-Valine                  EX_val__L_e
# Biotin                       EX_btn_e
# Choline                     EX_chol_e
# Pantothenate             EX_pnto__R_e
# Folic Acid                   EX_fol_e
# Niacinamide                 EX_ncam_e
# Pyridoxine                 EX_pydxn_e
# Riboflavin                EX_ribflv_e
# Thiamine                     EX_thm_e
# i-Inositol                 EX_inost_e
# D-Glucose                 EX_glc__D_e
# Glutathione reduced        EX_gthrd_e
# H+                             EX_h_e
# Sodium                       EX_na1_e
# H2O                          EX_h2o_e
# Sulfate                      EX_so4_e
# Potassium                      EX_k_e
# Bicarbonate                 EX_hco3_e
# Phosphate                     EX_pi_e
# CO2                          EX_co2_e
# O2                            EX_o2_e

# %%
for index, row in medium_df.iterrows():
    rxn_id = row['Reaction']
    if rxn_id in model.reactions:
        continue
    else:
        print(rxn_id)

# %%
# find all exhcngae reactions in the model
ex_rxns = []
for rxn in model.reactions:
    if rxn.id.startswith('EX_'):
        ex_rxns.append(rxn.id)
print(len(ex_rxns))
# Out:
# 1560

# %%
is_medium = []
for ex in ex_rxns:
    if ex in medium_df['Reaction'].values:
        is_medium.append(1)
    else:
        is_medium.append(0)
sum(is_medium)
# Out:
# 40

# %%
is_jain = []
for ex in ex_rxns:
    if ex in df_exo_flux['Reaction'].values:
        is_jain.append(1)
    else:
        is_jain.append(0)
sum(is_jain)
# Out:
# 115

# %%
df_exoflux = pd.DataFrame(index=ex_rxns, columns=['in_medium', 'in_jain'])
df_exoflux['in_medium'] = is_medium
df_exoflux['in_jain'] = is_jain
df_exoflux
# Out:
#                      in_medium  in_jain
# EX_5adtststerone_e           0        0
# EX_5adtststerones_e          0        0
# EX_5fthf_e                   0        0
# EX_5htrp_e                   0        0
# EX_5mthf_e                   0        0
# ...                        ...      ...
# EX_3h3mglt_e                 0        0
# EX_ppiogly_e                 0        0
# EX_sbt__D_e                  0        1
# EX_lvstacid_e                0        0
# EX_ptvstm13_e                0        0
#
# [1560 rows x 2 columns]

# %%
df_exo_flux
# Out:
#                             Min       Max relaxed_Min relaxed_Max  \
# Metabolite (b)
# 2-phosphoglycerate    -0.000002  0.000065   -0.000003    0.000097
# OH-phenylpyruvate      0.000009  0.000081    0.000005    0.000121
# aminoisobutyrate      -0.000046  0.000009   -0.000068    0.000014
# 3-hydroxyanthranilate      -0.0  0.000001        -0.0    0.000001
# 3-phosphoglycerate    -0.000002  0.000056   -0.000003    0.000083
# ...                         ...       ...         ...         ...
# uridine                -0.00008  0.001482    -0.00012    0.002223
# valine                -0.037305 -0.008895   -0.055958   -0.004448
# xanthine               0.000036   0.00081    0.000018    0.001215
# XMP                   -0.000007  0.000065    -0.00001    0.000098
# xanthosine            -0.000007  0.000037   -0.000011    0.000056
#
#                       Metabolite ID Recon3D       Reaction
# Metabolite (b)
# 2-phosphoglycerate                    2pg_e       EX_2pg_e
# OH-phenylpyruvate                   34hpp_e     EX_34hpp_e
# aminoisobutyrate                     3aib_e      EX_3aib_e
# 3-hydroxyanthranilate            3hanthrn_e  EX_3hanthrn_e
# 3-phosphoglycerate                    3pg_e       EX_3pg_e
# ...                                     ...            ...
# uridine                               uri_e       EX_uri_e
# valine                             val__L_e    EX_val__L_e
# xanthine                              xan_e       EX_xan_e
# XMP                                   xmp_e       EX_xmp_e
# xanthosine                           xtsn_e      EX_xtsn_e
#
# [115 rows x 6 columns]

# %%
col_met_ids = []
for index, row in df_exoflux.iterrows():
    rxn = model.reactions.get_by_id(index)
    for met in rxn.metabolites:
        col_met_ids.append(met.id)
df_exoflux['Metabolite ID Recon3D'] = col_met_ids
df_exoflux
# Out:
#                      in_medium  in_jain Metabolite ID Recon3D
# EX_5adtststerone_e           0        0       5adtststerone_e
# EX_5adtststerones_e          0        0      5adtststerones_e
# EX_5fthf_e                   0        0               5fthf_e
# EX_5htrp_e                   0        0               5htrp_e
# EX_5mthf_e                   0        0               5mthf_e
# ...                        ...      ...                   ...
# EX_3h3mglt_e                 0        0             3h3mglt_e
# EX_ppiogly_e                 0        0             ppiogly_e
# EX_sbt__D_e                  0        1              sbt__D_e
# EX_lvstacid_e                0        0            lvstacid_e
# EX_ptvstm13_e                0        0            ptvstm13_e
#
# [1560 rows x 3 columns]

# %%
row['in_jain']==1 & row['in_medium']==0
# Out:
# True

# %%
LB = []
UB = []
is_set_list = []
for index, row in df_exoflux.iterrows():
    if(row['in_jain']==1 and row['in_medium']==1):
        LB.append(df_exo_flux.loc[df_exo_flux['Reaction']==index, 'relaxed_Min'].values[0])
        UB.append(df_exo_flux.loc[df_exo_flux['Reaction']==index, 'relaxed_Max'].values[0])
        is_set = 1
    elif(row['in_jain']==1 and row['in_medium']==0):
        jain_LB = df_exo_flux.loc[df_exo_flux['Reaction']==index, 'relaxed_Min'].values[0]
        jain_UB = df_exo_flux.loc[df_exo_flux['Reaction']==index, 'relaxed_Max'].values[0]
        if(jain_LB<0 and jain_UB>0):
            LB.append(1e-7)
            UB.append(jain_UB)
        elif(jain_LB <0 and jain_UB<0):
            LB.append(-1e-7)
            UB.append(100)
        else:
            LB.append(jain_LB)
            UB.append(jain_UB)
        is_set = 1
    else:
        is_set = 0
        LB.append(-100)
        UB.append(+100)
    is_set_list.append(is_set)
df_exoflux['LB'] = LB
df_exoflux['UB'] = UB
df_exoflux['is_set'] = is_set_list
df_exoflux
# Out:
#                      in_medium  in_jain Metabolite ID Recon3D          LB  \
# EX_5adtststerone_e           0        0       5adtststerone_e -100.000000
# EX_5adtststerones_e          0        0      5adtststerones_e -100.000000
# EX_5fthf_e                   0        0               5fthf_e -100.000000
# EX_5htrp_e                   0        0               5htrp_e -100.000000
# EX_5mthf_e                   0        0               5mthf_e -100.000000
# ...                        ...      ...                   ...         ...
# EX_3h3mglt_e                 0        0             3h3mglt_e -100.000000
# EX_ppiogly_e                 0        0             ppiogly_e -100.000000
# EX_sbt__D_e                  0        1              sbt__D_e    0.000046
# EX_lvstacid_e                0        0            lvstacid_e -100.000000
# EX_ptvstm13_e                0        0            ptvstm13_e -100.000000
#
#                              UB  is_set
# EX_5adtststerone_e   100.000000       0
# EX_5adtststerones_e  100.000000       0
# EX_5fthf_e           100.000000       0
# EX_5htrp_e           100.000000       0
# EX_5mthf_e           100.000000       0
# ...                         ...     ...
# EX_3h3mglt_e         100.000000       0
# EX_ppiogly_e         100.000000       0
# EX_sbt__D_e            0.000514       1
# EX_lvstacid_e        100.000000       0
# EX_ptvstm13_e        100.000000       0
#
# [1560 rows x 6 columns]

# %%
df_exoflux.to_csv('./data/exoflux_bounds.csv')

# %%
#fix oxygen uptake based on literature LB = -2, UB = 0
#fix ATPM flux based on literature LB 2.576 UB 3.864
model.reactions.get_by_id('EX_o2_e').bounds = (-2, 0)
model.reactions.get_by_id('ATPM').bounds = (2.576, 3.864)

# %%
for index, row in tqdm(df_exoflux.iterrows(), total=df_exoflux.shape[0]):
    original_bounds = model.reactions.get_by_id(index).bounds
    model.reactions.get_by_id(index).bounds = (row['LB'], row['UB'])
    if math.isnan(model.slim_optimize()):
        print(f'Infeasible reaction: {index} with bounds {row["LB"]}, {row["UB"]}')
        model.reactions.get_by_id(index).bounds = original_bounds
# Out:
#  79%|███████▉  | 1232/1560 [00:08<00:05, 57.24it/s]
# Infeasible reaction: EX_sucr_e with bounds 1.9942750059574653e-06, 2.22776617839489e-05
#  99%|█████████▉| 1551/1560 [00:12<00:00, 72.79it/s]
# Infeasible reaction: EX_sbt__D_e with bounds 4.58713531797975e-05, 0.000513652932905718
# 100%|██████████| 1560/1560 [00:13<00:00, 114.52it/s]

# %% [markdown]
# All bounds were integrated correctly without need for MILP

# %%
model.objective = 'BIOMASS_reaction'

# %%
model.slim_optimize()
# Out:
# 313.26041897197297

# %% [markdown]
# Now we run FVA to get the feasible ranges for all reactions

# %%
df_fva = flux_variability_analysis(model, fraction_of_optimum=0.0, processes=20)
df_fva
# Out:
#                      minimum  maximum
# 24_25DHVITD3tm           0.0    100.0
# 25HVITD3t                0.0    100.0
# COAtl                    0.0   1000.0
# EX_5adtststerone_e    -100.0    100.0
# EX_5adtststerones_e   -100.0    100.0
# ...                      ...      ...
# ACMPGLUTTRsc             0.0    100.0
# FVSCOAhc                 0.0    100.0
# MDZGLChr                 0.0    100.0
# TMACMPhr                 0.0    100.0
# CYSACMPitr               0.0    100.0
#
# [10600 rows x 2 columns]

# %%
df_fva.to_csv('./data/fva_exoflux.csv')

# %%
df_fva = pd.read_csv('./data/fva_exoflux.csv', index_col=0)

# %%
#inject bounds into the model
for index, row in df_fva.iterrows():
    model.reactions.get_by_id(index).bounds = (row['minimum'], row['maximum'])

# %%
#check feasibility again
print(model.slim_optimize())
# Out:
# 313.26041896890126

# %% [markdown]
# # Low and high grade models

# %% [markdown]
# We have 7 cells belonging to 2 families: Low and High grade cancer.
#
# We are going to work in parallel for the two families.
#
# For each family, we select its cell lines and doubling times reported by your paper. We select the lowest and highest doubling time across all cell lines of this family. These are going to be the LB and UB for the biomass reaction associated to the generic model of family x. We also need to trasnform doubling time to  mmol/gdw*h.
#
# flux_biomass = ln(2)/DT

# %%
df_cells = pd.DataFrame(columns = ['ID', 'Type', 'Doubling time'])
df_cells.loc[0] = ['COV318', 'high_grade', 50]
df_cells.loc[1] = ['CAOV3', 'high_grade', 63.95]
df_cells.loc[2] = ['OAW28', 'high_grade', 37]
df_cells.loc[3] = ['59M', 'low_grade', 48]
df_cells.loc[4] = ['HEYA8', 'low_grade', 16]
df_cells
# Out:
#        ID        Type  Doubling time
# 0  COV318  high_grade          50.00
# 1   CAOV3  high_grade          63.95
# 2   OAW28  high_grade          37.00
# 3     59M   low_grade          48.00
# 4   HEYA8   low_grade          16.00

# %%
#high grade min = 37.0 max = 63.95
#low grade min = 16 max = 48
#we relax by a +-20%
LB_biomass_HG = (np.log(2)/63.95) *0.8
UB_biomass_HG = (np.log(2)/37.0)*1.2

LB_biomass_LG = (np.log(2)/48)*0.8
UB_biomass_LG = (np.log(2)/16)*1.2

print(LB_biomass_HG)
print(UB_biomass_HG)

print(LB_biomass_LG)
print(UB_biomass_LG)
# Out:
# 0.00867111406486249
# 0.022480449099241465
# 0.011552453009332421
# 0.0519860385419959

# %%
#we take the FVA from exofluxomics and for each family we set the biomass bounds and compute FVA again in order to create new bounds for each family
model.reactions.get_by_id('BIOMASS_reaction').bounds = (LB_biomass_HG, UB_biomass_HG)
print(model.slim_optimize())
df_fva_HG = flux_variability_analysis(model, fraction_of_optimum=0.0, processes=20)
df_fva_HG.to_csv('./data/fva_exoflux_HG.csv')
df_fva_HG.loc['BIOMASS_reaction']
# Out:
# 0.022480449099241465
# minimum    0.008671
# maximum    0.022480
# Name: BIOMASS_reaction, dtype: float64

# %%
model.reactions.get_by_id('BIOMASS_reaction').bounds = (LB_biomass_LG, UB_biomass_LG)
print(model.slim_optimize())
df_fva_LG = flux_variability_analysis(model, fraction_of_optimum=0.0, processes=20)
df_fva_LG.to_csv('./data/fva_exoflux_LG.csv')
df_fva_LG.loc['BIOMASS_reaction']
# Out:
# 0.0519860385419959
# minimum    0.011552
# maximum    0.051986
# Name: BIOMASS_reaction, dtype: float64

# %% [markdown]
# Basically each of these two FVA represent a model (HG anD LG)

# %% [markdown]
# # Minimize Sum of uptakes

# %% [markdown]
# In the exoflux dataset we used a column called is_set to indicate which exchange reactions had their bounds modified based on Jain data.
#
# All the experimantal bounds were integrated. However, many exchange reactions were left as -100, +100 (this doesn't happen in reality).
#
# For this reason, we apply the parsimonius principle to minimize the sum of uptakes BUT in such a way that the UB for growth rate can still be reached.
#
# We will run this pipeline for our two models: low and high grade.

# %%
model = load_json_model('./data/Recon3D.json')
model.solver = 'gurobi'
model
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2731476
# Academic license - for non-commercial use only - expires 2026-11-01
# <Model Recon3D at 0x717ce67bd960>

# %%
df_exoflux = pd.read_csv('./data/exoflux_bounds.csv', index_col=0)
df_exoflux
# Out:
#                      in_medium  in_jain Metabolite ID Recon3D          LB  \
# EX_5adtststerone_e           0        0       5adtststerone_e -100.000000
# EX_5adtststerones_e          0        0      5adtststerones_e -100.000000
# EX_5fthf_e                   0        0               5fthf_e -100.000000
# EX_5htrp_e                   0        0               5htrp_e -100.000000
# EX_5mthf_e                   0        0               5mthf_e -100.000000
# ...                        ...      ...                   ...         ...
# EX_3h3mglt_e                 0        0             3h3mglt_e -100.000000
# EX_ppiogly_e                 0        0             ppiogly_e -100.000000
# EX_sbt__D_e                  0        1              sbt__D_e    0.000046
# EX_lvstacid_e                0        0            lvstacid_e -100.000000
# EX_ptvstm13_e                0        0            ptvstm13_e -100.000000
#
#                              UB  is_set
# EX_5adtststerone_e   100.000000       0
# EX_5adtststerones_e  100.000000       0
# EX_5fthf_e           100.000000       0
# EX_5htrp_e           100.000000       0
# EX_5mthf_e           100.000000       0
# ...                         ...     ...
# EX_3h3mglt_e         100.000000       0
# EX_ppiogly_e         100.000000       0
# EX_sbt__D_e            0.000514       1
# EX_lvstacid_e        100.000000       0
# EX_ptvstm13_e        100.000000       0
#
# [1560 rows x 6 columns]

# %%
df_exoflux["is_set"].sum()
# Out:
# 115

# %%
df_fva_LG = pd.read_csv('./data/fva_exoflux_LG.csv', index_col=0)
df_fva_HG = pd.read_csv('./data/fva_exoflux_HG.csv', index_col=0)

# %%
for index, row in df_fva_LG.iterrows():
    model.reactions.get_by_id(index).bounds = (row['minimum'], row['maximum'])

obj_var = None
for index, row in df_exoflux.iterrows():
    if model.reactions.get_by_id(index).lower_bound < 1e-6:
        if row.is_set == 0:
            if(obj_var is None):
                obj_var = model.reactions.get_by_id(index).reverse_variable
            else:
                obj_var = obj_var + model.reactions.get_by_id(index).reverse_variable
            

#we take the reverse variable of each reaction flux. The reverse variable is between [0, |LB|]. It's always a positive number.
#cobra always return the net flux for each reactions as the difference between the forward and reverse variables.
#we want to minimize the negative flux of these reactions = uptake fluxes

original_biomass_bounds = model.reactions.get_by_id('BIOMASS_reaction').bounds
model.reactions.get_by_id('BIOMASS_reaction').bounds = (original_biomass_bounds[1]*0.90, original_biomass_bounds[1])

model.objective = obj_var
model.objective_direction = 'min'
X = model.slim_optimize()
print("MIN sum of uptake fluxes for LG: ", X)

#now we add a constraint to the model 
min_sum_up = model.problem.Constraint(
    obj_var,
    ub=X*1.2, lb = 0)
model.add_cons_vars(min_sum_up)
#we relax biomass bounds back to original
model.reactions.get_by_id('BIOMASS_reaction').bounds = original_biomass_bounds

model.objective = "BIOMASS_reaction"
model.objective_direction = "max"

#compute FVA again
df_fva_LG_min_sum = flux_variability_analysis(model, fraction_of_optimum=0.0, processes=20)
df_fva_LG_min_sum.to_csv('./data/fva_exoflux_LG_min_sum.csv')

# %%
model = load_json_model('./data/Recon3D.json')
model.solver = 'gurobi'
model
# Out:
# <Model Recon3D at 0x717b7b6d1300>

# %%
for index, row in df_fva_HG.iterrows():
    model.reactions.get_by_id(index).bounds = (row['minimum'], row['maximum'])

obj_var = None
for index, row in df_exoflux.iterrows():
    if model.reactions.get_by_id(index).lower_bound < 1e-6:
        if row.is_set == 0:
            if(obj_var is None):
                obj_var = model.reactions.get_by_id(index).reverse_variable
            else:
                obj_var = obj_var + model.reactions.get_by_id(index).reverse_variable
            

#we take the reverse variable of each reaction flux. The reverse variable is between [0, |LB|]. It's always a positive number.
#cobra always return the net flux for each reactions as the difference between the forward and reverse variables.
#we want to minimize the negative flux of these reactions = uptake fluxes

original_biomass_bounds = model.reactions.get_by_id('BIOMASS_reaction').bounds
model.reactions.get_by_id('BIOMASS_reaction').bounds = (original_biomass_bounds[1]*0.90, original_biomass_bounds[1])

model.objective = obj_var
model.objective_direction = 'min'
X = model.slim_optimize()
print("MIN sum of uptake fluxes for HG: ", X)

#now we add a constraint to the model 
min_sum_up = model.problem.Constraint(
    obj_var,
    ub=X*1.2, lb = 0)
model.add_cons_vars(min_sum_up)
#we relax biomass bounds back to original
model.reactions.get_by_id('BIOMASS_reaction').bounds = original_biomass_bounds

model.objective = "BIOMASS_reaction"
model.objective_direction = "max"

#compute FVA again
df_fva_HG_min_sum = flux_variability_analysis(model, fraction_of_optimum=0.0, processes=20)
df_fva_HG_min_sum.to_csv('./data/fva_exoflux_HG_min_sum.csv')
# Out:
# MIN sum of uptake fluxes for HG:  5e-07

# %%
df_fva_HG_min_sum.loc["BIOMASS_reaction"]
# Out:
# minimum    0.008671
# maximum    0.022480
# Name: BIOMASS_reaction, dtype: float64

# %%
df_fva_LG_min_sum.loc["BIOMASS_reaction"]
# Out:
# minimum    0.011552
# maximum    0.051986
# Name: BIOMASS_reaction, dtype: float64

# %% [markdown]
# As you see thr experimental bounds for biomass are still feasible

# %% [markdown]
# # RNA-seq integration

# %% [markdown]
# Now it's time to integrate RNA-seq data into the two models we've just created to generate 7 context-specific metaboli models.
#
# We're going to use INTEGRATE by de Filippo and Damiani with a small update: we will modify a reaction bound only if it guarantees to reach the upper bound of biomass of the general family model.

# %%
model = load_json_model('./data/Recon3D.json')
model.solver = 'gurobi'
model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = load_json_model('./data/Recon3D.json')
#       2 model.solver = 'gurobi'
#       3 model
#
# File c:\Users\leabr\anaconda3\envs\trial\Lib\site-packages\cobra\io\json.py:145, in load_json_model(filename)
#     126 """Load a cobra model from a file in JSON format.
#     127
#     128 Parameters
#    (...)    142
#     143 """
#     144 if isinstance(filename, (str, Path)):
# --> 145     with open(filename, "r") as file_handle:
#     146         return model_from_dict(json.load(file_handle))
#     147 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/Recon3D.json'

# %%
import mygene

# Extract Entrez gene IDs and model gene info
gene_data = []
for gene in model.genes:
    if 'ncbigene' in gene.annotation:
        entrez_id = gene.annotation['ncbigene'][0]  # First ID if multiple
        gene_data.append({
            'recon_id': gene.id,
            'gene_name': gene.name,
            'entrez_id': entrez_id
        })

genes_df = pd.DataFrame(gene_data)
print(f"Found {len(genes_df)} genes with Entrez IDs")

# Query mygene for Ensembl mapping
mg = mygene.MyGeneInfo()
results = mg.querymany(
    genes_df['entrez_id'].tolist(), 
    scopes='entrezgene',
    fields='ensembl',
    species='human'
)

# Parse results and keep only primary ENSG IDs
mapping = []
for result in results:
    if 'ensembl' in result and result['ensembl'] is not None:
        ensembl = result['ensembl']
        
        # Extract gene ID (handle various formats)
        if isinstance(ensembl, dict):
            gene_id = ensembl.get('gene')
        elif isinstance(ensembl, list) and len(ensembl) > 0:
            gene_id = ensembl[0].get('gene') if isinstance(ensembl[0], dict) else ensembl[0]
        else:
            gene_id = str(ensembl)
        
        # Keep only ENSG (gene-level, not transcripts)
        if gene_id and str(gene_id).startswith('ENSG'):
            mapping.append({
                'entrez_id': str(result['query']),
                'ensembl_id': gene_id
            })

mapping_df = pd.DataFrame(mapping)

# Merge with original gene data and remove duplicates
result_df_genes = genes_df.merge(mapping_df, on='entrez_id', how='left')
result_df_genes = result_df_genes.drop_duplicates(subset=['entrez_id'], keep='first')
# Out:
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# Found 2229 genes with Entrez IDs
# 237 input query terms found dup hits:	[('314', 2), ('6818', 3), ('3948', 2), ('51', 2), ('52', 3), ('55902', 2), ('57835', 4), ('4967', 2)

# %%
result_df_genes
# Out:
#         recon_id gene_name entrez_id       ensembl_id
# 0         26_AT1      AOC1        26  ENSG00000002726
# 1        314_AT1      AOC2       314  ENSG00000131480
# 3       8639_AT1      AOC3      8639  ENSG00000131471
# 6       1591_AT1   CYP24A1      1591  ENSG00000019186
# 7       1594_AT1   CYP27B1      1594  ENSG00000111012
# ...          ...       ...       ...              ...
# 3605  267020_AT1    ATP5L2    267020  ENSG00000249222
# 3635   27089_AT1     UQCRQ     27089  ENSG00000164405
# 3636   10975_AT1    UQCR11     10975  ENSG00000127540
# 3637    7381_AT1     UQCRB      7381  ENSG00000156467
# 3640    4519_AT1      CYTB      4519  ENSG00000198727
#
# [1865 rows x 4 columns]

# %%
cell_annotation = pd.read_csv('./data/Cell_lines_annotations_20181226.txt', index_col=0, sep='\t')
cell_annotation
# Out:
#                                             depMapID       Name   Pathology  \
# CCLE_ID
# DMS53_LUNG                                ACH-000698     DMS 53     primary
# SW1116_LARGE_INTESTINE                    ACH-000489     SW1116     primary
# NCIH1694_LUNG                             ACH-000431  NCI-H1694  metastasis
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000707     P3HR-1  metastasis
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000509     HuT 78     primary
# ...                                              ...        ...         ...
# GEO_LARGE_INTESTINE                       ACH-002394        NaN         NaN
# NCIH2330_LUNG                                    NaN        NaN         NaN
# LP6_SOFT_TISSUE                           ACH-001116        NaN         NaN
# HS578BST_BREAST                                  NaN        NaN         NaN
# LC1SQ_LUNG                                ACH-002156        NaN         NaN
#
#                                                                 Site_Primary  \
# CCLE_ID
# DMS53_LUNG                                                              lung
# SW1116_LARGE_INTESTINE                                       large_intestine
# NCIH1694_LUNG                                                           lung
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  haematopoietic_and_lymphoid_tissue
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  haematopoietic_and_lymphoid_tissue
# ...                                                                      ...
# GEO_LARGE_INTESTINE                                                      NaN
# NCIH2330_LUNG                                                            NaN
# LP6_SOFT_TISSUE                                                          NaN
# HS578BST_BREAST                                                          NaN
# LC1SQ_LUNG                                                               NaN
#
#                                          Site_Subtype1 Site_Subtype2  \
# CCLE_ID
# DMS53_LUNG                                          NS            NS
# SW1116_LARGE_INTESTINE                           colon            NS
# NCIH1694_LUNG                                       NS            NS
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS            NS
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE          skin            NS
# ...                                                ...           ...
# GEO_LARGE_INTESTINE                                NaN           NaN
# NCIH2330_LUNG                                      NaN           NaN
# LP6_SOFT_TISSUE                                    NaN           NaN
# HS578BST_BREAST                                    NaN           NaN
# LC1SQ_LUNG                                         NaN           NaN
#
#                                          Site_Subtype3          Histology  \
# CCLE_ID
# DMS53_LUNG                                          NS          carcinoma
# SW1116_LARGE_INTESTINE                              NS          carcinoma
# NCIH1694_LUNG                                       NS          carcinoma
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  lymphoid_neoplasm
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  lymphoid_neoplasm
# ...                                                ...                ...
# GEO_LARGE_INTESTINE                                NaN                NaN
# NCIH2330_LUNG                                      NaN                NaN
# LP6_SOFT_TISSUE                                    NaN                NaN
# HS578BST_BREAST                                    NaN                NaN
# LC1SQ_LUNG                                         NaN                NaN
#
#                                                               Hist_Subtype1  \
# CCLE_ID
# DMS53_LUNG                                             small_cell_carcinoma
# SW1116_LARGE_INTESTINE                                       adenocarcinoma
# NCIH1694_LUNG                                          small_cell_carcinoma
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                   Burkitt_lymphoma
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  mycosis_fungoides-Sezary_syndrome
# ...                                                                     ...
# GEO_LARGE_INTESTINE                                                     NaN
# NCIH2330_LUNG                                                           NaN
# LP6_SOFT_TISSUE                                                         NaN
# HS578BST_BREAST                                                         NaN
# LC1SQ_LUNG                                                              NaN
#
#                                          Hist_Subtype2  ...  \
# CCLE_ID                                                 ...
# DMS53_LUNG                                          NS  ...
# SW1116_LARGE_INTESTINE                              NS  ...
# NCIH1694_LUNG                                       NS  ...
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  ...
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NS  ...
# ...                                                ...  ...
# GEO_LARGE_INTESTINE                                NaN  ...
# NCIH2330_LUNG                                      NaN  ...
# LP6_SOFT_TISSUE                                    NaN  ...
# HS578BST_BREAST                                    NaN  ...
# LC1SQ_LUNG                                         NaN  ...
#
#                                               Growth.Medium  \
# CCLE_ID
# DMS53_LUNG                                Waymouth's+10%FBS
# SW1116_LARGE_INTESTINE                           L15+10%FBS
# NCIH1694_LUNG                                DMEM:F12+5%FBS
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                NaN
# ...                                                     ...
# GEO_LARGE_INTESTINE                                     NaN
# NCIH2330_LUNG                                           NaN
# LP6_SOFT_TISSUE                                         NaN
# HS578BST_BREAST                                         NaN
# LC1SQ_LUNG                                              NaN
#
#                                                                                 Supplements  \
# CCLE_ID
# DMS53_LUNG                                                                              NaN
# SW1116_LARGE_INTESTINE                                                                  NaN
# NCIH1694_LUNG                             005 mg/ml insulin, 01 mg/ml transferrin, 30nM ...
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                                                NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                                                NaN
# ...                                                                                     ...
# GEO_LARGE_INTESTINE                                                                     NaN
# NCIH2330_LUNG                                                                           NaN
# LP6_SOFT_TISSUE                                                                         NaN
# HS578BST_BREAST                                                                         NaN
# LC1SQ_LUNG                                                                              NaN
#
#                                          FreezingMedium  \
# CCLE_ID
# DMS53_LUNG                                       5%DMSO
# SW1116_LARGE_INTESTINE                           5%DMSO
# NCIH1694_LUNG                                   5% DMSO
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE            NaN
# ...                                                 ...
# GEO_LARGE_INTESTINE                                 NaN
# NCIH2330_LUNG                                       NaN
# LP6_SOFT_TISSUE                                     NaN
# HS578BST_BREAST                                     NaN
# LC1SQ_LUNG                                          NaN
#
#                                           DoublingTimefromVendor  \
# CCLE_ID
# DMS53_LUNG                                                   NaN
# SW1116_LARGE_INTESTINE                                       NaN
# NCIH1694_LUNG                                                NaN
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                     NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                     NaN
# ...                                                          ...
# GEO_LARGE_INTESTINE                                          NaN
# NCIH2330_LUNG                                                NaN
# LP6_SOFT_TISSUE                                              NaN
# HS578BST_BREAST                                              NaN
# LC1SQ_LUNG                                                   NaN
#
#                                          DoublingTimeCalculatedhrs  \
# CCLE_ID
# DMS53_LUNG                                                   450.0
# SW1116_LARGE_INTESTINE                                      1232.0
# NCIH1694_LUNG                                                812.0
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                       NaN
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                       NaN
# ...                                                            ...
# GEO_LARGE_INTESTINE                                            NaN
# NCIH2330_LUNG                                                  NaN
# LP6_SOFT_TISSUE                                                NaN
# HS578BST_BREAST                                                NaN
# LC1SQ_LUNG                                                     NaN
#
#                                                       type  \
# CCLE_ID
# DMS53_LUNG                                 lung_small_cell
# SW1116_LARGE_INTESTINE                          colorectal
# NCIH1694_LUNG                              lung_small_cell
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  lymphoma_Burkitt
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    lymphoma_other
# ...                                                    ...
# GEO_LARGE_INTESTINE                                    NaN
# NCIH2330_LUNG                                          NaN
# LP6_SOFT_TISSUE                                        NaN
# HS578BST_BREAST                                        NaN
# LC1SQ_LUNG                                             NaN
#
#                                                    type_refined  \
# CCLE_ID
# DMS53_LUNG                                      lung_small_cell
# SW1116_LARGE_INTESTINE                               colorectal
# NCIH1694_LUNG                                   lung_small_cell
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       lymphoma_Burkitt
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  T-cell_lymphoma_other
# ...                                                         ...
# GEO_LARGE_INTESTINE                                  colorectal
# NCIH2330_LUNG                                               NaN
# LP6_SOFT_TISSUE                                             NaN
# HS578BST_BREAST                                             NaN
# LC1SQ_LUNG                                             lung_NSC
#
#                                          PATHOLOGIST_ANNOTATION       mutRate  \
# CCLE_ID
# DMS53_LUNG                                            Lung:SCLC  1.572416e+09
# SW1116_LARGE_INTESTINE                     Colorectal:Carcinoma  9.437319e+09
# NCIH1694_LUNG                                         Lung:SCLC  1.095350e+08
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Lymphoma:NH_B_cell  1.664564e+09
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Lymphoma:NH_T_cell  1.182176e+09
# ...                                                         ...           ...
# GEO_LARGE_INTESTINE                                         NaN           NaN
# NCIH2330_LUNG                                               NaN           NaN
# LP6_SOFT_TISSUE                                             NaN           NaN
# HS578BST_BREAST                                             NaN           NaN
# LC1SQ_LUNG                                                  NaN           NaN
#
#                                           tcga_code
# CCLE_ID
# DMS53_LUNG                                     SCLC
# SW1116_LARGE_INTESTINE                    COAD/READ
# NCIH1694_LUNG                                  SCLC
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       DLBC
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        NaN
# ...                                             ...
# GEO_LARGE_INTESTINE                       COAD/READ
# NCIH2330_LUNG                                   NaN
# LP6_SOFT_TISSUE                                 NaN
# HS578BST_BREAST                                 NaN
# LC1SQ_LUNG                                     LUSC
#
# [1461 rows x 32 columns]

# %%
cell_annotation.loc[['COV318_OVARY', 'CAOV3_OVARY', 
                    'OAW28_OVARY', '59M_OVARY', 'HEYA8_OVARY', 'OV56_OVARY']]
# Out:
#                 depMapID    Name   Pathology Site_Primary Site_Subtype1  \
# CCLE_ID
# COV318_OVARY  ACH-000256  COV318     primary        ovary            NS
# CAOV3_OVARY   ACH-000713  Caov-3     primary        ovary            NS
# OAW28_OVARY   ACH-000116   OAW28     primary        ovary            NS
# 59M_OVARY     ACH-000520     59M  metastasis        ovary            NS
# HEYA8_OVARY   ACH-000542  Hey-A8  metastasis        ovary            NS
#
#              Site_Subtype2 Site_Subtype3  Histology   Hist_Subtype1  \
# CCLE_ID
# COV318_OVARY            NS            NS  carcinoma              NS
# CAOV3_OVARY             NS            NS  carcinoma  adenocarcinoma
# OAW28_OVARY             NS            NS  carcinoma              NS
# 59M_OVARY               NS            NS  carcinoma              NS
# HEYA8_OVARY             NS            NS  carcinoma              NS
#
#              Hist_Subtype2  ... Growth.Medium    Supplements FreezingMedium  \
# CCLE_ID                     ...
# COV318_OVARY            NS  ...   DMEM+10%FBS  2mM Glutamine         5%DMSO
# CAOV3_OVARY             NS  ...           NaN            NaN            NaN
# OAW28_OVARY             NS  ...           NaN            NaN            NaN
# 59M_OVARY               NS  ...           NaN            NaN            NaN
# HEYA8_OVARY             NS  ...           NaN            NaN            NaN
#
#               DoublingTimefromVendor DoublingTimeCalculatedhrs   type  \
# CCLE_ID
# COV318_OVARY                     NaN                     931.0  ovary
# CAOV3_OVARY                      NaN                       NaN  ovary
# OAW28_OVARY                      NaN                       NaN  ovary
# 59M_OVARY                        NaN                       NaN  ovary
# HEYA8_OVARY                      NaN                       NaN  ovary
#
#              type_refined PATHOLOGIST_ANNOTATION       mutRate tcga_code
# CCLE_ID
# COV318_OVARY        ovary        Ovary:Carcinoma  9.950889e+09        OV
# CAOV3_OVARY         ovary        Ovary:Carcinoma  1.409124e+09        OV
# OAW28_OVARY         ovary        Ovary:Carcinoma  8.353377e+09        OV
# 59M_OVARY           ovary        Ovary:Carcinoma  1.106123e+09        OV
# HEYA8_OVARY         ovary        Ovary:Carcinoma  1.110356e+09        OV
#
# [5 rows x 32 columns]

# %%
rna_seq_df = pd.read_csv('./data/CCLE_expression_full.csv', index_col=0)
rna_seq_df
# Out:
#             TSPAN6 (ENSG00000000003)  TNMD (ENSG00000000005)  \
# ACH-001113                  4.331992                0.000000
# ACH-001289                  4.566815                0.584963
# ACH-001339                  3.150560                0.000000
# ACH-001538                  5.085340                0.000000
# ACH-000242                  6.729145                0.000000
# ...                              ...                     ...
# ACH-000285                  0.056584                0.000000
# ACH-002669                  3.109361                0.000000
# ACH-001858                  4.390943                0.000000
# ACH-001997                  5.057017                0.000000
# ACH-000052                  4.247928                0.000000
#
#             DPM1 (ENSG00000000419)  SCYL3 (ENSG00000000457)  \
# ACH-001113                7.364397                 2.792855
# ACH-001289                7.106537                 2.543496
# ACH-001339                7.379032                 2.333424
# ACH-001538                7.154109                 2.545968
# ACH-000242                6.537607                 2.456806
# ...                            ...                      ...
# ACH-000285                6.604071                 3.264536
# ACH-002669                7.031219                 1.541019
# ACH-001858                7.013127                 1.887525
# ACH-001997                7.814935                 2.538538
# ACH-000052                6.174127                 2.316146
#
#             C1orf112 (ENSG00000000460)  FGR (ENSG00000000938)  \
# ACH-001113                    4.470537               0.028569
# ACH-001289                    3.504620               0.000000
# ACH-001339                    4.227279               0.056584
# ACH-001538                    3.084064               0.000000
# ACH-000242                    3.867896               0.799087
# ...                                ...                    ...
# ACH-000285                    4.972693               0.411426
# ACH-002669                    3.664483               0.014355
# ACH-001858                    3.252476               0.028569
# ACH-001997                    3.893362               0.028569
# ACH-000052                    3.823749               0.189034
#
#             CFH (ENSG00000000971)  FUCA2 (ENSG00000001036)  \
# ACH-001113               1.226509                 3.042644
# ACH-001289               0.189034                 3.813525
# ACH-001339               1.310340                 6.687061
# ACH-001538               5.868143                 6.165309
# ACH-000242               7.208381                 5.569856
# ...                           ...                      ...
# ACH-000285               0.097611                 0.704872
# ACH-002669               3.624101                 6.805292
# ACH-001858               3.286881                 6.902074
# ACH-001997               4.078951                 6.971429
# ACH-000052               1.321928                 3.536053
#
#             GCLC (ENSG00000001084)  NFYA (ENSG00000001167)  ...  \
# ACH-001113                6.499686                4.739848  ...
# ACH-001289                4.221104                3.481557  ...
# ACH-001339                3.682573                3.273516  ...
# ACH-001538                4.489928                3.956986  ...
# ACH-000242                7.127014                4.568032  ...
# ...                            ...                     ...  ...
# ACH-000285                4.829850                5.178715  ...
# ACH-002669                4.472488                4.397118  ...
# ACH-001858                5.410748                3.401903  ...
# ACH-001997                4.469886                3.463361  ...
# ACH-000052                3.943921                4.468583  ...
#
#             ENSG00000288714  ENSG00000288717  ENSG00000288718  \
# ACH-001113         0.000000         0.536053         0.000000
# ACH-001289         0.000000         0.879706         0.000000
# ACH-001339         0.028569         0.000000         0.084064
# ACH-001538         0.000000         0.000000         0.070389
# ACH-000242         0.000000         0.000000         0.201634
# ...                     ...              ...              ...
# ACH-000285         0.000000         0.000000         0.000000
# ACH-002669         0.000000         0.575312         0.807355
# ACH-001858         0.014355         0.000000         0.226509
# ACH-001997         0.000000         0.000000         0.084064
# ACH-000052         0.056584         0.000000         0.056584
#
#             ENSG00000288719  ENSG00000288720  ENSG00000288721  \
# ACH-001113         0.028569         0.176323         0.992768
# ACH-001289         0.014355         0.014355         0.432959
# ACH-001339         0.000000         0.097611         0.367371
# ACH-001538         0.000000         0.176323         0.411426
# ACH-000242         0.028569         0.137504         0.678072
# ...                     ...              ...              ...
# ACH-000285         0.056584         0.298658         1.244887
# ACH-002669         0.000000         0.163499         0.454176
# ACH-001858         0.014355         0.028569         0.695994
# ACH-001997         0.000000         0.214125         0.604071
# ACH-000052         0.042644         0.176323         0.985500
#
#             ENSG00000288722  ENSG00000288723  ENSG00000288724  ENSG00000288725
# ACH-001113         2.794936         0.000000              0.0         0.000000
# ACH-001289         2.972693         0.056584              0.0         0.070389
# ACH-001339         1.695994         0.084064              0.0         0.000000
# ACH-001538         3.921246         0.028569              0.0         0.000000
# ACH-000242         4.418190         0.000000              0.0         0.000000
# ...                     ...              ...              ...              ...
# ACH-000285         4.553975         0.056584              0.0         0.000000
# ACH-002669         5.377818         0.310340              0.0         0.000000
# ACH-001858         4.456806         0.367371              0.0         0.000000
# ACH-001997         4.196135         0.084064              0.0         0.028569
# ACH-000052         4.074677         0.000000              0.0         0.000000
#
# [1406 rows x 53970 columns]

# %%
rna_seq_df = rna_seq_df.loc[['ACH-000256', 'ACH-000713', 'ACH-000116', 'ACH-000520', 'ACH-000542', 'ACH-000091']]
rna_seq_df
# Out:
#             TSPAN6 (ENSG00000000003)  TNMD (ENSG00000000005)  \
# ACH-000256                  3.715893                     0.0
# ACH-000713                  4.990501                     0.0
# ACH-000116                  4.996841                     0.0
# ACH-000520                  3.460743                     0.0
# ACH-000542                  3.718088                     0.0
#
#             DPM1 (ENSG00000000419)  SCYL3 (ENSG00000000457)  \
# ACH-000256                6.957450                 1.985500
# ACH-000713                7.167017                 1.761285
# ACH-000116                6.455656                 2.298658
# ACH-000520                6.399000                 1.855990
# ACH-000542                7.133810                 1.922198
#
#             C1orf112 (ENSG00000000460)  FGR (ENSG00000000938)  \
# ACH-000256                    3.399171               0.137504
# ACH-000713                    3.472488               0.084064
# ACH-000116                    3.852998               0.028569
# ACH-000520                    3.374344               0.028569
# ACH-000542                    3.787641               0.000000
#
#             CFH (ENSG00000000971)  FUCA2 (ENSG00000001036)  \
# ACH-000256               5.750607                 4.849499
# ACH-000713               2.839960                 6.684819
# ACH-000116               0.863938                 6.507636
# ACH-000520               3.261531                 6.094869
# ACH-000542               0.475085                 6.115824
#
#             GCLC (ENSG00000001084)  NFYA (ENSG00000001167)  ...  \
# ACH-000256                3.214125                3.308885  ...
# ACH-000713                6.358080                5.019257  ...
# ACH-000116                4.698774                3.802193  ...
# ACH-000520                5.290203                3.947666  ...
# ACH-000542                4.336997                2.946731  ...
#
#             ENSG00000288714  ENSG00000288717  ENSG00000288718  \
# ACH-000256         0.028569         0.176323         0.000000
# ACH-000713         0.000000         0.000000         0.124328
# ACH-000116         0.028569         0.454176         0.124328
# ACH-000520         0.028569         0.000000         0.137504
# ACH-000542         0.000000         0.000000         0.855990
#
#             ENSG00000288719  ENSG00000288720  ENSG00000288721  \
# ACH-000256         0.014355         0.084064         0.411426
# ACH-000713         0.042644         0.056584         0.378512
# ACH-000116         0.014355         0.613532         0.739848
# ACH-000520         0.000000         0.056584         0.978196
# ACH-000542         0.014355         0.042644         0.575312
#
#             ENSG00000288722  ENSG00000288723  ENSG00000288724  ENSG00000288725
# ACH-000256         3.771886         0.028569              0.0         0.070389
# ACH-000713         2.671293         0.000000              0.0         0.000000
# ACH-000116         4.937344         0.028569              0.0         0.097611
# ACH-000520         3.116032         0.000000              0.0         0.137504
# ACH-000542         4.095924         0.000000              0.0         0.000000
#
# [5 rows x 53970 columns]

# %%
g_list = []
for k in rna_seq_df.columns:
    g_list.append(k)

g_ensembl = []
for n in range(len(g_list)):
    if 'ENS' not in (g_list[n].split())[0]:
        g_ensembl.append((g_list[n].split())[1])
    if 'ENS' in (g_list[n].split())[0]:
        g_ensembl.append((g_list[n].split())[0])
        
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
g_ensembl_2 = []
for n in range(len(g_ensembl)):
    for x in g_ensembl[n]:
        if x in punc:
            g_ensembl[n] = g_ensembl[n].replace(x, "")
    g_ensembl_2.append(g_ensembl[n])
g_ensembl_2
# Out:
# ['ENSG00000000003',
#  'ENSG00000000005',
#  'ENSG00000000419',
#  'ENSG00000000457',
#  'ENSG00000000460',
#  'ENSG00000000938',
#  'ENSG00000000971',
#  'ENSG00000001036',
#  'ENSG00000001084',
#  'ENSG00000001167',
#  'ENSG00000001460',
#  'ENSG00000001461',
#  'ENSG00000001497',
#  'ENSG00000001561',
#  'ENSG00000001617',
#  'ENSG00000001626',
#  'ENSG00000001629',
#  'ENSG00000001630',
#  'ENSG00000001631',
#  'ENSG00000066136',
#  'ENSG00000066185',
#  'ENSG00000066230',
#  'ENSG00000066248',
#  'ENSG00000066279',
#  'ENSG00000066294',
#  'ENSG00000066322',
#  'ENSG00000066336',
#  'ENSG00000066379',
#  'ENSG00000066382',
#  'ENSG00000066405',
#  'ENSG00000066422',
#  'ENSG00000066427',
#  'ENSG00000066455',
#  'ENSG00000066468',
#  'ENSG00000066557',
#  'ENSG00000066583',
#  'ENSG00000066629',
#  'ENSG00000066651',
#  'ENSG00000066654',
#  'ENSG00000066697',
#  'ENSG00000066735',
#  'ENSG00000066739',
#  'ENSG00000066777',
#  'ENSG00000066813',
#  'ENSG00000066827',
#  'ENSG00000066855',
#  'ENSG00000066923',
#  'ENSG00000066926',
#  'ENSG00000066933',
#  'ENSG00000067048',
#  'ENSG00000067057',
#  'ENSG00000067064',
#  'ENSG00000067066',
#  'ENSG00000067082',
#  'ENSG00000067113',
#  'ENSG00000067141',
#  'ENSG00000067167',
#  ...]

# %%
g_ensembl_2_final = []
for el in g_ensembl_2:
    if el in result_df_genes['ensembl_id'].values.tolist():
        g_ensembl_2_final.append(el)
g_ensembl_2_final
# Out:
# ['ENSG00000001036',
#  'ENSG00000001084',
#  'ENSG00000001626',
#  'ENSG00000001630',
#  'ENSG00000002549',
#  'ENSG00000002587',
#  'ENSG00000002726',
#  'ENSG00000003987',
#  'ENSG00000003989',
#  'ENSG00000004455',
#  'ENSG00000004468',
#  'ENSG00000004779',
#  'ENSG00000004864',
#  'ENSG00000004939',
#  'ENSG00000005022',
#  'ENSG00000005187',
#  'ENSG00000005381',
#  'ENSG00000005469',
#  'ENSG00000005471',
#  'ENSG00000005483',
#  'ENSG00000006071',
#  'ENSG00000006530',
#  'ENSG00000006534',
#  'ENSG00000006625',
#  'ENSG00000006757',
#  'ENSG00000007001',
#  'ENSG00000007168',
#  'ENSG00000007171',
#  'ENSG00000007216',
#  'ENSG00000007350',
#  'ENSG00000007541',
#  'ENSG00000008130',
#  'ENSG00000008311',
#  'ENSG00000008513',
#  'ENSG00000010256',
#  'ENSG00000010379',
#  'ENSG00000010404',
#  'ENSG00000011083',
#  'ENSG00000011198',
#  'ENSG00000011405',
#  'ENSG00000012232',
#  'ENSG00000012660',
#  'ENSG00000013375',
#  'ENSG00000013392',
#  'ENSG00000014257',
#  'ENSG00000014641',
#  'ENSG00000015413',
#  'ENSG00000015520',
#  'ENSG00000015532',
#  'ENSG00000016391',
#  'ENSG00000016864',
#  'ENSG00000017483',
#  'ENSG00000017797',
#  'ENSG00000018280',
#  'ENSG00000018625',
#  'ENSG00000019186',
#  'ENSG00000021461',
#  'ENSG00000021488',
#  'ENSG00000021826',
#  'ENSG00000023228',
#  'ENSG00000023330',
#  'ENSG00000023572',
#  'ENSG00000023697',
#  'ENSG00000023839',
#  'ENSG00000023909',
#  'ENSG00000025423',
#  'ENSG00000025708',
#  'ENSG00000026652',
#  'ENSG00000027847',
#  'ENSG00000033100',
#  'ENSG00000033627',
#  'ENSG00000033867',
#  'ENSG00000035687',
# 7       1594_AT1   CYP27B1      1594  ENSG00000111012
# ...          ...       ...       ...              ...
# 3605  267020_AT1    ATP5L2    267020  ENSG00000249222
# 3635   27089_AT1     UQCRQ     27089  ENSG00000164405
# 3636   10975_AT1    UQCR11     10975  ENSG00000127540
# 3637    7381_AT1     UQCRB      7381  ENSG00000156467
# 3640    4519_AT1      CYTB      4519  ENSG00000198727
#
# [1803 rows x 4 columns]

# %%
import re
new_columns = []
for column in rna_seq_df.columns:
    new_columns.append(re.search(r'(ENSG\d+)', column).group(1))
rna_seq_df.columns = new_columns
rna_seq_df
# Out:
#             ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# ACH-000256         3.715893              0.0         6.957450
# ACH-000713         4.990501              0.0         7.167017
# ACH-000116         4.996841              0.0         6.455656
# ACH-000520         3.460743              0.0         6.399000
# ACH-000542         3.718088              0.0         7.133810
#
#             ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# ACH-000256         1.985500         3.399171         0.137504
# ACH-000713         1.761285         3.472488         0.084064
# ACH-000116         2.298658         3.852998         0.028569
# ACH-000520         1.855990         3.374344         0.028569
# ACH-000542         1.922198         3.787641         0.000000
#
#             ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# ACH-000256         5.750607         4.849499         3.214125
# ACH-000713         2.839960         6.684819         6.358080
# ACH-000116         0.863938         6.507636         4.698774
# ACH-000520         3.261531         6.094869         5.290203
# ACH-000542         0.475085         6.115824         4.336997
#
#             ENSG00000001167  ...  ENSG00000288714  ENSG00000288717  \
# ACH-000256         3.308885  ...         0.028569         0.176323
# ACH-000713         5.019257  ...         0.000000         0.000000
# ACH-000116         3.802193  ...         0.028569         0.454176
# ACH-000520         3.947666  ...         0.028569         0.000000
# ACH-000542         2.946731  ...         0.000000         0.000000
#
#             ENSG00000288718  ENSG00000288719  ENSG00000288720  \
# ACH-000256         0.000000         0.014355         0.084064
# ACH-000713         0.124328         0.042644         0.056584
# ACH-000116         0.124328         0.014355         0.613532
# ACH-000520         0.137504         0.000000         0.056584
# ACH-000542         0.855990         0.014355         0.042644
#
#             ENSG00000288721  ENSG00000288722  ENSG00000288723  \
# ACH-000256         0.411426         3.771886         0.028569
# ACH-000713         0.378512         2.671293         0.000000
# ACH-000116         0.739848         4.937344         0.028569
# ACH-000520         0.978196         3.116032         0.000000
# ACH-000542         0.575312         4.095924         0.000000
#
#             ENSG00000288724  ENSG00000288725
# ACH-000256              0.0         0.070389
# ACH-000713              0.0         0.000000
# ACH-000116              0.0         0.097611
# ACH-000520              0.0         0.137504
# ACH-000542              0.0         0.000000
#
# [5 rows x 53970 columns]

# %%
rna_seq_df = rna_seq_df[g_ensembl_2_final]
rna_seq_df
# Out:
#             ENSG00000001036  ENSG00000001084  ENSG00000001626  \
# ACH-000256         4.849499         3.214125         2.353323
# ACH-000713         6.684819         6.358080         0.014355
# ACH-000116         6.507636         4.698774         0.321928
# ACH-000520         6.094869         5.290203         0.014355
# ACH-000542         6.115824         4.336997         0.014355
#
#             ENSG00000001630  ENSG00000002549  ENSG00000002587  \
# ACH-000256         5.859970         5.568640         0.000000
# ACH-000713         6.581653         5.732269         0.310340
# ACH-000116         5.955592         5.128046         0.378512
# ACH-000520         4.815575         5.593354         0.056584
# ACH-000542         4.828327         5.318317         0.097611
#
#             ENSG00000002726  ENSG00000003987  ENSG00000003989  \
# ACH-000256         0.000000         1.117695         2.424922
# ACH-000713         0.687061         2.169925         2.182692
# ACH-000116         0.495695         1.137504         0.298658
# ACH-000520         0.028569         0.333424         3.415488
# ACH-000542         0.014355         0.344828         2.594549
#
#             ENSG00000004455  ...  ENSG00000268104  ENSG00000272333  \
# ACH-000256         7.401562  ...         0.028569         4.731726
# ACH-000713         7.047451  ...         0.070389         3.691534
# ACH-000116         8.079271  ...         0.070389         4.426936
# ACH-000520         7.963359  ...         0.000000         4.204767
# ACH-000542         7.572965  ...         0.000000         2.737687
#
#             ENSG00000274276  ENSG00000276293  ENSG00000277893  \
# ACH-000256         1.189034         3.975447         0.000000
# ACH-000713         0.584963         3.244887         0.070389
# ACH-000116         1.395063         4.671859         0.000000
# ACH-000520         0.678072         4.408712         0.028569
# ACH-000542         3.965323         3.523562         0.000000
#
#             ENSG00000284762  ENSG00000284922  ENSG00000286112  \
# ACH-000256         0.000000         0.687061         0.201634
# ACH-000713         0.000000         0.344828         0.344828
# ACH-000116         0.111031         1.748461         0.286881
# ACH-000520         0.042644         0.526069         0.042644
# ACH-000542         0.000000         1.014355         0.356144
#
#             ENSG00000288702  ENSG00000288705
# ACH-000256         0.111031         0.000000
# ACH-000713         0.000000         0.000000
# ACH-000116         0.000000         0.000000
# ACH-000520         0.000000         0.238787
# ACH-000542         0.000000         0.000000
#
# [5 rows x 1803 columns]

# %%
new_columns = []
for column in rna_seq_df.columns:
    new_columns.append(result_df_genes.loc[result_df_genes['ensembl_id']==column, 'recon_id'].values[0])
rna_seq_df.columns = new_columns
rna_seq_df
# Out:
#             2519_AT1  2729_AT1  1080_AT1  1595_AT1  51056_AT1  9957_AT1  \
# ACH-000256  4.849499  3.214125  2.353323  5.859970   5.568640  0.000000
# ACH-000713  6.684819  6.358080  0.014355  6.581653   5.732269  0.310340
# ACH-000116  6.507636  4.698774  0.321928  5.955592   5.128046  0.378512
# ACH-000520  6.094869  5.290203  0.014355  4.815575   5.593354  0.056584
# ACH-000542  6.115824  4.336997  0.014355  4.828327   5.318317  0.097611
#
#               26_AT1  9108_AT1  6542_AT1   204_AT1  ...  11254_AT1  9757_AT1  \
# ACH-000256  0.000000  1.117695  2.424922  7.401562  ...   0.028569  4.731726
# ACH-000713  0.687061  2.169925  2.182692  7.047451  ...   0.070389  3.691534
# ACH-000116  0.495695  1.137504  0.298658  8.079271  ...   0.070389  4.426936
# ACH-000520  0.028569  0.333424  3.415488  7.963359  ...   0.000000  4.204767
# ACH-000542  0.014355  0.344828  2.594549  7.572965  ...   0.000000  2.737687
#
#             102724560_AT1  8396_AT2  6716_AT1  8622_AT1  220074_AT1   883_AT1  \
# ACH-000256       1.189034  3.975447  0.000000  0.000000    0.687061  0.201634
# ACH-000713       0.584963  3.244887  0.070389  0.000000    0.344828  0.344828
# ACH-000116       1.395063  4.671859  0.000000  0.111031    1.748461  0.286881
# ACH-000520       0.678072  4.408712  0.028569  0.042644    0.526069  0.042644
# ACH-000542       3.965323  3.523562  0.000000  0.000000    1.014355  0.356144
#
#             54659_AT1  54579_AT1
# ACH-000256   0.111031   0.000000
# ACH-000713   0.000000   0.000000
# ACH-000116   0.000000   0.000000
# ACH-000520   0.000000   0.238787
# ACH-000542   0.000000   0.000000
#
# [5 rows x 1803 columns]

# %%
high_grade_ids = ['ACH-000256', 'ACH-000713', 'ACH-000116'] #COV318, CAOV3, OAW28
low_grade_ids = ['ACH-000520', 'ACH-000542'] #59M, HEYA8

# %%
#convert df_rnaseq in adata object
import scanpy as sc
adata_rnaseq = sc.AnnData(rna_seq_df)
adata_rnaseq
# Out:
# AnnData object with n_obs × n_vars = 5 × 1803

# %%
from ras import RAS_computation

# %%
obj_ras = RAS_computation(adata_rnaseq, model)

# %%
ras_adata = obj_ras.compute()
ras_adata
# Out:
# 100%|#########################################################################|
# AnnData object with n_obs × n_vars = 5 × 5792
#     var: 'common_gprs', 'compartments', 'GPR rule'

# %%
ras_adata.X
# Out:
# array([[2.64698205e+01, 8.54572322e+01, 1.19215512e+02, ...,
#         8.46232534e-01, 8.31877241e-01, 3.33127527e+00],
#        [2.97407217e+01, 1.01163855e+02, 1.25607499e+02, ...,
#         2.31678162e-01, 3.52984458e-01, 3.29786638e+00],
#        [2.99562489e+01, 1.05270791e+02, 1.27082843e+02, ...,
#         2.89362340e-01, 6.53518671e-01, 4.46453105e+00],
#        [2.90355416e+01, 9.32068895e+01, 1.23670373e+02, ...,
#         1.43552930e-02, 7.09388213e-02, 3.19175213e+00],
#        [2.90771338e+01, 8.50050119e+01, 1.29234083e+02, ...,
#         2.50961574e-01, 3.48572370e-01, 2.45948408e+00]])

# %%
ras_matrix=ras_adata.to_df().T
ras_matrix=ras_matrix.T
ras_matrix=ras_matrix.div(ras_matrix.max(axis=0)).T
ras_matrix.fillna(0,inplace=True)
ras_matrix
# Out:
#            ACH-000256  ACH-000713  ACH-000116  ACH-000520  ACH-000542
# REACTIONS
# PDHm         0.883616    0.992805    1.000000    0.969265    0.970653
# ATPasel_1    0.811785    0.960987    1.000000    0.885401    0.807489
# ATPS4mi      0.922477    0.971938    0.983354    0.956949    1.000000
# ACACT4m      0.860846    0.891944    1.000000    0.892040    0.854016
# ACACT5m      0.860846    0.891944    1.000000    0.892040    0.854016
# ...               ...         ...         ...         ...         ...
# XYLK         0.769155    0.517443    1.000000    0.800897    0.990697
# S3T3g        0.034543    0.337036    0.107597    1.000000    0.013078
# S3T2g        1.000000    0.273776    0.341942    0.016964    0.296563
# S3T1g        1.000000    0.424323    0.785595    0.085276    0.419019
# ASCBt4       0.746165    0.738681    1.000000    0.714913    0.550894
#
# [5792 rows x 5 columns]

# %%
def integrate_rnaseq(model, cell_name, ras_matrix, biomass_target):

    print('Integrating RNA-seq for cell line:', cell_name)

    reactions = [reaction.id for reaction in model.reactions]
    ras_rxns = []
    original_lb_list = []
    original_ub_list = []
    data_lb_list = []
    data_ub_list = []
 
    for rxn_id in reactions:
        if rxn_id in ras_matrix.index:
            ras_coeff = ras_matrix.loc[rxn_id, cell_name]
            ras_rxns.append(rxn_id)

            lower_bound=model.reactions.get_by_id(rxn_id).lower_bound
            upper_bound=model.reactions.get_by_id(rxn_id).upper_bound
            original_lb_list.append(lower_bound)
            original_ub_list.append(upper_bound)

            if(lower_bound>0 and upper_bound>0):
                data_ub=(float((upper_bound-lower_bound))*ras_coeff)+lower_bound
                data_lb=lower_bound
            elif(lower_bound<0 and upper_bound<0):
                data_lb=(float((lower_bound-upper_bound))*ras_coeff)+upper_bound
                data_ub=upper_bound
            else:
                data_lb=float(lower_bound)*ras_coeff
                data_ub=float(upper_bound)*ras_coeff

            data_lb_list.append(data_lb)
            data_ub_list.append(data_ub)

    #iterate again to set new bounds only if biomass ub is still respecteed
    for i in range(len(ras_rxns)):
        rxn_id = ras_rxns[i]
        data_lb = data_lb_list[i]
        data_ub = data_ub_list[i]

        model.reactions.get_by_id(rxn_id).bounds = (data_lb, data_ub)
        if np.abs(model.slim_optimize() - biomass_target) > 1e-6:
            #infeasible, restore original bounds
            model.reactions.get_by_id(rxn_id).bounds = (original_lb_list[i], original_ub_list[i])
            print(f'Restored original bounds for reaction {rxn_id} due to infeasibility.')
        else:
            print(f'Set new bounds for reaction {rxn_id}: ({data_lb}, {data_ub}) from original ({original_lb_list[i]}, {original_ub_list[i]})')

# %% [markdown]
# ## High grade

# %%
model = load_json_model('./data/Recon3D.json')
model.solver = 'gurobi' #you can use cplex or glpk as you whish, but gurobi and cplex are usually faster
model

# %%
df_fva_HG_min_sum = pd.read_csv('./data/fva_exoflux_HG_min_sum.csv', index_col=0)
df_fva_HG_min_sum
# Out:
#                           minimum       maximum
# 24_25DHVITD3tm       0.000000e+00  1.000000e+02
# 25HVITD3t            0.000000e+00  1.000000e+02
# COAtl                0.000000e+00  1.000000e+03
# EX_5adtststerone_e  -1.000000e-07  1.000000e+02
# EX_5adtststerones_e -1.000000e-07  1.000000e+02
# ...                           ...           ...
# ACMPGLUTTRsc         0.000000e+00  3.500001e-07
# FVSCOAhc             0.000000e+00  3.500001e-07
# MDZGLChr             0.000000e+00  3.500001e-07
# TMACMPhr             0.000000e+00  3.500001e-07
# CYSACMPitr           0.000000e+00  3.500001e-07
#
# [10600 rows x 2 columns]

# %%
df_fva_HG_min_sum.loc[df_fva_HG_min_sum['minimum'] > df_fva_HG_min_sum['maximum']]
# Out:
#                      minimum       maximum
# EX_gmp_e        1.000000e-07  9.999991e-08
# MK10t           5.340757e-13  0.000000e+00
# EX_s2l2n2m2m_e  4.547474e-13  0.000000e+00

# %%
df_fva_HG_min_sum.loc['EX_gmp_e'] = [0,0]
df_fva_HG_min_sum.loc['MK10t'] = [0,0]
df_fva_HG_min_sum.loc['EX_s2l2n2m2m_e'] = [0,0]

# %%
for index, row in df_fva_HG_min_sum.iterrows():
    model.reactions.get_by_id(index).bounds = (row['minimum'], row['maximum'])

# %%
model.reactions.get_by_id('BIOMASS_reaction').bounds
# Out:
# (np.float64(0.0086711140648624), np.float64(0.0224804490992414))

# %%
model.objective = 'BIOMASS_reaction'

# %%
sol = model.optimize()

# %%
sol.objective_value
# Out:
# 0.0224804490992414

# %%
biomass_target = sol.objective_value
biomass_target
# Out:
# 0.0224804490992414

# %%
for cell_name in ['ACH-000256', 'ACH-000713', 'ACH-000116']: #COV318, CAOV3, OAW28
    print("***********************************************")
    print("Processing cell line:", cell_name)
    print("***********************************************")
    #reset model
    for index, row in df_fva_HG_min_sum.iterrows():
        model.reactions.get_by_id(index).bounds = (row['minimum'], row['maximum'])
    integrate_rnaseq(model, cell_name, ras_matrix, biomass_target)
    #compute variability analysis
    df_var = flux_variability_analysis(model, fraction_of_optimum=0.0)
    df_var.to_csv(f'./data/fva_rnaseq_{cell_name}_HG.csv')
# Out:
# ***********************************************
# Processing cell line: ACH-000256
# ***********************************************
# Integrating RNA-seq for cell line: ACH-000256
# Set new bounds for reaction 24_25VITD3Hm: (0.0, 14.484895518115279) from original (0.0, 100.0)
# Set new bounds for reaction 13DAMPPOX: (0.0, 624.9868107505508) from original (0.0, 922.0872647447684)
# Set new bounds for reaction 25VITD2Hm: (0.0, 386.75424605896035) from original (0.0, 799.9997537356364)
# Set new bounds for reaction 2AMACHYD: (0.0, 31.103958344576608) from original (0.0, 1000.0)
# Set new bounds for reaction 2AMACSULT: (0.0, 738.3239423707793) from original (0.0, 1000.0)
# Set new bounds for reaction 2AMADPTm: (0.0, 82.24780858389389) from original (0.0, 1000.0)
# Set new bounds for reaction 2OXOADOXm: (0.0, 863.7132683028937) from original (0.0, 1000.0)
# Set new bounds for reaction 2OXOADPTm: (-82.24780858389389, 82.24780858389389) from original (-1000.0, 1000.0)
# Set new bounds for reaction 34DHPHEt: (-301.03380843415476, 4.5155071265123214e-08) from original (-1000.0, 1.5e-07)
# Set new bounds for reaction 34DHXMANDACOX: (0.0, 458.82147147965065) from original (0.0, 1000.0)
# Set new bounds for reaction 3AIBtm: (0.0, 4.416153006610177e-06) from original (0.0, 1.351217979236835e-05)
# Set new bounds for reaction 3HAO: (1e-07, 295.56158101938155) from original (1e-07, 666.6665026404241)
# Set new bounds for reaction 3MOXTYROX: (0.0, 43.999062952604426) from original (0.0, 100.0)
# Set new bounds for reaction 42A12BOOX: (0.0, 589.6180186427706) from original (0.0, 1000.0)
# Set new bounds for reaction 4HOXPACDOX_NADP: (-430.11401854038934, 43.01140185403894) from original (-1000.0, 100.0)
# Set new bounds for reaction 4NPHSULT: (0.0, 3.8407557329223254e-08) from original (0.0, 1.5000003435852706e-07)
# Set new bounds for reaction 5ADTSTSTERONESULT: (0.0, 738.3239423707793) from original (0.0, 1000.0)
# Set new bounds for reaction 5FTHFt2_1: (0.0, 1.1429642936054832e-07) from original (0.0, 1.499999206716893e-07)
# Set new bounds for reaction 5HOXINOXDA: (0.0, 87.99814562305266) from original (0.0, 200.00004481423576)
# Set new bounds for reaction A4GALTc: (0.0, 346.23604504537764) from original (0.0, 1000.0)
# Set new bounds for reaction A4GALTg: (0.0, 86.55901128298416) from original (0.0, 250.0000000625)
# Set new bounds for reaction A4GNT2g: (0.0, 0.0) from original (0.0, 2.4999999997943334e-07)
# Set new bounds for reaction ABTArm: (-326.82757885625614, 326.82757885625614) from original (-1000.0, 1000.0)
# Set new bounds for reaction ABUTt2rL: (-728.8422380049005, 728.8422380049005) from original (-1000.0, 1000.0)
# Set new bounds for reaction ACACT10m: (-177.6699732796659, 621.8450364923879) from original (-200.00000005, 700.0001465290011)
# Set new bounds for reaction ACACT5p: (0.0, 517.4637436635129) from original (0.0, 670.0000000333333)
# Set new bounds for reaction ACACT8p: (0.0, 772.3339457280126) from original (0.0, 1000.0)
# Set new bounds for reaction ACACT9p: (0.0, 772.3339457280126) from original (0.0, 1000.0)
# Set new bounds for reaction ACCOALm: (0.0, 503.4929845048583) from original (0.0, 1000.0)
# Set new bounds for reaction ACCOAtr: (-613.8614194742324, 613.8614194742324) from original (-1000.0, 1000.0)
# Set new bounds for reaction ACETONEt2: (-68.72158065964999, 687.2158065964999) from original (-100.0, 1000.0)
# Set new bounds for reaction ACGAMK: (0.0, 937.037563229841) from original (0.0, 1000.0)
# Set new bounds for reaction ACGAMPM: (0.0, 742.5771656219789) from original (0.0, 1000.0)
# Set new bounds for reaction ACHVESSEC_1: (0.0, 436.88135823440547) from original (0.0, 1000.0)
# Set new bounds for reaction ACNAMlt: (-691.2300680162808, 0.0) from original (-1000.0, 0.0)
# Set new bounds for reaction ACOAD10m: (0.0, 669.8279133875354) from original (0.0, 900.0001466790011)
# Set new bounds for reaction ACOAD8m: (0.0, 834.8828349852478) from original (0.0, 1000.0)
# Set new bounds for reaction ACOAD9m: (0.0, 855.3966949559598) from original (0.0, 1000.0)
# Set new bounds for reaction ACOAO7p: (0.0, 673.3689948641506) from original (0.0, 1000.0)
# Set new bounds for reaction ACODA: (0.0, 3.4308989219464543e-07) from original (0.0, 4.999999987376214e-07)
# Set new bounds for reaction ACONTm: (-696.9001722550114, 696.9001722550114) from original (-1000.0, 1000.0)
# Set new bounds for reaction ACP1_FMN: (0.0, 919.4442209500345) from original (0.0, 1000.0)
# Set new bounds for reaction ACS2: (0.0, 733.6197728280702) from original (0.0, 999.9999999)
# Set new bounds for reaction ACSRTNMT: (0.0, 0.0) from original (0.0, 300.0)
# Set new bounds for reaction ADEt: (-1.087758329286531e-05, 68.20830919693218) from original (-1.5947592617465105e-05, 99.9999999)
# Set new bounds for reaction ADK3: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADK3m: (-581.8575963311217, 581.8575963311217) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADKd: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADMDC: (0.0, 765.3271615016897) from original (0.0, 999.9999955343447)
# Set new bounds for reaction ADNt4: (0.0, 854.4684755052335) from original (0.0, 1000.0)
# Set new bounds for reaction ADNtl: (0.0, 350.85940200735644) from original (0.0, 1000.0)
# Set new bounds for reaction ADNtm: (-552.4618081551655, 552.4618081551655) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADPMAN: (0.0, 3.7205250024943237e-07) from original (0.0, 5e-07)
# Set new bounds for reaction ADPRIBt: (0.0, 5e-07) from original (0.0, 5e-07)
# Set new bounds for reaction ADRNCRNt: (-807.3734827323149, 807.3734827323149) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADSL2r: (0.0, 544.5483710179332) from original (0.0, 649.4908879429782)
# Set new bounds for reaction AG13T16g: (0.0, 20.668692373485516) from original (0.0, 38.46153846923076)
# Set new bounds for reaction AG13T18g: (0.0, 20.668692373485516) from original (0.0, 38.46153846923076)
# Set new bounds for reaction AG13T2g: (0.0, 22.39108340460932) from original (0.0, 41.66666667500001)
# Set new bounds for reaction AGMTm: (0.0, 77.03341798644362) from original (0.0, 100.00000010000004)
# Set new bounds for reaction AGTim: (0.0, 65.7330603329644) from original (0.0, 1000.0)
# Set new bounds for reaction AHANDROSTANGLCte: (0.0, 3.9939253999185e-07) from original (0.0, 5e-07)
# Set new bounds for reaction AHEXASE2ly: (0.0, 3.8966949203832817e-07) from original (0.0, 5.000000555810402e-07)
# Set new bounds for reaction AIRCr: (0.0, 529.843460416054) from original (0.0, 649.4908879225962)
# Set new bounds for reaction AKGMALtm: (-731.4190860296978, 731.4190860296978) from original (-1000.0, 1000.0)
# Set new bounds for reaction AKGt4_3: (-539.8998650304796, 539.8998650304796) from original (-1000.0, 1000.0)
# Set new bounds for reaction AKR1C41: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction AKR1D: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ALAGLYexR: (-799.4903909093603, 799.4903909093603) from original (-1000.0, 1000.0)
# Set new bounds for reaction ALASERNaEx: (0.0, 540.757143223241) from original (0.0, 1000.0)
# Set new bounds for reaction ALASm: (0.0, 750.0152400545905) from original (0.0, 1000.0)
# Set new bounds for reaction ALATHRNaEx: (0.0, 540.757143223241) from original (0.0, 1000.0)
# Set new bounds for reaction ALCD21_D: (0.0, 682.1894050305643) from original (0.0, 1000.0)
# Set new bounds for reaction ALCD22_D: (0.0, 682.1894050305643) from original (0.0, 1000.0)
# Set new bounds for reaction ALCD2y: (0.0, 4.5785047797069375e-07) from original (0.0, 5e-07)
# Set new bounds for reaction ALDD20xm: (0.0, 69.47685315652862) from original (0.0, 100.0)
# Set new bounds for reaction ALDD2xm: (0.0, 737.8261971590423) from original (0.0, 1000.0)
# Set new bounds for reaction ALDD2y: (0.0, 762.232602405355) from original (0.0, 1000.0)
# Set new bounds for reaction ALOX15: (0.0, 20.138367820461717) from original (0.0, 500.0)
# Set new bounds for reaction ALR2: (0.0, 897.0799229441435) from original (0.0, 1000.0)
# Set new bounds for reaction ALR3: (0.0, 897.0799229441435) from original (0.0, 1000.0)
# Set new bounds for reaction AMACR2p: (0.0, 743.7001401656809) from original (0.0, 1000.0)
# Set new bounds for reaction AMACRp: (0.0, 669.3302353830466) from original (0.0, 900.0001468790011)
# Set new bounds for reaction AMETt2m: (-649.4314311481058, 649.4314311481058) from original (-1000.0, 1000.0)
# Set new bounds for reaction AMPDA: (0.0, 909.4352324014202) from original (0.0, 1000.0)
# Set new bounds for reaction AMY2e: (0.0, 5.277211753904199e-07) from original (0.0, 6e-07)
# Set new bounds for reaction ANDRSTRNGLCte: (0.0, 79.87850799837) from original (0.0, 100.0)
# Set new bounds for reaction APRTO2: (0.0, 43.999062952604426) from original (0.0, 100.0)
# Set new bounds for reaction ARABR: (0.0, 5.382479537664861e-07) from original (0.0, 6e-07)
# Set new bounds for reaction ARACHDt2: (-991.5909612786643, 991.5909612786643) from original (-1000.0, 1000.0)
# Set new bounds for reaction ARGDCm: (0.0, 60.16640670037209) from original (0.0, 200.0000006)
# Set new bounds for reaction ARGLYSex: (0.0, 674.9216336647318) from original (0.0, 1000.0)
# Set new bounds for reaction ARGSS: (0.0, 740.237059220795) from original (0.0, 1000.0)
# Set new bounds for reaction ARGt4: (0.0, 405.87334831282317) from original (0.0, 1000.0)
# Set new bounds for reaction ASNCYSNaEx: (0.0, 703.7659106736511) from original (0.0, 1000.0)
# Set new bounds for reaction ASNGLNNaEx: (0.0, 703.7659106736511) from original (0.0, 1000.0)
# Set new bounds for reaction ASNNm: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction ASNS1: (0.0, 660.9773637815085) from original (0.0, 1000.0)
# Set new bounds for reaction ASNt4: (0.0, 751.3412048920551) from original (0.0, 1000.0)
# Set new bounds for reaction ASPGLUm: (0.0, 973.1941629321639) from original (0.0, 1000.0)
# Set new bounds for reaction ASPt6: (0.0, 849.0065496463033) from original (0.0, 1000.0)
# Set new bounds for reaction ASPTAm: (-693.7247638825085, 693.7247638825085) from original (-1000.0, 1000.0)
# Set new bounds for reaction BILGLCURte: (0.0, 798.7850799836999) from original (0.0, 1000.0)
# Set new bounds for reaction BILIRED: (0.0, 64.43372046620931) from original (0.0, 100.00000020000016)
# Set new bounds for reaction ATPasel_1: (0.0, 811.7848378210829) from original (0.0, 1000.0)
# Set new bounds for reaction B3GALT3g: (0.0, 58.52312722202185) from original (0.0, 250.00000015)
# Set new bounds for reaction B3GNT310g: (0.0, 46.49812238856581) from original (0.0, 200.0000000833333)
# Set new bounds for reaction B3GNT315g: (0.0, 15.499374130813555) from original (0.0, 66.66666670000001)
# Set new bounds for reaction B3GNT31g: (0.0, 23.2490611845958) from original (0.0, 100.0)
# Set new bounds for reaction B3GNT34g: (0.0, 23.249061198545235) from original (0.0, 100.00000006)
# Set new bounds for reaction B3GNT37g: (0.0, 23.2490611845958) from original (0.0, 100.0)
# Set new bounds for reaction B3GNT39g: (0.0, 116.24530599272617) from original (0.0, 500.0000003)
# Set new bounds for reaction B3GNT51g: (0.0, 9.518862391426715) from original (0.0, 200.00000008333333)
# Set new bounds for reaction BACCL: (0.0, 586.3656283055349) from original (0.0, 1000.0)
# Set new bounds for reaction BALAVECSEC_1: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction BHMT: (0.0, 374.3111756488706) from original (0.0, 999.999994934345)
# Set new bounds for reaction BILDGLCURt: (-0.0, 0.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction BTNDm: (0.0, 606.9859746077207) from original (0.0, 1000.0)
# Set new bounds for reaction BTNPL: (0.0, 586.3656283055349) from original (0.0, 1000.0)
# Set new bounds for reaction BTNt2m: (0.0, 867.9606839939448) from original (0.0, 1000.0)
# Set new bounds for reaction BTNt3i_1: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction C160CPT1: (-505.952626665873, 505.952626665873) from original (-1000.0, 1000.0)
# Set new bounds for reaction C160CPT2: (-556.696237717268, 556.696237717268) from original (-1000.0, 1000.0)
# Set new bounds for reaction C160CRNt: (-807.3734827323149, 807.3734827323149) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CPT1: (-505.952626665873, 505.952626665873) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CPT12: (-338.98825987456746, 505.952626665873) from original (-670.0000000166666, 1000.0)
# Set new bounds for reaction C161CPT2: (-807.2585256964397, 807.2585256964397) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CRN2t: (-807.3734827323149, 807.3734827323149) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CRNt: (-807.3734827323149, 807.3734827323149) from original (-1000.0, 1000.0)
# Set new bounds for reaction C180CPT1: (-505.952626665873, 505.952626665873) from original (-1000.0, 1000.0)
# Set new bounds for reaction C181CPT1: (-505.952626665873, 505.952626665873) from original (-1000.0, 1000.0)
# Set new bounds for reaction C181CRNt: (-807.3734827323149, 807.3734827323149) from original (-1000.0, 1000.0)
# Set new bounds for reaction C204CPT1: (-505.952626665873, 505.952626665873) from original (-1000.0, 1000.0)
# Set new bounds for reaction C204CPT2: (-807.2585256964397, 807.2585256964397) from original (-1000.0, 1000.0)
# Set new bounds for reaction C226CPT1: (0.0, 505.952626665873) from original (0.0, 1000.0)
# Set new bounds for reaction C226CPT2: (0.0, 807.2585256964397) from original (0.0, 1000.0)
# Set new bounds for reaction C3STDH1r: (0.0, 176.09737560133428) from original (0.0, 204.7437925529652)
# Set new bounds for reaction C4STMO1r: (0.0, 161.86321131436677) from original (0.0, 194.7751268410724)
# Set new bounds for reaction C4STMO2Pr: (0.0, 169.12935782235178) from original (0.0, 196.6422613304036)
# Set new bounds for reaction CAATPS_1: (0.0, 837.7658547828853) from original (0.0, 1000.0)
# Set new bounds for reaction CAt7r: (-244.46976995496888, 244.46976995496888) from original (-1000.0, 1000.0)
# Set new bounds for reaction CATm: (0.0, 425.82309780226234) from original (0.0, 1000.0)
# Set new bounds for reaction CATp: (0.0, 425.82309780226234) from original (0.0, 1000.0)
# Set new bounds for reaction CBL2tm: (0.0, 1.460667199835158e-07) from original (0.0, 2.999995558639057e-07)
# Set new bounds for reaction CBPPer: (0.0, 772.0317342037175) from original (0.0, 999.9990016629896)
# Set new bounds for reaction CBR2: (0.0, 691.8864566544781) from original (0.0, 1000.0)
# Set new bounds for reaction CDIPTr: (-148.84709336965025, 725.3711693751474) from original (-205.20128129419703, 1000.0)
# Set new bounds for reaction CDS: (0.0, 727.4487552901213) from original (0.0, 1000.0)
# Set new bounds for reaction CERT1gt: (-678.0465396778002, 678.0465396778002) from original (-1000.0, 1000.0)
# Set new bounds for reaction CERT1rt: (0.0, 678.0465396778002) from original (0.0, 1000.0)
# Set new bounds for reaction CERT2rt: (-678.0465396778002, 678.0465396778002) from original (-1000.0, 1000.0)
# Set new bounds for reaction CH25H: (0.0, 48.83928826471807) from original (0.0, 1000.0)
# Set new bounds for reaction CHATn: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CHLP: (0.0, 515.0629621918065) from original (0.0, 1000.0)
# Set new bounds for reaction CHOLD2m: (0.0, 71.49419743173499) from original (0.0, 1000.0)
# Set new bounds for reaction CHOLK: (0.0, 790.8969375022092) from original (0.0, 1000.0)
# Set new bounds for reaction CITRtm: (-550.3972009029206, 550.3972009029206) from original (-1000.0, 1000.0)
# Set new bounds for reaction CITtam: (-659.359037171351, 659.359037171351) from original (-1000.0, 1000.0)
# Set new bounds for reaction CK_cho: (0.0, 116.51865835141734) from original (0.0, 999.9999999)
# Set new bounds for reaction CLHCO3tex2: (0.0, 642.3529595208017) from original (0.0, 1000.0)
# Set new bounds for reaction CLOXAtex2: (0.0, 642.3529595208017) from original (0.0, 1000.0)
# Set new bounds for reaction CLPNDCPT1: (0.0, 319.3803519182871) from original (0.0, 631.24556546517)
# Set new bounds for reaction ACNMCT: (0.0, 640.7022676979977) from original (0.0, 1000.0)
# Set new bounds for reaction COAtim: (-670.041545835286, 670.041545835286) from original (-1000.0, 1000.0)
# Set new bounds for reaction COKECBESr: (0.0, 3.786307071636215e-07) from original (0.0, 5.5e-07)
# Set new bounds for reaction COQ3m: (0.0, 95.23616383127485) from original (0.0, 151.62083413599106)
# Set new bounds for reaction COQ6m: (0.0, 121.66366655053497) from original (0.0, 151.62083413599092)
# Set new bounds for reaction COQ7m: (0.0, 117.23466656678856) from original (0.0, 151.62083413599092)
# Set new bounds for reaction CORE3GTg: (0.0, 7.843897283332552) from original (0.0, 38.4615387999997)
# Set new bounds for reaction CORE6GTg: (0.0, 28.62587412868135) from original (0.0, 166.6666667249999)
# Set new bounds for reaction CREATt4_2_r: (-841.6505682637951, 841.6505681796301) from original (-1000.0, 999.9999999)
# Set new bounds for reaction CRNCARtp: (0.0, 722.5455916114389) from original (0.0, 1000.0)
# Set new bounds for reaction CRNt: (-546.2048745772711, 546.2048745772711) from original (-1000.0, 1000.0)
# Set new bounds for reaction CRNtHa: (0.0, 408.94954128052314) from original (0.0, 1000.0)
# Set new bounds for reaction CRNtuNa: (0.0, 546.2048745772711) from original (0.0, 1000.0)
# Set new bounds for reaction CSNAT2m: (-722.5455916114389, 722.5455916114389) from original (-1000.0, 1000.0)
# Set new bounds for reaction CSNAT2x: (-753.8896061018562, 753.8896061018562) from original (-1000.0, 1000.0)
# Set new bounds for reaction CSNATm: (-722.5455916114389, 722.5455916114389) from original (-1000.0, 1000.0)
# Set new bounds for reaction CSNATr: (-722.5455916114389, 722.5455916114389) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSALANaEx: (0.0, 540.757143223241) from original (0.0, 1000.0)
# Set new bounds for reaction CYSASNNaEx: (0.0, 703.7659106736511) from original (0.0, 1000.0)
# Set new bounds for reaction CYSGLYex: (-950.16399615111, 950.16399615111) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSO: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction CYSSERNaEx: (0.0, 540.757143223241) from original (0.0, 1000.0)
# Set new bounds for reaction CYStec: (-320.49814605471647, 320.49814605471647) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSTGLUex: (0.0, 1.4361717166161505e-07) from original (0.0, 4.4999969329801386e-07)
# Set new bounds for reaction CYTD: (0.0, 73.26498054010685) from original (0.0, 1000.0)
# Set new bounds for reaction CYTDn: (0.0, 452.0907232468672) from original (0.0, 1000.0)
# Set new bounds for reaction CYTDt: (-659.0961996849458, 659.0961996849458) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTDtl: (0.0, 350.85940200735644) from original (0.0, 1000.0)
# Set new bounds for reaction CYTK12: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK12n: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK13n: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK14: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK1m: (0.0, 856.9605091735708) from original (0.0, 1000.0)
# Set new bounds for reaction CYTK2n: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK3: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK4: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK5n: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CPK1: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK6n: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK7: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK7n: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK8: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK8n: (-739.5718592268079, 739.5718592268079) from original (-1000.0, 1000.0)
# Set new bounds for reaction DAGK_hs: (0.0, 794.645005738408) from original (0.0, 1000.0)
# Set new bounds for reaction DARGOp: (0.0, 0.0) from original (0.0, 4.999998139965101e-07)
# Set new bounds for reaction DASPO1p: (0.0, 4.1561974611572826e-08) from original (0.0, 4.999998139965101e-07)
# Set new bounds for reaction DCK1n: (-660.1116860351444, 660.1116860351444) from original (-1000.0, 1000.0)
# Set new bounds for reaction DLNLCGCPT2: (0.0, 807.2585256964397) from original (0.0, 1000.0)
# Set new bounds for reaction DCSPTN1CPT1: (0.0, 505.95250221955723) from original (0.0, 999.9997540356364)
# Set new bounds for reaction DCSPTN1CRNt: (-807.3734827323149, 807.3734827323149) from original (-1000.0, 1000.0)
# Set new bounds for reaction DCYTD: (0.0, 73.26498054010685) from original (0.0, 1000.0)
# Set new bounds for reaction DCYTDn: (0.0, 452.0907232468672) from original (0.0, 1000.0)
# Set new bounds for reaction DCYTt: (-682.0830926831965, -1e-07) from original (-1000.0, -1e-07)
# Set new bounds for reaction DESAT18_10: (0.0, 615.0147176265253) from original (0.0, 1000.0)
# Set new bounds for reaction DESAT18_6: (0.0, 615.0147176265253) from original (0.0, 1000.0)
# Set new bounds for reaction DESAT18_12: (0.0, 539.8422349521791) from original (0.0, 877.7712459232631)
# Set new bounds for reaction DESAT24_1: (0.0, 2.1525517230028368e-07) from original (0.0, 3.50000034358527e-07)
# Set new bounds for reaction DGSNt: (-682.0830926514047, 1.36416106396321e-07) from original (-1000.0, 1.999992491619196e-07)
# Set new bounds for reaction DHCRD2: (0.0, 725.0736553721243) from original (0.0, 1000.0)
# Set new bounds for reaction DHDPBMTm: (0.0, 95.23616381431339) from original (0.0, 151.62083410898754)
# Set new bounds for reaction DHEASt: (-365.89424864585095, 365.89424864585095) from original (-1000.0, 1000.0)
# Set new bounds for reaction DHEASULT: (0.0, 897.5425367207431) from original (0.0, 1000.0)
# Set new bounds for reaction DHORD9: (0.0009985370099195, 645.7453592092584) from original (0.0009985370099195, 908.2641523479734)
# Set new bounds for reaction DHPM1: (0.0, 734.7632088016899) from original (0.0, 895.3896164098184)
# Set new bounds for reaction D_LACt2: (-70.21482880390381, 1.755372000843399e-07) from original (-100.0, 2.500001824038918e-07)
# Set new bounds for reaction DLNLCGCPT1: (-505.952626665873, 505.952626665873) from original (-1000.0, 1000.0)
# Set new bounds for reaction DMATTx: (0.0, 510.13041483060346) from original (0.0, 534.4048369157231)
# Set new bounds for reaction DMGDHm: (0.0, 164.00135007371037) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt10m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt11m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt13m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt14m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt15m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt16m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt17m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt18m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt1m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt20m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt21m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt25m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt28m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt32m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt37m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt38m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt39m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt40m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt42m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt43m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt45m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt49m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt50m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt52m: (0.0, 563.2334691156884) from original (0.0, 838.9416066299489)
# Set new bounds for reaction DNDPt55m: (0.0, 560.350941230215) from original (0.0, 834.6480539417686)
# Set new bounds for reaction DNDPt56m: (0.0, 563.2334668455687) from original (0.0, 838.941603248584)
# Set new bounds for reaction DNDPt57m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt59m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt5m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt60m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt61m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt62m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt63m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt6m: (0.0, 671.3619454138322) from original (0.0, 1000.0)
# Set new bounds for reaction DOLPH_Uer: (0.0, 433.2171326442225) from original (0.0, 1000.0)
# Set new bounds for reaction DOLPMT_U: (0.0, 670.2322873803023) from original (0.0, 1000.0)
# Set new bounds for reaction DOPAt4_2_r: (-609.8146758847874, 609.8146758847874) from original (-1000.0, 1000.0)
# Set new bounds for reaction DOPAtu: (-538.27370885887, 538.27370885887) from original (-1000.0, 1000.0)
# Set new bounds for reaction DOPAVESSEC_1: (0.0, 711.4825021281484) from original (0.0, 1000.0)
# Set new bounds for reaction DPGase: (0.0, 786.4463566615312) from original (0.0, 1000.0)
# Set new bounds for reaction DURAD: (-24.862662017998577, 1.2431284339415728e-09) from original (-1000.0, 4.9999812290479895e-08)
# Set new bounds for reaction DURAD2: (-22.398059135350472, 24.862662017998577) from original (-900.8713193758606, 1000.0)
# Set new bounds for reaction DURIK1: (0.0, 680.6376207203432) from original (0.0, 1000.0)
# Set new bounds for reaction DURIt: (-682.0830926831965, -1e-07) from original (-1000.0, -1e-07)
# Set new bounds for reaction DUTPDPm: (0.0, 950.4749199270177) from original (0.0, 1000.0)
# Set new bounds for reaction ECOAH12m: (0.0, 882.9490900978191) from original (0.0, 1000.0)
# Set new bounds for reaction ECOAH9m: (-88.29490914222448, 706.3594014559033) from original (-100.00000015000025, 800.0001465290009)
# Set new bounds for reaction EICOSTETCPT1: (0.0, 505.952626665873) from original (0.0, 1000.0)
# Set new bounds for reaction ESTRIOLGLCte: (0.0, 79.87850799837) from original (0.0, 100.0)
# Set new bounds for reaction ESTRONEGLCt: (0.0, 6.125314727037683) from original (0.0, 100.0)
# Set new bounds for reaction ESTRONESt: (-630.4534023591121, 630.4534023591121) from original (-1000.0, 1000.0)
# Set new bounds for reaction ESTRONESt2: (0.0, 339.8489509027126) from original (0.0, 1000.0)
# Set new bounds for reaction ETF: (0.0, 730.5643576528963) from original (0.0, 933.3323350963236)
# Set new bounds for reaction ETFQO: (0.0, 754.1822834135689) from original (0.0, 933.3323350963234)
# Set new bounds for reaction ETHAK: (0.0, 760.3915869657294) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL140: (0.0, 783.5004571104466) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL160: (0.0, 607.6091048153874) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL170: (0.0, 762.9334686617117) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL181: (0.0, 774.0152280561838) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL1821: (0.0, 774.0152280561838) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL1822: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL1831: (0.0, 607.6091048153874) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL184: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL203: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL204: (0.0, 774.0152280561838) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL2042: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL205: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL2251: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL2252: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL240_1: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL241: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL245_1: (0.0, 361.7311043106063) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL40im: (0.0, 4.9309207665459654e-08) from original (0.0, 2.5e-07)
# Set new bounds for reaction FACOAL80: (0.0, 1.9587511427761165e-07) from original (0.0, 2.5e-07)
# Set new bounds for reaction FAEL184: (0.0, 577.2772881533502) from original (0.0, 1000.0)
# Set new bounds for reaction FAEL204: (0.0, 577.2772881533502) from original (0.0, 1000.0)
# Set new bounds for reaction FAEL205: (0.0, 577.2772881533502) from original (0.0, 1000.0)
# Set new bounds for reaction FAH1: (0.0, 100.0) from original (0.0, 100.0)
# Set new bounds for reaction FAH2: (0.0, 100.0) from original (0.0, 100.0)
# Set new bounds for reaction FALDH: (-850.4213201365219, 850.4213201365219) from original (-1000.0, 1000.0)
# Set new bounds for reaction FAOXC11: (0.0, 0.0) from original (0.0, 0.0)
# Set new bounds for reaction FAOXC16080m: (0.0, 597.5123164847398) from original (0.0, 793.3330836865808)
# Set new bounds for reaction FAOXC16080x: (0.0, 380.91137168636675) from original (0.0, 502.50000003125)
# Set new bounds for reaction FAOXC180x: (0.0, 758.0325804232402) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC1811601m: (0.0, 597.5123165223981) from original (0.0, 793.3330837365808)
# Set new bounds for reaction FAOXC1811603m: (0.0, 597.5123165223982) from original (0.0, 793.3330837365809)
# Set new bounds for reaction FAOXC182806m: (0.0, 753.1670224921526) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC18280m: (0.0, 753.1670224921526) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC183806m: (0.0, 753.1668364505513) from original (0.0, 999.99975298759)
# Set new bounds for reaction FAOXC18480m: (0.0, 753.1670224921526) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC200180x: (0.0, 758.0325804232402) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC2031836m: (0.0, 753.1670224921526) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC204: (0.0, 472.2002389000519) from original (0.0, 626.9528866752419)
# Set new bounds for reaction FAOXC2051843m: (0.0, 753.1670224921526) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC2051843x: (0.0, 647.2431750105757) from original (0.0, 853.8461165471193)
# Set new bounds for reaction FAOXC2251836m: (0.0, 753.1668371083837) from original (0.0, 999.9997538610116)
# Set new bounds for reaction FAOXC2252053m: (0.0, 602.5334697168333) from original (0.0, 799.999803128809)
# Set new bounds for reaction FAOXC2252053x: (0.0, 606.425915103588) from original (0.0, 799.999803128509)
# Set new bounds for reaction FAOXC226205m: (0.0, 753.1670224921526) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC2442246x: (0.0, 1.1370499655808328e-07) from original (0.0, 1.5000014444576667e-07)
# Set new bounds for reaction FAOXC2452253x: (0.0, 1.1370482420142934e-07) from original (0.0, 1.499999170720912e-07)
# Set new bounds for reaction FAOXC2452256x: (0.0, 1.1370482420142934e-07) from original (0.0, 1.499999170720912e-07)
# Set new bounds for reaction FAOXC246226x: (0.0, 1.1370482693004199e-07) from original (0.0, 1.499999206716893e-07)
# Set new bounds for reaction FAOXC260240x_1: (0.0, 758.0325804232402) from original (0.0, 1000.0)
# Set new bounds for reaction FAS160COA: (0.0, 755.9784355344977) from original (0.0, 1000.0)
# Set new bounds for reaction FATP1t: (-622.5831336472212, 622.5831336472212) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP2t: (-654.1300137160969, 654.1300137160969) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP3t: (-654.1300137160969, 654.1300137160969) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP7t: (-606.4794016461728, 606.4794016461728) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP8t: (-606.4794016461728, 606.4794016461728) from original (-1000.0, 1000.0)
# Set new bounds for reaction FBA5: (0.0, 3.655487209826469e-08) from original (0.0, 1.499999312829459e-07)
# Set new bounds for reaction FDH: (0.0, 39.7731110347879) from original (0.0, 1000.0)
# Set new bounds for reaction FE3R2e_1: (0.0, 763.7270747030373) from original (0.0, 1000.0)
# Set new bounds for reaction FK: (0.0, 1.6060530006469474e-07) from original (0.0, 2.4999995673624653e-07)
# Set new bounds for reaction FKYNH: (2e-07, 984.6824446690725) from original (2e-07, 1000.0)
# Set new bounds for reaction FPGS2: (0.0, 664.4484887547171) from original (0.0, 1000.0)
# Set new bounds for reaction FPGS2m: (0.0, 664.4484887547171) from original (0.0, 1000.0)
# Set new bounds for reaction FPGS3: (0.0, 664.4484887547171) from original (0.0, 1000.0)
# Set new bounds for reaction FPGS4_1: (0.0, 166.11212218867928) from original (0.0, 250.0)
# Set new bounds for reaction FPGS4m_1: (0.0, 132.8896977509434) from original (0.0, 200.0)
# Set new bounds for reaction FPGS5: (0.0, 132.8896977509434) from original (0.0, 200.0)
# Set new bounds for reaction FPGS5m: (0.0, 132.8896977509434) from original (0.0, 200.0)
# Set new bounds for reaction FPGS6m: (0.0, 110.74141479245284) from original (0.0, 166.66666666666666)
# Set new bounds for reaction FPGS7m_1: (0.0, 166.11212218867928) from original (0.0, 250.0)
# Set new bounds for reaction FPGS8m: (0.0, 132.8896977509434) from original (0.0, 200.0)
# Set new bounds for reaction FPGS9: (0.0, 110.74141479245284) from original (0.0, 166.66666666666666)
# Set new bounds for reaction FPGSm_1: (0.0, 664.4484887547171) from original (0.0, 1000.0)
# Set new bounds for reaction FRUt1r: (-779.2765379120124, 779.2765379120124) from original (-1000.0, 1000.0)
# Set new bounds for reaction FTHFDH: (0.0, 141.45521316184022) from original (0.0, 1000.0)
# Set new bounds for reaction FTHFLmi: (0.0, 703.4904756166394) from original (0.0, 1000.0)
# Set new bounds for reaction FUCASE2ly: (0.0, 2.5735964194811875e-07) from original (0.0, 4.5e-07)
# Set new bounds for reaction FUCASEe: (0.0, 3.264523100700914e-07) from original (0.0, 4.5e-07)
# Set new bounds for reaction FUMAC: (0.0, 552.2016525321313) from original (0.0, 999.9997540110112)
# Set new bounds for reaction FUMSO4tm: (-584.8038247970627, 584.8038247970627) from original (-1000.0, 1000.0)
# Set new bounds for reaction FUMtm: (-584.8038247970627, 584.8038247970627) from original (-1000.0, 1000.0)
# Set new bounds for reaction FUT15g: (0.0, 8.865604030543645) from original (0.0, 83.33333335833333)
# Set new bounds for reaction FUT16g: (0.0, 9.67156803332034) from original (0.0, 90.90909093636364)
# Set new bounds for reaction FUT32g: (0.0, 13.603795282806121) from original (0.0, 100.0)
# Set new bounds for reaction FUT911g: (0.0, 0.0) from original (0.0, 66.66666669666667)
# Set new bounds for reaction FUT91g: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction FUT94g: (0.0, 0.0) from original (0.0, 90.9090909590909)
# Set new bounds for reaction FUT96g: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction FUT97g: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction FUT99g: (0.0, 0.0) from original (0.0, 66.66666670333333)
# Set new bounds for reaction G14T20g: (0.0, 27.31527726039317) from original (0.0, 38.46153848269231)
# Set new bounds for reaction G14T21g: (0.0, 27.31527726039317) from original (0.0, 38.46153848269231)
# Set new bounds for reaction G14T2g: (0.0, 29.591550365425935) from original (0.0, 41.66666668958334)
# Set new bounds for reaction G14T5g: (0.0, 29.591550365425935) from original (0.0, 41.66666668958334)
# Set new bounds for reaction G5SDym: (0.0, 731.329617598136) from original (0.0, 1000.0)
# Set new bounds for reaction G6PDH1er: (-905.3527834288453, 905.3527834288453) from original (-1000.0, 1000.0)
# Set new bounds for reaction G6PDH2er: (-684.4711326918518, 684.4711326918518) from original (-1000.0, 1000.0)
# Set new bounds for reaction G6PPer: (0.0, 772.0325049523404) from original (0.0, 1000.0)
# Set new bounds for reaction GABAVESSEC_1: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction GACMTRc: (1e-07, 285.17780827579355) from original (1e-07, 1000.0)
# Set new bounds for reaction GALASE10ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE12ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE13ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE15ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE16ly: (0.0, 37.51938575346791) from original (0.0, 41.66666715833333)
# Set new bounds for reaction GALASE17ly: (0.0, 37.51938575346791) from original (0.0, 41.66666715833333)
# Set new bounds for reaction GALASE19ly: (0.0, 150.07754166317383) from original (0.0, 166.6666671333334)
# Set new bounds for reaction GALASE1ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE20ly: (0.0, 34.633279191680586) from original (0.0, 38.46153895384616)
# Set new bounds for reaction GALASE4ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE7ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE8ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALASE9ly: (0.0, 4.5023262372886996e-07) from original (0.0, 5e-07)
# Set new bounds for reaction GALGT2: (0.0, 58.42069048536236) from original (0.0, 166.66666673333333)
# Set new bounds for reaction GALGT3: (0.0, 43.81551787278487) from original (0.0, 125.000000075)
# Set new bounds for reaction GALNACT1g: (0.0, 18.356772734680494) from original (0.0, 71.42857145714285)
# Set new bounds for reaction GALNACT2g: (0.0, 43.573881339570725) from original (0.0, 71.42857145714285)
# Set new bounds for reaction GALNACT3g: (0.0, 43.573881339570725) from original (0.0, 71.42857145714285)
# Set new bounds for reaction GALNACT4g: (0.0, 38.1271461721244) from original (0.0, 62.50000002500002)
# Set new bounds for reaction GALNACT5g: (0.0, 35.88437286788178) from original (0.0, 58.82352943529412)
# Set new bounds for reaction GALt1r: (-628.3516518981667, 628.3516518981667) from original (-1000.0, 1000.0)
# Set new bounds for reaction GALT2g: (0.0, 71.05000324969707) from original (0.0, 71.42857145714285)
# Set new bounds for reaction GAO1g: (0.0, 61.38614194742325) from original (0.0, 100.0)
# Set new bounds for reaction GASNASE2ly: (0.0, 2.1488680641781525e-07) from original (0.0, 3e-07)
# Set new bounds for reaction GASNASEly: (0.0, 2.1488680641781525e-07) from original (0.0, 3e-07)
# Set new bounds for reaction GBA: (0.0, 878.5714513034114) from original (0.0, 1000.0)
# Set new bounds for reaction GBGT1: (0.0, 24.988628072835724) from original (0.0, 166.66666673333333)
# Set new bounds for reaction GCCam: (0.0, 305.4491802970638) from original (0.0, 1000.0)
# Set new bounds for reaction GCHOLAt2: (0.0, 339.8489509027126) from original (0.0, 1000.0)
# Set new bounds for reaction GDPFUCtg: (0.0, 363.9462742392498) from original (0.0, 366.6666667833333)
# Set new bounds for reaction GFUCS: (0.0, 557.4111915974804) from original (0.0, 833.3333353833333)
# Set new bounds for reaction GGH_10FTHF7GLUl: (0.0, 113.88582679071627) from original (0.0, 166.66666666666666)
# Set new bounds for reaction GGH_5THFl: (0.0, 170.8287401860744) from original (0.0, 250.0)
# Set new bounds for reaction GGH_6DHFl: (0.0, 136.66299214885953) from original (0.0, 200.0)
# Set new bounds for reaction GGH_7THFe: (0.0, 2.391602362605042e-07) from original (0.0, 3.5e-07)
# Set new bounds for reaction GGLUCT: (0.0, 694.4741750317875) from original (0.0, 1000.0)
# Set new bounds for reaction GHMT2rm: (0.0, 691.345406907177) from original (0.0, 1000.0)
# Set new bounds for reaction GLAl: (0.0, 700.4728378732699) from original (0.0, 1000.0)
# Set new bounds for reaction GLB1: (0.0, 900.4652474577399) from original (0.0, 1000.0)
# Set new bounds for reaction GLCAASE4ly: (0.0, 58.23328784740652) from original (0.0, 71.42857167857146)
# Set new bounds for reaction GLCAASE6ly: (0.0, 50.954126891957756) from original (0.0, 62.500000250000014)
# Set new bounds for reaction GLCAASE7ly: (0.0, 47.95682532206713) from original (0.0, 58.823529661764766)
# Set new bounds for reaction GLCAASE8ly: (0.0, 432.1238560827423) from original (0.0, 500.0)
# Set new bounds for reaction GLCAASE9ly: (0.0, 407.63301350512995) from original (0.0, 500.0)
# Set new bounds for reaction GLCAT4g: (0.0, 50.7336749045719) from original (0.0, 62.500000009375)
# Set new bounds for reaction GLCAT5g: (0.0, 47.7493410866559) from original (0.0, 58.82352942058824)
# Set new bounds for reaction GLCAT6g: (0.0, 14.24877789581468) from original (0.0, 28.571428575714297)
# Set new bounds for reaction GLCAT7g: (0.0, 14.24877789581468) from original (0.0, 28.571428575714297)
# Set new bounds for reaction GLCAT8g: (0.0, 14.24877789581468) from original (0.0, 28.571428575714297)
# Set new bounds for reaction GLCNACASE5ly: (0.0, 24.605327319958032) from original (0.0, 28.571428721428617)
# Set new bounds for reaction GLCNACDASg: (0.0, 19.853663120616286) from original (0.0, 28.57142857571429)
# Set new bounds for reaction GLCNACT2g: (0.0, 15.419700815280477) from original (0.0, 28.57142857571429)
# Set new bounds for reaction GLCNACT5g: (0.0, 15.419700815280477) from original (0.0, 28.57142857571429)
# Set new bounds for reaction GLGNS1: (0.0, 125.96234990032175) from original (0.0, 181.81818181818184)
# Set new bounds for reaction GLNALANaEx: (0.0, 703.7659106736511) from original (0.0, 1000.0)
# Set new bounds for reaction GLNASNNaEx: (0.0, 703.7659106736511) from original (0.0, 1000.0)
# Set new bounds for reaction GLNCYSNaEx: (0.0, 703.7659106736511) from original (0.0, 1000.0)
# Set new bounds for reaction GLPASE1: (0.0, 495.2251009258805) from original (0.0, 495.2251009258805)
# Set new bounds for reaction GLPASE2: (0.0, 410.9996760888323) from original (0.0, 410.9996760888323)
# Set new bounds for reaction GLUt6: (0.0, 849.0065496463033) from original (0.0, 1000.0)
# Set new bounds for reaction GLXO2p: (0.0, 7.633209753318141e-06) from original (0.0, 2.8885783545767777e-05)
# Set new bounds for reaction GLYAMDTRc: (0.0, 92.43241988242355) from original (0.0, 1000.0)
# Set new bounds for reaction GLYBt4_2_r: (-568.0094149318286, 568.0094148750276) from original (-1000.0, 999.9999999)
# Set new bounds for reaction GLYt4: (0.0, 751.3412048920551) from original (0.0, 1000.0)
# Set new bounds for reaction GLYt7_211_r: (-442.6742517418273, 442.6742517418273) from original (-1000.0, 1000.0)
# Set new bounds for reaction GLYVESSEC_1: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction GNDer: (0.0, 740.1448082571249) from original (0.0, 1000.0)
# Set new bounds for reaction GNMT: (0.0, 413.37099666287065) from original (0.0, 1000.0)
# Set new bounds for reaction GPAM_hs_1: (0.0, 694.1800081226) from original (0.0, 1000.0)
# Set new bounds for reaction GPIDA2er: (0.0, 333.33333333333326) from original (0.0, 333.33333333333326)
# Set new bounds for reaction GPIDAer: (0.0, 333.33333333333337) from original (0.0, 333.33333333333337)
# Set new bounds for reaction GTHOm: (0.0, 655.5150239540679) from original (0.0, 1000.0)
# Set new bounds for reaction GTHPi: (0.0, 824.3835906463476) from original (0.0, 1000.0)
# Set new bounds for reaction GTHPm: (0.0, 891.2610530141958) from original (0.0, 1000.0)
# Set new bounds for reaction GTHS: (0.0, 793.7446340176303) from original (0.0, 1000.0)
# Set new bounds for reaction HCO3Em: (0.0, 768.7547805933771) from original (0.0, 1000.0)
# Set new bounds for reaction H2O2syn: (0.0, 171.315962167347) from original (0.0, 1000.0)
# Set new bounds for reaction H3MTer_U: (0.0, 277.3727163050773) from original (0.0, 333.33333333333326)
# Set new bounds for reaction H4ET3er: (0.0, 257.79629131456875) from original (0.0, 333.33333333333337)
# Set new bounds for reaction H4ETer: (0.0, 188.19937216991843) from original (0.0, 333.33333333333326)
# Set new bounds for reaction H6ET3er: (0.0, 257.79629131456863) from original (0.0, 333.33333333333326)
# Set new bounds for reaction H7ET2er: (0.0, 259.62893672938355) from original (0.0, 333.33333333333326)
# Set new bounds for reaction HACD1x: (-724.5354477375056, 0.0) from original (-1000.0, 0.0)
# Set new bounds for reaction HACD9m: (-166.4371313366142, 582.5300811389756) from original (-200.0000001500001, 700.0001464790012)
# Set new bounds for reaction HAS1: (0.0, 158.0206449990324) from original (0.0, 550.0000000750001)
# Set new bounds for reaction HBZOPT10m: (0.0, 77.8485814747444) from original (0.0, 151.62083411809252)
# Set new bounds for reaction HCO3_CLt: (-833.766387292174, 833.766387292174) from original (-1000.0, 1000.0)
# Set new bounds for reaction HDCAt: (-991.5909612786643, 991.5909612786643) from original (-1000.0, 1000.0)
# Set new bounds for reaction HEX4: (0.0, 1.6392176321693034e-07) from original (0.0, 2.999999821895472e-07)
# Set new bounds for reaction HISDC: (0.0, 428.8087197837317) from original (0.0, 999.9989041191556)
# Set new bounds for reaction HISt4: (0.0, 699.1161374314026) from original (0.0, 1000.0)
# Set new bounds for reaction HISTAVESSEC_1: (0.0, 711.4825021281484) from original (0.0, 1000.0)
# Set new bounds for reaction HMGCOASm: (-95.34619961728377, 0.0) from original (-1000.0, 0.0)
# Set new bounds for reaction HMGLm: (0.0, 665.4437196881743) from original (0.0, 1000.0)
# Set new bounds for reaction HMGLx: (0.0, 921.3028126012977) from original (0.0, 1000.0)
# Set new bounds for reaction HOMt4: (0.0, 655.1231327586133) from original (0.0, 1000.0)
# Set new bounds for reaction HPDCACRNCPT1: (-505.952626665873, 2.5297666100867663e-08) from original (-1000.0, 5.000006871705409e-08)
# Set new bounds for reaction HPDCACRNCPT2: (-807.2585256964397, 4.036298175724976e-08) from original (-1000.0, 5.000006871705409e-08)
# Set new bounds for reaction HPYRR2x_1: (0.0, 36.130499255714135) from original (0.0, 50.0)
# Set new bounds for reaction HS2ly: (0.0, 22.593759831372058) from original (0.0, 28.571428821428604)
# Set new bounds for reaction HSD17B42x_1: (0.0, 792.259549746197) from original (0.0, 1000.0)
# Set new bounds for reaction HSD17B4x: (0.0, 713.0337108209648) from original (0.0, 900.0001464790012)
# Set new bounds for reaction HSD17B7r: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HSD17B8r: (0.0, 35.13138815817421) from original (0.0, 1000.0)
# Set new bounds for reaction HSD17B9r: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HSD3A1r: (-0.0, 0.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction HSD3B11: (0.0, 100.0) from original (0.0, 100.0)
# ...
# Set new bounds for reaction r2269: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2270: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2271: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2272: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2274: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2279: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2280: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2281: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2284: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2285: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2286: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2287: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2288: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2290: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2291: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2292: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2295: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2296: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2298: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2302: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2303: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2304: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2305: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2306: (0.0, 198.66788975274278) from original (0.0, 1000.0)
# Set new bounds for reaction r2308: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2311: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2312: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2314: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2316: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2318: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2319: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2320: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2322: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2323: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2326: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2327: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2328: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2329: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2330: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2338: (-398.57180534405285, 398.57180534405285) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE0565C: (0.0, 668.9797104885522) from original (0.0, 1000.0)
# Set new bounds for reaction RE0577C: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction RE0578C: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE0579C_1: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction RE0688E: (0.0, 144.29443309346962) from original (0.0, 200.0)
# Set new bounds for reaction RE0827E: (0.0, 72.14721654673481) from original (0.0, 100.0)
# Set new bounds for reaction RE0828E: (0.0, 144.29443309346962) from original (0.0, 200.0)
# Set new bounds for reaction RE0830N: (-950.7736331998719, 950.7736331998719) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE0915E: (-1.056539465258668e-13, 3.7026578390934984e-07) from original (-1.5694043287162176e-13, 5.500000171792635e-07)
# Set new bounds for reaction RE0926E: (0.0, 3.7026578390934984e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction RE0935E: (0.0, 3.7026578390934984e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction RE0936E: (0.0, 5.500000171792635e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction RE0937E: (0.0, 5.500000171792635e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction RE0938E: (0.0, 5.500000171792635e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction RE0944E: (0.0, 3.7026578390934984e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction RE0958E: (2.297108949368985e-13, 3.702658589764595e-07) from original (2.297108949368985e-13, 5.500000171792635e-07)
# Set new bounds for reaction RE1099C: (-95.82007630041419, 958.2007630041419) from original (-100.0, 1000.0)
# Set new bounds for reaction STS4r: (-958.2007630041419, 958.2007630041419) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE1447M_1: (0.0, 740.4693793547906) from original (0.0, 1000.0)
# Set new bounds for reaction RE1448R_1: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction RE1516M: (0.0, 915.2080837865808) from original (0.0, 915.2080837865808)
# Set new bounds for reaction RE3038C: (-100.0, 100.0) from original (-100.0, 100.0)
# Set new bounds for reaction RE3040C: (-1.0000003669574653e-07, 100.0) from original (-1.0000003669574653e-07, 100.0)
# Set new bounds for reaction RE3074X: (0.0, 838.6983042039652) from original (0.0, 1000.0)
# Set new bounds for reaction RE3082X: (0.0, 1.852076824946404e-07) from original (0.0, 5.499999815583578e-07)
# Set new bounds for reaction RE3086X: (0.0, 4.0305962629418326e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction RE3095C: (0.0, 928.4386019602379) from original (0.0, 1000.0)
# Set new bounds for reaction RE3132R: (0.0, 838.6983042039652) from original (0.0, 1000.0)
# Set new bounds for reaction RE3134C: (-166.2290151813289, 0.0) from original (-166.2290151813289, 0.0)
# Set new bounds for reaction CHLSTD78I: (0.0, 157.95951897598667) from original (0.0, 168.50183614353173)
# Set new bounds for reaction RE3151C: (0.0, 668.9797104885522) from original (0.0, 1000.0)
# Set new bounds for reaction RE3157X: (0.0, 1.8320901899992874e-07) from original (0.0, 2.500001414773579e-07)
# Set new bounds for reaction RE3158X: (0.0, 2.500001414773579e-07) from original (0.0, 2.500001414773579e-07)
# Set new bounds for reaction RE3159X: (0.0, 2.0630968582124209e-07) from original (0.0, 2.500001414773579e-07)
# Set new bounds for reaction RE3160R: (0.0, 838.6983042039652) from original (0.0, 1000.0)
# Set new bounds for reaction RE3161C: (0.0, 568.5299124491845) from original (0.0, 849.8462711731426)
# Set new bounds for reaction RE3177M: (0.0, 3.178115471755285e-07) from original (0.0, 4.000000899395673e-07)
# Set new bounds for reaction FAOXC122x: (0.0, 484.78729419979794) from original (0.0, 499.9998770555057)
# Set new bounds for reaction FAOXC123C102m: (0.0, 634.6664670392646) from original (0.0, 634.6664670392646)
# Set new bounds for reaction FAOXC123x: (0.0, 389.76908043473696) from original (0.0, 402.00000006)
# Set new bounds for reaction FAOXC120100m: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC12C12OHm: (0.0, 832.7519862884475) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC12DCTc: (-1000.0, 5.00000034358527e-07) from original (-1000.0, 5.00000034358527e-07)
# Set new bounds for reaction FAOXC141C121m: (0.0, 892.4165009823698) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC141C121x: (0.0, 21.214319528364758) from original (0.0, 335.0000000416667)
# Set new bounds for reaction FAOXC142C142OHm: (0.0, 3.549589099914899e-07) from original (0.0, 4.000000899395673e-07)
# Set new bounds for reaction FAOXC140120x: (0.0, 42.428639056729516) from original (0.0, 670.0000000833334)
# Set new bounds for reaction FAOXC14DCC12DCx: (0.0, 35.51891968693962) from original (0.0, 560.8870970711694)
# Set new bounds for reaction FAOXC15C13m: (0.0, 4.4620825578929886e-07) from original (0.0, 5.000000059368176e-07)
# Set new bounds for reaction FAOXC15NADPx: (0.0, 5.000000271593308e-07) from original (0.0, 5.000000271593308e-07)
# Set new bounds for reaction FAOXC162C142m: (0.0, 816.7467957924448) from original (0.0, 915.2080837740808)
# Set new bounds for reaction FAOXC163C143m: (0.0, 566.3868277346297) from original (0.0, 634.6664669592647)
# Set new bounds for reaction FAOXC163GC142m: (0.0, 816.746795747824) from original (0.0, 915.2080837240808)
# Set new bounds for reaction FAOXC164GC163m: (0.0, 562.7579075567868) from original (0.0, 915.2080837240808)
# Set new bounds for reaction FAOXC16Brx: (0.0, 499.23928318444445) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC160140m: (0.0, 892.4165009823698) from original (0.0, 1000.0)
# Set new bounds for reaction ALAB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ARGB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ASNB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction BETBGTtc: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ESTROSABCCte: (0.0, 629.704891353689) from original (0.0, 1000.0)
# Set new bounds for reaction FOLOAT1tc: (-0.0, 0.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction FOLOATPtc: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction GLNB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction GSNt2: (-707.8299461136443, 707.8299461136443) from original (-1000.0, 1000.0)
# Set new bounds for reaction LEUKABCtc: (0.0, 302.2320557356294) from original (0.0, 1000.0)
# Set new bounds for reaction PHEB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction PSHSABCtc: (0.0, 565.2480266129821) from original (0.0, 1000.0)
# Set new bounds for reaction THCHOLSTOICt: (-1000.0, 100.0) from original (-1000.0, 100.0)
# Set new bounds for reaction XOL7AH3ATP: (0.0, 283.593783014137) from original (0.0, 1000.0)
# Set new bounds for reaction XOL7AH3t: (-1000.0, 100.0) from original (-1000.0, 100.0)
# Set new bounds for reaction XOL7AONEt: (-1000.0, 100.0) from original (-1000.0, 100.0)
# Set new bounds for reaction XOLDIOLONEATP: (0.0, 28.359378301413702) from original (0.0, 100.0)
# Set new bounds for reaction 7KILTCHOLt: (-1000.0, 100.0) from original (-1000.0, 100.0)
# Set new bounds for reaction ACACt2: (-633.6495292477051, 633.6495292477051) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADK1: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADPT: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction ADSS: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction ALAR: (-1.500000343116426e-07, 1000.0) from original (-1.500000343116426e-07, 1000.0)
# Set new bounds for reaction PHPYRte: (-60.926901853039226, 1.523174447291711e-07) from original (-100.0, 2.500003120076144e-07)
# Set new bounds for reaction CE4970te: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction CE2026te: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction VANILPYRc: (0.0, 100.0) from original (0.0, 100.0)
# Set new bounds for reaction HMR_0614: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0625: (0.0, 921.3827057767973) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0634: (0.0, 829.5525676373637) from original (0.0, 842.7733208036897)
# Set new bounds for reaction HMR_0642: (0.0, 970.2035497169231) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0678: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0750: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0758: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0761: (0.0, 692.2295116596302) from original (0.0, 1000.0)
# Set new bounds for reaction SBPP3: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0793: (0.0, 999.9998487268996) from original (0.0, 999.9998487268996)
# Set new bounds for reaction HMR_0795: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_2736: (0.0, 451.1082828582475) from original (0.0, 451.1082828582475)
# Set new bounds for reaction HMR_2738: (-328.79341390014633, 0.0) from original (-451.1082828457224, 0.0)
# Set new bounds for reaction HMR_2739: (0.0, 525.0416370925864) from original (0.0, 525.0416370925864)
# Set new bounds for reaction HMR_2740: (0.0, 438.5008015981077) from original (0.0, 525.0416370925865)
# Set new bounds for reaction HMR_2741: (-382.6802540598492, 0.0) from original (-525.041637057641, 0.0)
# Set new bounds for reaction HMR_2772: (0.0, 330.0867714652388) from original (0.0, 395.2314300021643)
# Set new bounds for reaction HMR_2774: (0.0, 451.108282861757) from original (0.0, 451.108282861757)
# Set new bounds for reaction HMR_2775: (0.0, 376.7536318410954) from original (0.0, 451.10828286175695)
# Set new bounds for reaction HMR_2817: (0.0, 885.7390121633781) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_2821: (-885.7390121633781, 885.7390121633781) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2852: (-310.8234163438169, 310.8234163438169) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2857: (0.0, 885.7390121633781) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_2862: (-310.8234163438169, 310.8234163438169) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2866: (-310.8234163438169, 310.8234163438169) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2890: (-310.8234163438169, 310.8234163438169) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2945: (0.0, 856.1083181243217) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_3113: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_9719: (0.0, 787.9404288799296) from original (0.0, 787.9404288799296)
# Set new bounds for reaction HMR_9801: (0.0, 1.7690088109206454e-07) from original (0.0, 3.5000005153779055e-07)
# Set new bounds for reaction HMR_9805: (0.0, 147.06627107472937) from original (0.0, 999.997415546422)
# Set new bounds for reaction HMR_2957: (0.0, 947.0356687115494) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_6580: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0980: (-73.6995578481207, 0.0) from original (-100.0, 0.0)
# Set new bounds for reaction HMR_4816: (0.0, 123.66513046135661) from original (0.0, 200.0)
# Set new bounds for reaction HMR_4772: (0.0, 88.82463726511412) from original (0.0, 100.0)
# Set new bounds for reaction 12DHCHOLt: (-448.7210374157782, 448.7210374157782) from original (-1000.0, 1000.0)
# Set new bounds for reaction 12DHCHOLt2: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHCDCHOLabc: (0.0, 331.8096680344677) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHCDCHOLt: (-448.7210374157782, 448.7210374157782) from original (-1000.0, 1000.0)
# Set new bounds for reaction 3DHCDCHOLt2: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHDCAS: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHDCAt: (-448.7210374157782, 448.7210374157782) from original (-1000.0, 1000.0)
# Set new bounds for reaction 3DHLCAt: (-448.7210374157782, 448.7210374157782) from original (-1000.0, 1000.0)

# %% [markdown]
# ## Low grade

# %%
model = load_json_model('./data/Recon3D.json')
model.solver = 'gurobi' #you can use cplex or glpk as you whish, but gurobi and cplex are usually faster
model
# Out:
# <Model Recon3D at 0x79e4053dbf70>

# %%
df_fva_LG_min_sum = pd.read_csv('./data/fva_exoflux_LG_min_sum.csv', index_col=0)
df_fva_LG_min_sum
# Out:
#                           minimum       maximum
# 24_25DHVITD3tm       0.000000e+00  1.000000e+02
# 25HVITD3t            0.000000e+00  1.000000e+02
# COAtl                0.000000e+00  1.000000e+03
# EX_5adtststerone_e  -1.000000e-07  1.000000e+02
# EX_5adtststerones_e -1.000000e-07  1.000000e+02
# ...                           ...           ...
# ACMPGLUTTRsc         0.000000e+00  1.500006e-07
# FVSCOAhc             0.000000e+00  1.500006e-07
# MDZGLChr             0.000000e+00  1.500007e-07
# TMACMPhr             0.000000e+00  1.500006e-07
# CYSACMPitr           0.000000e+00  1.500006e-07
#
# [10600 rows x 2 columns]

# %%
df_fva_LG_min_sum.loc[df_fva_LG_min_sum['minimum'] > df_fva_LG_min_sum['maximum']]
# Out:
# Empty DataFrame
# Columns: [minimum, maximum]
# Index: []

# %%
for index, row in df_fva_LG_min_sum.iterrows():
    model.reactions.get_by_id(index).bounds = (row['minimum'], row['maximum'])

# %%
model.reactions.get_by_id('BIOMASS_reaction').bounds
# Out:
# (np.float64(0.0115524530093324), np.float64(0.0519860385419959))

# %%
model.objective = 'BIOMASS_reaction'

# %%
sol = model.optimize()

# %%
sol.objective_value
# Out:
# 0.0519860385419959

# %%
biomass_target = sol.objective_value
biomass_target
# Out:
# 0.0519860385419959

# %%
for cell_name in ['ACH-000520', 'ACH-000542']: #59M, HEYA8
    print("***********************************************")
    print("Processing cell line:", cell_name)
    print("***********************************************")
    #reset model
    for index, row in df_fva_LG_min_sum.iterrows():
        model.reactions.get_by_id(index).bounds = (row['minimum'], row['maximum'])
    integrate_rnaseq(model, cell_name, ras_matrix, biomass_target)
    #compute variability analysis
    df_var = flux_variability_analysis(model, fraction_of_optimum=0.0)
    df_var.to_csv(f'./data/fva_rnaseq_{cell_name}_LG.csv')
# Out:
# ***********************************************
# Processing cell line: ACH-000520
# ***********************************************
# Integrating RNA-seq for cell line: ACH-000520
# Set new bounds for reaction 24_25VITD3Hm: (0.0, 2.9837005599391997) from original (0.0, 100.0)
# Set new bounds for reaction 13DAMPPOX: (0.0, 659.1154496705864) from original (0.0, 922.0810110695865)
# Set new bounds for reaction 25VITD2Hm: (0.0, 407.10676718774766) from original (0.0, 799.9996724540762)
# Set new bounds for reaction 2AMACHYD: (0.0, 54.93868528101064) from original (0.0, 1000.0)
# Set new bounds for reaction 2AMACSULT: (0.0, 701.1557253236767) from original (0.0, 1000.0)
# Set new bounds for reaction 2AMADPTm: (0.0, 430.9875300203422) from original (0.0, 1000.0)
# Set new bounds for reaction 2OXOADOXm: (0.0, 955.5745735642786) from original (0.0, 1000.0)
# Set new bounds for reaction 2OXOADPTm: (-430.9875300203422, 430.9875300203422) from original (-1000.0, 1000.0)
# Set new bounds for reaction 34DHPHEt: (-152.09589506506882, 3.802398421784906e-08) from original (-1000.0, 2.500000687170541e-07)
# Set new bounds for reaction 34DHXMANDACOX: (0.0, 819.357805768822) from original (0.0, 1000.0)
# Set new bounds for reaction 3AIBtm: (0.0, 1.0556800847283857e-06) from original (0.0, 1.351217979236835e-05)
# Set new bounds for reaction 3HAO: (1e-07, 208.15712598928226) from original (1e-07, 666.6664482360508)
# Set new bounds for reaction 3MOXTYROX: (0.0, 37.260893886268974) from original (0.0, 100.0)
# Set new bounds for reaction 42A12BOOX: (0.0, 546.9127152636742) from original (0.0, 1000.0)
# Set new bounds for reaction 4HOXPACDOX_NADP: (-769.3131527352986, 76.93131527352986) from original (-1000.0, 100.0)
# Set new bounds for reaction 4NPHSULT: (0.0, 3.82057821208728e-08) from original (0.0, 1.5000004623216228e-07)
# Set new bounds for reaction 5ADTSTSTERONESULT: (0.0, 701.1557253236767) from original (0.0, 1000.0)
# Set new bounds for reaction 5FTHFt2_1: (0.0, 1.4504931365407399e-07) from original (0.0, 1.4999993425135474e-07)
# Set new bounds for reaction 5HOXINOXDA: (0.0, 74.52180447072278) from original (0.0, 200.00004481423576)
# Set new bounds for reaction A4GALTc: (0.0, 698.3096867648376) from original (0.0, 1000.0)
# Set new bounds for reaction A4GALTg: (0.0, 174.5774216999383) from original (0.0, 250.00000001250004)
# Set new bounds for reaction A4GNT2g: (0.0, 1.2684969335477291e-08) from original (0.0, 4.999969860364217e-08)
# Set new bounds for reaction ABTArm: (-78.12803714502316, 78.12803714502316) from original (-1000.0, 1000.0)
# Set new bounds for reaction ABUTt2rL: (-760.0740440458774, 760.0740440458774) from original (-1000.0, 1000.0)
# Set new bounds for reaction ACACT10m: (-198.99543742875872, 696.4841766195477) from original (-200.00000005, 700.0001465290011)
# Set new bounds for reaction ACACT5p: (0.0, 604.4418152744221) from original (0.0, 670.0000000250001)
# Set new bounds for reaction ACACT8p: (0.0, 902.1519630624898) from original (0.0, 1000.0)
# Set new bounds for reaction ACACT9p: (0.0, 902.1519630624898) from original (0.0, 1000.0)
# Set new bounds for reaction ACCOALm: (0.0, 687.7269245351999) from original (0.0, 1000.0)
# Set new bounds for reaction ACCOAtr: (-815.1577951107421, 815.1577951107421) from original (-1000.0, 1000.0)
# Set new bounds for reaction ACETONEt2: (-97.67605959014564, 976.7605959014563) from original (-100.0, 1000.0)
# Set new bounds for reaction ACGAMK: (0.0, 930.7339891071633) from original (0.0, 1000.0)
# Set new bounds for reaction ACGAMPM: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction ACHVESSEC_1: (0.0, 861.218919359983) from original (0.0, 1000.0)
# Set new bounds for reaction ACNAMlt: (-843.3476526900707, 0.0) from original (-1000.0, 0.0)
# Set new bounds for reaction ACOAD10m: (0.0, 779.4539410992382) from original (0.0, 900.0001465290011)
# Set new bounds for reaction ACOAD8m: (0.0, 630.9978196401811) from original (0.0, 1000.0)
# Set new bounds for reaction ACOAD9m: (0.0, 900.75713155013) from original (0.0, 1000.0)
# Set new bounds for reaction ACOAO7p: (0.0, 990.044993539718) from original (0.0, 1000.0)
# Set new bounds for reaction ACODA: (0.0, 8.156484256480059e-08) from original (0.0, 1.0000000201168536e-07)
# Set new bounds for reaction ACONTm: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction ACP1_FMN: (0.0, 673.0721461963972) from original (0.0, 1000.0)
# Set new bounds for reaction ACS2: (0.0, 716.3818380318721) from original (0.0, 999.9999999)
# Set new bounds for reaction ACSRTNMT: (0.0, 0.0) from original (0.0, 300.0)
# Set new bounds for reaction ADEt: (-6.0150653566003095e-06, 37.717701572566575) from original (-1.5947592509083892e-05, 99.9999999)
# Set new bounds for reaction ADK3: (-661.1761459656934, 661.1761459656934) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADK3m: (-583.6458649070128, 583.6458649070128) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADKd: (-661.1761459656934, 661.1761459656934) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADMDC: (0.0, 721.182472353898) from original (0.0, 999.999995534345)
# Set new bounds for reaction ADNt4: (0.0, 357.8057110223044) from original (0.0, 1000.0)
# Set new bounds for reaction ADNtl: (0.0, 700.2024802091674) from original (0.0, 1000.0)
# Set new bounds for reaction ADNtm: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADPMAN: (0.0, 4.820694734916402e-07) from original (0.0, 5e-07)
# Set new bounds for reaction ADPRIBt: (0.0, 6.500887712313235e-08) from original (0.0, 5e-07)
# Set new bounds for reaction ADRNCRNt: (-885.5747041223486, 885.5747041223486) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADSL2r: (0.0, 620.5617770974633) from original (0.0, 649.4837406126152)
# Set new bounds for reaction AG13T16g: (0.0, 16.232137616347636) from original (0.0, 38.46153846923077)
# Set new bounds for reaction AG13T18g: (0.0, 16.232137616347572) from original (0.0, 38.46153846923062)
# Set new bounds for reaction AG13T2g: (0.0, 17.58481574928479) from original (0.0, 41.66666667083334)
# Set new bounds for reaction AGMTm: (0.0, 79.61126616342612) from original (0.0, 100.0000001000002)
# Set new bounds for reaction AGTim: (0.0, 39.35177734419111) from original (0.0, 1000.0)
# Set new bounds for reaction AHANDROSTANGLCte: (0.0, 2.0517303366712833e-07) from original (0.0, 2.6666673412134213e-07)
# Set new bounds for reaction AHEXASE2ly: (0.0, 2.6555168192082657e-07) from original (0.0, 2.666667341213421e-07)
# Set new bounds for reaction AIRCr: (0.0, 573.6294242941842) from original (0.0, 649.4837405113242)
# Set new bounds for reaction AKGMALtm: (-786.9843970882932, 786.9843970882932) from original (-1000.0, 1000.0)
# Set new bounds for reaction AKGt4_3: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction AKR1C41: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction AKR1D: (0.0, 336.62835090059997) from original (0.0, 1000.0)
# Set new bounds for reaction ALAGLYexR: (-342.5378786151189, 342.5378786151189) from original (-1000.0, 1000.0)
# Set new bounds for reaction ALASERNaEx: (0.0, 922.1365479523306) from original (0.0, 1000.0)
# Set new bounds for reaction ALASm: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction ALATHRNaEx: (0.0, 922.1365479523306) from original (0.0, 1000.0)
# Set new bounds for reaction ALCD21_D: (0.0, 732.6759559029867) from original (0.0, 1000.0)
# Set new bounds for reaction ALCD22_D: (0.0, 732.6759559029867) from original (0.0, 1000.0)
# Set new bounds for reaction ALCD2y: (0.0, 1.582337888941131e-07) from original (0.0, 1.666668490705585e-07)
# Set new bounds for reaction ALDD20xm: (0.0, 88.26563868304984) from original (0.0, 100.0)
# Set new bounds for reaction ALDD2xm: (0.0, 910.9584423649266) from original (0.0, 1000.0)
# Set new bounds for reaction ALDD2y: (0.0, 946.9789734343393) from original (0.0, 1000.0)
# Set new bounds for reaction ALOX15: (0.0, 0.0) from original (0.0, 500.0)
# Set new bounds for reaction ALR2: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction ALR3: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction AMACR2p: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction AMACRp: (0.0, 900.0001465290012) from original (0.0, 900.0001465290012)
# Set new bounds for reaction AMETt2m: (-803.9266505191613, 803.9266505191613) from original (-1000.0, 1000.0)
# Set new bounds for reaction AMPDA: (0.0, 988.8116501153637) from original (0.0, 1000.0)
# Set new bounds for reaction AMY2e: (0.0, 1.0000045236324696e-07) from original (0.0, 1.0000045236324696e-07)
# Set new bounds for reaction ANDRSTRNGLCte: (0.0, 76.93986816284624) from original (0.0, 100.0)
# Set new bounds for reaction APRTO2: (0.0, 37.260893886268974) from original (0.0, 100.0)
# Set new bounds for reaction ARABR: (0.0, 1.000001824038918e-07) from original (0.0, 1.000001824038918e-07)
# Set new bounds for reaction ARACHDt2: (-497.4478731194424, 497.4478731194424) from original (-1000.0, 1000.0)
# Set new bounds for reaction ARGDCm: (0.0, 200.0000001) from original (0.0, 200.0000001)
# Set new bounds for reaction ARGLYSex: (0.0, 849.3428709177401) from original (0.0, 1000.0)
# Set new bounds for reaction ARGSS: (0.0, 800.3044908604742) from original (0.0, 1000.0)
# Set new bounds for reaction ARGt4: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ASNCYSNaEx: (0.0, 906.0817317235067) from original (0.0, 1000.0)
# Set new bounds for reaction ASNGLNNaEx: (0.0, 906.0817317235067) from original (0.0, 1000.0)
# Set new bounds for reaction ASNNm: (0.0, 612.6074446171593) from original (0.0, 1000.0)
# Set new bounds for reaction ASNS1: (0.0, 761.3863486340426) from original (0.0, 1000.0)
# Set new bounds for reaction ASNt4: (0.0, 757.7151172262975) from original (0.0, 1000.0)
# Set new bounds for reaction ASPGLUm: (0.0, 726.5394600353136) from original (0.0, 1000.0)
# Set new bounds for reaction ASPt6: (0.0, 276.90569366599277) from original (0.0, 1000.0)
# Set new bounds for reaction ASPTAm: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction BILGLCURte: (0.0, 769.3986816284623) from original (0.0, 1000.0)
# Set new bounds for reaction BILIRED: (0.0, 98.73367486618118) from original (0.0, 100.00000010000018)
# Set new bounds for reaction ATPasel_1: (0.0, 885.4012437534495) from original (0.0, 1000.0)
# Set new bounds for reaction B3GALT3g: (0.0, 161.62110762202096) from original (0.0, 250.0000000625)
# Set new bounds for reaction B3GNT310g: (0.0, 15.939232859869044) from original (0.0, 200.00000004166668)
# Set new bounds for reaction B3GNT315g: (0.0, 5.313077620177727) from original (0.0, 66.66666668333335)
# Set new bounds for reaction B3GNT31g: (0.0, 7.969616428274184) from original (0.0, 100.0)
# Set new bounds for reaction B3GNT34g: (0.0, 7.96961643026659) from original (0.0, 100.00000002500002)
# Set new bounds for reaction B3GNT37g: (0.0, 7.969616428274184) from original (0.0, 100.0)
# Set new bounds for reaction B3GNT39g: (0.0, 39.84808215332535) from original (0.0, 500.00000015)
# Set new bounds for reaction B3GNT51g: (0.0, 68.00474726515696) from original (0.0, 200.00000004)
# Set new bounds for reaction BACCL: (0.0, 573.0542138795003) from original (0.0, 1000.0)
# Set new bounds for reaction BALAVECSEC_1: (0.0, 502.47528796785735) from original (0.0, 1000.0)
# Set new bounds for reaction BHMT: (0.0, 586.4086181934643) from original (0.0, 999.9999951343448)
# Set new bounds for reaction BILDGLCURt: (-0.0, 0.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction BTNDm: (0.0, 816.227875104136) from original (0.0, 1000.0)
# Set new bounds for reaction BTNPL: (0.0, 573.0542138795003) from original (0.0, 1000.0)
# Set new bounds for reaction BTNt2m: (0.0, 941.3524141735321) from original (0.0, 1000.0)
# Set new bounds for reaction BTNt3i_1: (0.0, 919.8423103759187) from original (0.0, 1000.0)
# Set new bounds for reaction C160CPT1: (-606.9536036219657, 606.9536036219657) from original (-1000.0, 1000.0)
# Set new bounds for reaction C160CPT2: (-652.2273097686501, 652.2273097686501) from original (-1000.0, 1000.0)
# Set new bounds for reaction C160CRNt: (-885.5747041223486, 885.5747041223486) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CPT1: (-606.9536036219657, 606.9536036219657) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CPT12: (-406.6589144621226, 606.9536036219657) from original (-670.0000000583333, 1000.0)
# Set new bounds for reaction C161CPT2: (-630.4265169524245, 630.4265169524245) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CRN2t: (-885.5747041223486, 885.5747041223486) from original (-1000.0, 1000.0)
# Set new bounds for reaction C161CRNt: (-885.5747041223486, 885.5747041223486) from original (-1000.0, 1000.0)
# Set new bounds for reaction C180CPT1: (-606.9536036219657, 606.9536036219657) from original (-1000.0, 1000.0)
# Set new bounds for reaction C181CPT1: (-606.9536036219657, 606.9536036219657) from original (-1000.0, 1000.0)
# Set new bounds for reaction C181CRNt: (-885.5747041223486, 885.5747041223486) from original (-1000.0, 1000.0)
# Set new bounds for reaction C204CPT1: (-606.9536036219657, 606.9536036219657) from original (-1000.0, 1000.0)
# Set new bounds for reaction C204CPT2: (-630.4265169524245, 630.4265169524245) from original (-1000.0, 1000.0)
# Set new bounds for reaction C226CPT1: (0.0, 606.9536036219657) from original (0.0, 1000.0)
# Set new bounds for reaction C226CPT2: (0.0, 630.4265169524245) from original (0.0, 1000.0)
# Set new bounds for reaction C3STDH1r: (0.0, 188.0322740138805) from original (0.0, 204.74206183210612)
# Set new bounds for reaction C4STMO1r: (0.0, 184.96773361848346) from original (0.0, 194.77347384008664)
# Set new bounds for reaction C4STMO2Pr: (0.0, 180.59199673151426) from original (0.0, 196.64059244668672)
# Set new bounds for reaction CAATPS_1: (0.0, 560.6743526908692) from original (0.0, 1000.0)
# Set new bounds for reaction CAt7r: (-152.1089248111692, 152.1089248111692) from original (-1000.0, 1000.0)
# Set new bounds for reaction CATm: (0.0, 985.1887153405387) from original (0.0, 1000.0)
# Set new bounds for reaction CATp: (0.0, 985.1887153405387) from original (0.0, 1000.0)
# Set new bounds for reaction CBL2tm: (0.0, 1.1770364033099778e-07) from original (0.0, 2.0000010307558114e-07)
# Set new bounds for reaction CBPPer: (0.0, 999.9986701157914) from original (0.0, 999.9986701157914)
# Set new bounds for reaction CBR2: (0.0, 865.0231116199838) from original (0.0, 1000.0)
# Set new bounds for reaction CDIPTr: (-148.61399592929467, 724.2352301080986) from original (-205.20127957198756, 1000.0)
# Set new bounds for reaction CDS: (0.0, 526.0431142680194) from original (0.0, 1000.0)
# Set new bounds for reaction CERT1gt: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CERT1rt: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction CERT2rt: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CH25H: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction CHATn: (-0.0, 0.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CHLP: (0.0, 118.19653675765065) from original (0.0, 1000.0)
# Set new bounds for reaction CHOLD2m: (0.0, 179.90713952248487) from original (0.0, 1000.0)
# Set new bounds for reaction CHOLK: (0.0, 649.5084042270266) from original (0.0, 1000.0)
# Set new bounds for reaction CITRtm: (-804.2527331130436, 804.2527331130436) from original (-1000.0, 1000.0)
# Set new bounds for reaction CITtam: (-740.1410862518327, 740.1410862518327) from original (-1000.0, 1000.0)
# Set new bounds for reaction CK_cho: (0.0, 33.136876001694326) from original (0.0, 999.9999999)
# Set new bounds for reaction CLHCO3tex2: (0.0, 814.5549829676843) from original (0.0, 1000.0)
# Set new bounds for reaction CLOXAtex2: (0.0, 814.5549829676843) from original (0.0, 1000.0)
# Set new bounds for reaction CLPNDCPT1: (0.0, 383.136554355483) from original (0.0, 631.2452089733622)
# Set new bounds for reaction ACNMCT: (0.0, 859.5950559700418) from original (0.0, 1000.0)
# Set new bounds for reaction COAtim: (-806.8945719719388, 806.8945719719388) from original (-1000.0, 1000.0)
# Set new bounds for reaction COKECBESr: (0.0, 4.7334653565836956e-07) from original (0.0, 5.500000171792635e-07)
# Set new bounds for reaction COQ3m: (0.0, 101.81051461847686) from original (0.0, 151.61917407712966)
# Set new bounds for reaction COQ6m: (0.0, 92.0123445000155) from original (0.0, 151.61917407712966)
# Set new bounds for reaction COQ7m: (0.0, 110.26443820910058) from original (0.0, 151.61917407712966)
# Set new bounds for reaction CORE3GTg: (0.0, 38.4615388846154) from original (0.0, 38.4615388846154)
# Set new bounds for reaction CORE6GTg: (0.0, 19.96536031341974) from original (0.0, 166.6666667416667)
# Set new bounds for reaction CREATt4_2_r: (-1000.0, 999.9999999) from original (-1000.0, 999.9999999)
# Set new bounds for reaction CRNCARtp: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction CRNt: (-579.4185555302199, 579.4185555302199) from original (-1000.0, 1000.0)
# Set new bounds for reaction CRNtHa: (0.0, 782.3244362178256) from original (0.0, 1000.0)
# Set new bounds for reaction CRNtuNa: (0.0, 579.4185555302199) from original (0.0, 1000.0)
# Set new bounds for reaction CSNAT2m: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CSNAT2x: (-338.1781866550304, 338.1781866550304) from original (-1000.0, 1000.0)
# Set new bounds for reaction CSNATm: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CSNATr: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSALANaEx: (0.0, 922.1365479523306) from original (0.0, 1000.0)
# Set new bounds for reaction CYSASNNaEx: (0.0, 906.0817317235067) from original (0.0, 1000.0)
# Set new bounds for reaction CYSGLYex: (-843.8520053188676, 843.8520053188676) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSO: (0.0, 9.881847978763961) from original (0.0, 1000.0)
# Set new bounds for reaction CYSSERNaEx: (0.0, 922.1365479523306) from original (0.0, 1000.0)
# Set new bounds for reaction CYStec: (-921.2983015695245, 921.2983015695245) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSTGLUex: (0.0, 2.0000033044925658e-07) from original (0.0, 2.0000033044925658e-07)
# Set new bounds for reaction CYTD: (0.0, 236.699913944805) from original (0.0, 1000.0)
# Set new bounds for reaction CYTDn: (0.0, 205.75301208015145) from original (0.0, 1000.0)
# Set new bounds for reaction CYTDt: (-713.9713353747863, 713.9713353747863) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTDtl: (0.0, 700.2024802091674) from original (0.0, 1000.0)
# Set new bounds for reaction CYTK12: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK12n: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK13n: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK14: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK1m: (0.0, 369.0556586601033) from original (0.0, 1000.0)
# Set new bounds for reaction CYTK2n: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK3: (-661.1761459656934, 661.1761459656934) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK4: (-661.1761459656934, 661.1761459656934) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK5n: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CPK1: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK6n: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK7: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK7n: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK8: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYTK8n: (-845.7780356623979, 845.7780356623979) from original (-1000.0, 1000.0)
# Set new bounds for reaction DAGK_hs: (0.0, 980.5482639406453) from original (0.0, 1000.0)
# Set new bounds for reaction DARGOp: (0.0, 0.0) from original (0.0, 2.500002564265742e-07)
# Set new bounds for reaction DASPO1p: (0.0, 2.399437408789776e-09) from original (0.0, 2.500002564265742e-07)
# Set new bounds for reaction DCK1n: (-708.5865030035657, 708.5865030035657) from original (-1000.0, 1000.0)
# Set new bounds for reaction DLNLCGCPT2: (0.0, 630.4265169524245) from original (0.0, 1000.0)
# Set new bounds for reaction DCSPTN1CPT1: (0.0, 606.9534046802223) from original (0.0, 999.9996722290762)
# Set new bounds for reaction DCSPTN1CRNt: (-885.5747041223486, 885.5747041223486) from original (-1000.0, 1000.0)
# Set new bounds for reaction DCYTD: (0.0, 236.699913944805) from original (0.0, 1000.0)
# Set new bounds for reaction DCYTDn: (0.0, 205.75301208015145) from original (0.0, 1000.0)
# Set new bounds for reaction DCYTt: (-377.1770161651251, -1e-07) from original (-1000.0, -1e-07)
# Set new bounds for reaction DESAT18_10: (0.0, 759.2939704610138) from original (0.0, 1000.0)
# Set new bounds for reaction DESAT18_6: (0.0, 759.2939704610138) from original (0.0, 1000.0)
# Set new bounds for reaction DESAT18_12: (0.0, 666.4863787328934) from original (0.0, 877.7711988523084)
# Set new bounds for reaction DESAT24_1: (0.0, 7.592988888826139e-08) from original (0.0, 1.0000064776249928e-07)
# Set new bounds for reaction DGSNt: (-377.17701610284274, 7.543552785843313e-08) from original (-1000.0, 2.0000033044925658e-07)
# Set new bounds for reaction DHCRD2: (0.0, 685.540994009673) from original (0.0, 1000.0)
# Set new bounds for reaction DHDPBMTm: (0.0, 101.81051458812235) from original (0.0, 151.61917403192484)
# Set new bounds for reaction DHEASt: (-225.88689337368425, 225.88689337368425) from original (-1000.0, 1000.0)
# Set new bounds for reaction DHEASULT: (0.0, 698.7217728186872) from original (0.0, 1000.0)
# Set new bounds for reaction DHORD9: (0.0013298342085329, 494.60084501307614) from original (0.0013298342085329, 908.2622590381956)
# Set new bounds for reaction DHPM1: (0.0, 895.3875587370862) from original (0.0, 895.3875587370862)
# Set new bounds for reaction D_LACt2: (-95.3910308404869, 2.86173407740413e-07) from original (-100.0, 3.0000033044925655e-07)
# Set new bounds for reaction DLNLCGCPT1: (-606.9536036219657, 606.9536036219657) from original (-1000.0, 1000.0)
# Set new bounds for reaction DMATTx: (0.0, 462.2845099798141) from original (0.0, 534.4001508017086)
# Set new bounds for reaction DMGDHm: (0.0, 315.2190641945351) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt10m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt11m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt13m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt14m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt15m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt16m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt17m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt18m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt1m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt20m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt21m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt25m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt28m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt32m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt37m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt38m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt39m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt40m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt42m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt43m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt45m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt49m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt50m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt52m: (0.0, 708.9167455094395) from original (0.0, 838.9393791831787)
# Set new bounds for reaction DNDPt55m: (0.0, 705.2885102806888) from original (0.0, 834.6456882390451)
# Set new bounds for reaction DNDPt56m: (0.0, 708.916741821591) from original (0.0, 838.9393748189409)
# Set new bounds for reaction DNDPt57m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt59m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt5m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt60m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt61m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt62m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt63m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DNDPt6m: (0.0, 845.0154601154449) from original (0.0, 1000.0)
# Set new bounds for reaction DOLPH_Uer: (0.0, 513.6489372304354) from original (0.0, 1000.0)
# Set new bounds for reaction DOLPMT_U: (0.0, 571.053485386592) from original (0.0, 1000.0)
# Set new bounds for reaction DOPAt4_2_r: (-405.87334831282317, 405.87334831282317) from original (-1000.0, 1000.0)
# Set new bounds for reaction DOPAtu: (-614.681810598246, 614.681810598246) from original (-1000.0, 1000.0)
# Set new bounds for reaction DOPAVESSEC_1: (0.0, 231.8670829983939) from original (0.0, 1000.0)
# Set new bounds for reaction DPGase: (0.0, 801.1392300902547) from original (0.0, 1000.0)
# Set new bounds for reaction DURAD: (-971.0898599000815, 5.826539159400489e-07) from original (-1000.0, 6e-07)
# Set new bounds for reaction DURAD2: (-874.82491140388, 971.0898599000815) from original (-900.8691651809582, 1000.0)
# Set new bounds for reaction DURIK1: (0.0, 878.5410541401177) from original (0.0, 1000.0)
# Set new bounds for reaction DURIt: (-377.1770161651251, -1e-07) from original (-1000.0, -1e-07)
# Set new bounds for reaction DUTPDPm: (0.0, 795.9689597526449) from original (0.0, 1000.0)
# Set new bounds for reaction ECOAH12m: (0.0, 964.1012185587045) from original (0.0, 1000.0)
# Set new bounds for reaction ECOAH9m: (-96.41012209689595, 771.2811164531879) from original (-100.0000002500002, 800.0001468790015)
# Set new bounds for reaction EICOSTETCPT1: (0.0, 606.9536036219657) from original (0.0, 1000.0)
# Set new bounds for reaction ESTRIOLGLCte: (0.0, 76.93986816284624) from original (0.0, 100.0)
# Set new bounds for reaction ESTRONEGLCt: (0.0, 74.83632980446572) from original (0.0, 100.0)
# Set new bounds for reaction ESTRONESt: (-483.0820088802479, 483.0820088802479) from original (-1000.0, 1000.0)
# Set new bounds for reaction ESTRONESt2: (0.0, 170.7656994704147) from original (0.0, 1000.0)
# Set new bounds for reaction ETF: (0.0, 857.5132118731929) from original (0.0, 933.3320037991248)
# Set new bounds for reaction ETFQO: (0.0, 777.4896827052394) from original (0.0, 933.3320037991244)
# Set new bounds for reaction ETHAK: (0.0, 775.755907533249) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL140: (0.0, 969.2073076768417) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL160: (0.0, 808.9493764016283) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL170: (0.0, 968.4068616224918) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL181: (0.0, 964.9561057473544) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL1821: (0.0, 964.9561057473544) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL1822: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL1831: (0.0, 811.0524194631062) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL184: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL203: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL204: (0.0, 964.9561057473544) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL2042: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL205: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL2251: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL2252: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL240_1: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL241: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL245_1: (0.0, 664.2429835127455) from original (0.0, 1000.0)
# Set new bounds for reaction FACOAL40im: (0.0, 0.0) from original (0.0, 1.5e-07)
# Set new bounds for reaction FACOAL80: (0.0, 1.4538109615152623e-07) from original (0.0, 1.5e-07)
# Set new bounds for reaction FAEL184: (0.0, 952.0016491402238) from original (0.0, 1000.0)
# Set new bounds for reaction FAEL204: (0.0, 952.0016491402238) from original (0.0, 1000.0)
# Set new bounds for reaction FAEL205: (0.0, 952.0016491402238) from original (0.0, 1000.0)
# Set new bounds for reaction FAH1: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction FAH2: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction FALDH: (-870.8671119145431, 870.8671119145431) from original (-1000.0, 1000.0)
# Set new bounds for reaction FAOXC11: (0.0, 1.1502805238914292e-07) from original (0.0, 1.250000029684088e-07)
# Set new bounds for reaction FAOXC16080m: (0.0, 716.9837081733149) from original (0.0, 793.3330008747812)
# Set new bounds for reaction FAOXC16080x: (0.0, 417.345556868951) from original (0.0, 502.500000075)
# Set new bounds for reaction FAOXC180x: (0.0, 830.5384215057923) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC1811601m: (0.0, 716.9837082185029) from original (0.0, 793.3330009247812)
# Set new bounds for reaction FAOXC1811603m: (0.0, 716.9837082185028) from original (0.0, 793.3330009247811)
# Set new bounds for reaction FAOXC182806m: (0.0, 903.761355424168) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC18280m: (0.0, 903.761355424168) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC183806m: (0.0, 903.7610580340679) from original (0.0, 999.9996709417832)
# Set new bounds for reaction FAOXC18480m: (0.0, 903.761355424168) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC200180x: (0.0, 830.5384215057923) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC2031836m: (0.0, 903.761355424168) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC204: (0.0, 566.6154612708433) from original (0.0, 626.9525222229823)
# Set new bounds for reaction FAOXC2051843m: (0.0, 903.761355424168) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC2051843x: (0.0, 709.1519955997572) from original (0.0, 853.8461042103776)
# Set new bounds for reaction FAOXC2251836m: (0.0, 903.7610591974734) from original (0.0, 999.999672229076)
# Set new bounds for reaction FAOXC2252053m: (0.0, 723.0088473579787) from original (0.0, 799.9997377832608)
# Set new bounds for reaction FAOXC2252053x: (0.0, 664.4305192906711) from original (0.0, 799.9997376232609)
# Set new bounds for reaction FAOXC226205m: (0.0, 903.761355424168) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC2442246x: (0.0, 4.152692107528961e-07) from original (0.0, 5e-07)
# Set new bounds for reaction FAOXC2452253x: (0.0, 3.322153971383937e-07) from original (0.0, 4.00000034358527e-07)
# Set new bounds for reaction FAOXC2452256x: (0.0, 3.322153971383937e-07) from original (0.0, 4.00000034358527e-07)
# Set new bounds for reaction FAOXC246226x: (0.0, 3.322153971383937e-07) from original (0.0, 4.00000034358527e-07)
# Set new bounds for reaction FAOXC260240x_1: (0.0, 830.5384215057923) from original (0.0, 1000.0)
# Set new bounds for reaction FAS160COA: (0.0, 990.4868811871371) from original (0.0, 1000.0)
# Set new bounds for reaction FATP1t: (-688.3875621235259, 688.3875621235259) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP2t: (-970.263987115933, 970.263987115933) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP3t: (-970.263987115933, 970.263987115933) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP7t: (-329.8452702175791, 329.8452702175791) from original (-1000.0, 1000.0)
# Set new bounds for reaction FATP8t: (-329.8452702175791, 329.8452702175791) from original (-1000.0, 1000.0)
# Set new bounds for reaction FBA5: (0.0, 4.393424610529429e-08) from original (0.0, 2.499999999998164e-07)
# Set new bounds for reaction FDH: (0.0, 62.737645723641045) from original (0.0, 1000.0)
# Set new bounds for reaction FE3R2e_1: (0.0, 782.6742708257467) from original (0.0, 1000.0)
# Set new bounds for reaction FK: (0.0, 1.488559096906758e-07) from original (0.0, 2.499999993688107e-07)
# Set new bounds for reaction FKYNH: (2e-07, 945.987413859825) from original (2e-07, 1000.0)
# Set new bounds for reaction FPGS2: (0.0, 833.6800310941791) from original (0.0, 1000.0)
# Set new bounds for reaction FPGS2m: (0.0, 833.6800310941791) from original (0.0, 1000.0)
# Set new bounds for reaction FPGS3: (0.0, 833.6800310941791) from original (0.0, 1000.0)
# Set new bounds for reaction FPGS4_1: (0.0, 208.42000777354477) from original (0.0, 250.0)
# Set new bounds for reaction FPGS4m_1: (0.0, 166.73600621883583) from original (0.0, 200.0)
# Set new bounds for reaction FPGS5: (0.0, 166.73600621883583) from original (0.0, 200.0)
# Set new bounds for reaction FPGS5m: (0.0, 166.73600621883583) from original (0.0, 200.0)
# Set new bounds for reaction FPGS6m: (0.0, 138.94667184902985) from original (0.0, 166.66666666666666)
# Set new bounds for reaction FPGS7m_1: (0.0, 208.42000777354477) from original (0.0, 250.0)
# Set new bounds for reaction FPGS8m: (0.0, 166.73600621883583) from original (0.0, 200.0)
# Set new bounds for reaction FPGS9: (0.0, 138.94667184902985) from original (0.0, 166.66666666666666)
# Set new bounds for reaction FPGSm_1: (0.0, 833.6800310941791) from original (0.0, 1000.0)
# Set new bounds for reaction FRUt1r: (-399.1916209225889, 399.1916209225889) from original (-1000.0, 1000.0)
# Set new bounds for reaction FTHFDH: (0.0, 826.1111915070675) from original (0.0, 1000.0)
# Set new bounds for reaction FTHFLmi: (0.0, 870.1972688853973) from original (0.0, 1000.0)
# Set new bounds for reaction FUCASE2ly: (0.0, 1.2163907233114403e-07) from original (0.0, 2.500000343585271e-07)
# Set new bounds for reaction FUCASEe: (0.0, 2.2793700583542254e-07) from original (0.0, 2.500000343585271e-07)
# Set new bounds for reaction FUMAC: (0.0, 999.9996723044512) from original (0.0, 999.9996723044512)
# Set new bounds for reaction FUMSO4tm: (-607.8396108323167, 607.8396108323167) from original (-1000.0, 1000.0)
# Set new bounds for reaction FUMtm: (-607.8396108323167, 607.8396108323167) from original (-1000.0, 1000.0)
# Set new bounds for reaction FUT15g: (0.0, 5.270828630770475) from original (0.0, 83.33333334166666)
# Set new bounds for reaction FUT16g: (0.0, 5.749994870506427) from original (0.0, 90.90909092727271)
# Set new bounds for reaction FUT32g: (0.0, 7.024548643515657) from original (0.0, 100.0)
# Set new bounds for reaction FUT911g: (0.0, 0.0) from original (0.0, 66.66666667999999)
# Set new bounds for reaction FUT91g: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction FUT94g: (0.0, 0.0) from original (0.0, 90.90909092727271)
# Set new bounds for reaction FUT96g: (0.0, 0.0) from original (0.0, 100.00000002)
# Set new bounds for reaction FUT97g: (0.0, 0.0) from original (0.0, 100.00000002)
# Set new bounds for reaction FUT99g: (0.0, 0.0) from original (0.0, 66.66666667999999)
# Set new bounds for reaction G14T20g: (0.0, 31.85077897564926) from original (0.0, 38.461538465384606)
# Set new bounds for reaction G14T21g: (0.0, 31.85077897564927) from original (0.0, 38.46153846538462)
# Set new bounds for reaction G14T2g: (0.0, 34.505010556953366) from original (0.0, 41.66666667083333)
# Set new bounds for reaction G14T5g: (0.0, 34.505010556953366) from original (0.0, 41.66666667083333)
# Set new bounds for reaction G5SDym: (0.0, 888.6372902869913) from original (0.0, 1000.0)
# Set new bounds for reaction G6PDH1er: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction G6PDH2er: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction G6PPer: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction GABAVESSEC_1: (0.0, 502.47528796785735) from original (0.0, 1000.0)
# Set new bounds for reaction GACMTRc: (1e-07, 1000.0) from original (1e-07, 1000.0)
# Set new bounds for reaction GALASE10ly: (0.0, 1.2144654902402828e-07) from original (0.0, 1.5000011899246601e-07)
# Set new bounds for reaction GALASE12ly: (0.0, 1.2144654902402828e-07) from original (0.0, 1.5000011899246601e-07)
# Set new bounds for reaction GALASE13ly: (0.0, 1.2144654902402828e-07) from original (0.0, 1.5000011899246601e-07)
# Set new bounds for reaction GALASE15ly: (0.0, 1.2144654902402828e-07) from original (0.0, 1.5000011899246601e-07)
# Set new bounds for reaction GALASE16ly: (0.0, 33.73512585986862) from original (0.0, 41.66666680833336)
# Set new bounds for reaction GALASE17ly: (0.0, 33.735125859868596) from original (0.0, 41.66666680833333)
# Set new bounds for reaction GALASE19ly: (0.0, 134.94050307513515) from original (0.0, 166.66666678333348)
# Set new bounds for reaction GALASE1ly: (0.0, 1.2144650831889205e-07) from original (0.0, 1.500000687170541e-07)
# Set new bounds for reaction GALASE20ly: (0.0, 31.14011618768235) from original (0.0, 38.46153860384624)
# Set new bounds for reaction GALASE4ly: (0.0, 1.2144650831889205e-07) from original (0.0, 1.500000687170541e-07)
# Set new bounds for reaction GALASE7ly: (0.0, 1.2144650831889205e-07) from original (0.0, 1.500000687170541e-07)
# Set new bounds for reaction GALASE8ly: (0.0, 1.2144650831889205e-07) from original (0.0, 1.500000687170541e-07)
# Set new bounds for reaction GALASE9ly: (0.0, 1.2144650831889205e-07) from original (0.0, 1.500000687170541e-07)
# Set new bounds for reaction GALGT2: (0.0, 135.72080074642545) from original (0.0, 166.66666667500007)
# Set new bounds for reaction GALGT3: (0.0, 101.7906005852668) from original (0.0, 125.00000003750014)
# Set new bounds for reaction GALNACT1g: (0.0, 44.606143598151874) from original (0.0, 71.42857143571432)
# Set new bounds for reaction GALNACT2g: (0.0, 61.953843797947506) from original (0.0, 71.42857143571432)
# Set new bounds for reaction GALNACT3g: (0.0, 61.953843797947506) from original (0.0, 71.42857143571432)
# Set new bounds for reaction GALNACT4g: (0.0, 54.20961332320408) from original (0.0, 62.50000000625004)
# Set new bounds for reaction GALNACT5g: (0.0, 51.02081253948618) from original (0.0, 58.82352941764709)
# Set new bounds for reaction GALt1r: (-738.2507004524881, 738.2507004524881) from original (-1000.0, 1000.0)
# Set new bounds for reaction GALT2g: (0.0, 55.07018379562095) from original (0.0, 71.42857145357144)
# Set new bounds for reaction GAO1g: (0.0, 81.5157795110742) from original (0.0, 100.0)
# Set new bounds for reaction GASNASE2ly: (0.0, 2.499999893887434e-07) from original (0.0, 2.499999893887434e-07)
# Set new bounds for reaction GASNASEly: (0.0, 2.499999893887434e-07) from original (0.0, 2.499999893887434e-07)
# Set new bounds for reaction GBA: (0.0, 775.1692975184046) from original (0.0, 1000.0)
# Set new bounds for reaction GBGT1: (0.0, 166.666666725) from original (0.0, 166.666666725)
# Set new bounds for reaction GCCam: (0.0, 677.4096332341987) from original (0.0, 1000.0)
# Set new bounds for reaction GCHOLAt2: (0.0, 170.7656994704147) from original (0.0, 1000.0)
# Set new bounds for reaction GDPFUCtg: (0.0, 344.77297652705494) from original (0.0, 366.6666667333335)
# Set new bounds for reaction GFUCS: (0.0, 833.0775459841168) from original (0.0, 833.3333344833362)
# Set new bounds for reaction GGH_10FTHF7GLUl: (0.0, 119.50133237021889) from original (0.0, 166.66666666666666)
# Set new bounds for reaction GGH_5THFl: (0.0, 179.25199855532833) from original (0.0, 250.0)
# Set new bounds for reaction GGH_6DHFl: (0.0, 143.40159884426268) from original (0.0, 200.0)
# Set new bounds for reaction GGH_7THFe: (0.0, 1.4340197752403586e-07) from original (0.0, 2.0000052813884397e-07)
# Set new bounds for reaction GGLUCT: (0.0, 657.4596417998717) from original (0.0, 1000.0)
# Set new bounds for reaction GHMT2rm: (0.0, 790.7682832666409) from original (0.0, 1000.0)
# Set new bounds for reaction GLAl: (0.0, 735.0478368002005) from original (0.0, 1000.0)
# Set new bounds for reaction GLB1: (0.0, 809.64301788406) from original (0.0, 1000.0)
# Set new bounds for reaction GLCAASE4ly: (0.0, 43.09300313318697) from original (0.0, 71.42857177857151)
# Set new bounds for reaction GLCAASE6ly: (0.0, 37.70637776793306) from original (0.0, 62.50000035000007)
# Set new bounds for reaction GLCAASE7ly: (0.0, 35.488355558710865) from original (0.0, 58.823529761764775)
# Set new bounds for reaction GLCAASE8ly: (0.0, 370.2707883008226) from original (0.0, 500.0)
# Set new bounds for reaction GLCAASE9ly: (0.0, 301.65102045421844) from original (0.0, 500.0)
# Set new bounds for reaction GLCAT4g: (0.0, 59.43535231102356) from original (0.0, 62.500000021875)
# Set new bounds for reaction GLCAT5g: (0.0, 55.93915511625746) from original (0.0, 58.82352943235294)
# Set new bounds for reaction GLCAT6g: (0.0, 28.571428581428577) from original (0.0, 28.571428581428577)
# Set new bounds for reaction GLCAT7g: (0.0, 28.571428581428577) from original (0.0, 28.571428581428577)
# Set new bounds for reaction GLCAT8g: (0.0, 28.571428581428577) from original (0.0, 28.571428581428577)
# Set new bounds for reaction GLCNACASE5ly: (0.0, 24.884830141795554) from original (0.0, 28.571428921428637)
# Set new bounds for reaction GLCNACDASg: (0.0, 24.01878583898123) from original (0.0, 28.571428581428567)
# Set new bounds for reaction GLCNACT2g: (0.0, 28.57142858142857) from original (0.0, 28.57142858142857)
# Set new bounds for reaction GLCNACT5g: (0.0, 28.57142858142857) from original (0.0, 28.57142858142857)
# Set new bounds for reaction GLGNS1: (0.0, 155.50923368566723) from original (0.0, 181.8181818181818)
# Set new bounds for reaction GLNALANaEx: (0.0, 906.0817317235067) from original (0.0, 1000.0)
# Set new bounds for reaction GLNASNNaEx: (0.0, 906.0817317235067) from original (0.0, 1000.0)
# Set new bounds for reaction GLNCYSNaEx: (0.0, 906.0817317235067) from original (0.0, 1000.0)
# Set new bounds for reaction GLPASE1: (0.0, 366.3252433160314) from original (0.0, 495.2217619928669)
# Set new bounds for reaction GLPASE2: (0.0, 304.02203693288783) from original (0.0, 410.9963251554505)
# Set new bounds for reaction GLUt6: (0.0, 276.90569366599277) from original (0.0, 1000.0)
# Set new bounds for reaction GLXO2p: (0.0, 0.0) from original (0.0, 2.8885783545767777e-05)
# Set new bounds for reaction GLYAMDTRc: (0.0, 236.5160045336605) from original (0.0, 1000.0)
# Set new bounds for reaction GLYBt4_2_r: (-23.310313450122376, 23.310313447791344) from original (-1000.0, 999.9999999)
# Set new bounds for reaction GLYt4: (0.0, 757.7151172262975) from original (0.0, 1000.0)
# Set new bounds for reaction GLYt7_211_r: (-688.0672636355329, 688.0672636355329) from original (-1000.0, 1000.0)
# Set new bounds for reaction GLYVESSEC_1: (0.0, 502.47528796785735) from original (0.0, 1000.0)
# Set new bounds for reaction GNDer: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction GNMT: (0.0, 231.81908563274538) from original (0.0, 1000.0)
# Set new bounds for reaction GPAM_hs_1: (0.0, 981.8141047208745) from original (0.0, 1000.0)
# Set new bounds for reaction GPIDA2er: (0.0, 248.21962894947106) from original (0.0, 333.33333333333326)
# Set new bounds for reaction GPIDAer: (0.0, 248.21962894947106) from original (0.0, 333.33333333333326)
# Set new bounds for reaction GTHOm: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction GTHPi: (0.0, 974.2115303223621) from original (0.0, 1000.0)
# Set new bounds for reaction GTHPm: (0.0, 976.489660346504) from original (0.0, 1000.0)
# Set new bounds for reaction GTHS: (0.0, 903.1208502706894) from original (0.0, 1000.0)
# Set new bounds for reaction HCO3Em: (0.0, 623.0865246749768) from original (0.0, 1000.0)
# Set new bounds for reaction H2O2syn: (0.0, 28.615174499214955) from original (0.0, 1000.0)
# Set new bounds for reaction H3MTer_U: (0.0, 203.26743172523481) from original (0.0, 333.33333333333326)
# Set new bounds for reaction H4ET3er: (0.0, 236.56495248350865) from original (0.0, 333.33333333333337)
# Set new bounds for reaction H4ETer: (0.0, 173.75220327090068) from original (0.0, 333.33333333333337)
# Set new bounds for reaction H6ET3er: (0.0, 236.56495248350865) from original (0.0, 333.33333333333337)
# Set new bounds for reaction H7ET2er: (0.0, 236.27868726724728) from original (0.0, 333.33333333333326)
# Set new bounds for reaction HACD1x: (-673.6031765512505, 0.0) from original (-1000.0, 0.0)
# Set new bounds for reaction HACD9m: (-155.9908972247482, 545.9682545335723) from original (-200.00000000000017, 700.0001464790012)
# Set new bounds for reaction HAS1: (0.0, 484.53227542613365) from original (0.0, 550.0000000333334)
# Set new bounds for reaction HBZOPT10m: (0.0, 140.63833047582298) from original (0.0, 151.6191740118828)
# Set new bounds for reaction HCO3_CLt: (-845.686768421659, 845.686768421659) from original (-1000.0, 1000.0)
# Set new bounds for reaction HDCAt: (-497.4478731194424, 497.4478731194424) from original (-1000.0, 1000.0)
# Set new bounds for reaction HEX4: (0.0, 1.0500002698187015e-06) from original (0.0, 1.0500002698187015e-06)
# Set new bounds for reaction HISDC: (0.0, 172.0277602912326) from original (0.0, 999.9985401006252)
# Set new bounds for reaction HISt4: (0.0, 845.5277184467486) from original (0.0, 1000.0)
# Set new bounds for reaction HISTAVESSEC_1: (0.0, 231.8670829983939) from original (0.0, 1000.0)
# Set new bounds for reaction HMGCOASm: (-648.3196487045524, 0.0) from original (-1000.0, 0.0)
# Set new bounds for reaction HMGLm: (0.0, 727.903311504769) from original (0.0, 1000.0)
# Set new bounds for reaction HMGLx: (0.0, 965.6078487399957) from original (0.0, 1000.0)
# Set new bounds for reaction HOMt4: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HPDCACRNCPT1: (-606.9536036219657, 9.104306963955353e-08) from original (-1000.0, 1.5000004793819246e-07)
# Set new bounds for reaction HPDCACRNCPT2: (-630.4265169524245, 9.45640077643714e-08) from original (-1000.0, 1.5000004793819246e-07)
# Set new bounds for reaction HPYRR2x_1: (0.0, 45.29968189257968) from original (0.0, 50.0)
# Set new bounds for reaction HS2ly: (0.0, 24.499951684403722) from original (0.0, 28.57142867142852)
# Set new bounds for reaction HSD17B42x_1: (0.0, 894.8873388509545) from original (0.0, 1000.0)
# Set new bounds for reaction HSD17B4x: (0.0, 805.3987359585739) from original (0.0, 900.0001463790012)
# Set new bounds for reaction HSD17B7r: (0.0, 920.2664948201525) from original (0.0, 1000.0)
# Set new bounds for reaction HSD17B8r: (0.0, 41.95656365794543) from original (0.0, 1000.0)
# Set new bounds for reaction HSD17B9r: (0.0, 920.2664948201525) from original (0.0, 1000.0)
# ...
# Set new bounds for reaction r2280: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2281: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2284: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2285: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2286: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2287: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2288: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2290: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2291: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2292: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2295: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2296: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2298: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2302: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2303: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2304: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2305: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2306: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction r2308: (-46.90258840184372, 46.90258840184372) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2311: (-46.90258840184372, 46.90258840184372) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2312: (-46.90258840184372, 46.90258840184372) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2314: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2316: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2318: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2319: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2320: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2322: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2323: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2326: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2327: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2328: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2329: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2330: (-244.46764800729153, 244.46764800729153) from original (-1000.0, 1000.0)
# Set new bounds for reaction r2338: (-84.29551688395975, 84.29551688395975) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE0565C: (0.0, 907.0847053149149) from original (0.0, 1000.0)
# Set new bounds for reaction RE0577C: (-2.0818184089461445e-07, 594.8052305037105) from original (-3.500000171792635e-07, 1000.0)
# Set new bounds for reaction RE0578C: (-594.8052305037105, 594.8052305037105) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE0579C_1: (-2.0818184089461445e-07, 594.8052305037105) from original (-3.500000171792635e-07, 1000.0)
# Set new bounds for reaction RE0688E: (0.0, 4.178755449320183) from original (0.0, 200.0)
# Set new bounds for reaction RE0827E: (0.0, 2.0893777246600913) from original (0.0, 100.0)
# Set new bounds for reaction RE0828E: (0.0, 4.178755449320183) from original (0.0, 200.0)
# Set new bounds for reaction RE0830N: (-917.7862467648523, 917.7862467648523) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE0915E: (-1.1165064348502987e-07, 1.1165068927505976e-07) from original (-1.500000858963176e-07, 1.5000014741417544e-07)
# Set new bounds for reaction RE0926E: (-1.1165064348502987e-07, 1.8608436318450027e-07) from original (-1.500000858963176e-07, 2.500000858963176e-07)
# Set new bounds for reaction RE0935E: (-1.1165064348502987e-07, 1.8608436318450027e-07) from original (-1.500000858963176e-07, 2.500000858963176e-07)
# Set new bounds for reaction RE0936E: (-3.3768820739404096e-09, 5.628135500737787e-09) from original (-1.5000008589632736e-07, 2.500000858963176e-07)
# Set new bounds for reaction RE0937E: (-3.3768820739404096e-09, 5.628135500737787e-09) from original (-1.5000008589632736e-07, 2.500000858963176e-07)
# Set new bounds for reaction RE0938E: (-3.3768820739401896e-09, 5.628135500737787e-09) from original (-1.500000858963176e-07, 2.500000858963176e-07)
# Set new bounds for reaction RE0944E: (-1.1165064348502987e-07, 1.8608436318450027e-07) from original (-1.500000858963176e-07, 2.500000858963176e-07)
# Set new bounds for reaction RE0958E: (-1.1165064348502987e-07, 1.8608436318450027e-07) from original (-1.500000858963176e-07, 2.500000858963176e-07)
# Set new bounds for reaction RE1099C: (-41.592514408134576, 415.92514408134576) from original (-100.0, 1000.0)
# Set new bounds for reaction STS4r: (-415.92514408134576, 415.92514408134576) from original (-1000.0, 1000.0)
# Set new bounds for reaction RE1447M_1: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction RE1448R_1: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction RE1516M: (0.0, 166.04374987460605) from original (0.0, 915.2080008372812)
# Set new bounds for reaction RE3038C: (-3.63232565172745, 3.63232565172745) from original (-100.0, 100.0)
# Set new bounds for reaction RE3040C: (-5.448491767415999e-09, 3.63232565172745) from original (-1.5000009057075658e-07, 100.0)
# Set new bounds for reaction RE3074X: (0.0, 961.5104812106046) from original (0.0, 1000.0)
# Set new bounds for reaction RE3082X: (0.0, 3.972092709725861e-08) from original (0.0, 5.000012025484464e-08)
# Set new bounds for reaction RE3086X: (0.0, 5.0000153350993066e-08) from original (0.0, 5.0000153350993066e-08)
# Set new bounds for reaction RE3095C: (0.0, 893.7908241562477) from original (0.0, 1000.0)
# Set new bounds for reaction RE3132R: (0.0, 961.5104812106046) from original (0.0, 1000.0)
# Set new bounds for reaction RE3134C: (-52.79929107918448, 0.0) from original (-166.22800545002502, 0.0)
# Set new bounds for reaction CHLSTD78I: (0.0, 101.74640729304267) from original (0.0, 168.50055563954828)
# Set new bounds for reaction RE3151C: (0.0, 907.0847053149149) from original (0.0, 1000.0)
# Set new bounds for reaction RE3157X: (0.0, 3.9999997625272964e-07) from original (0.0, 3.9999997625272964e-07)
# Set new bounds for reaction RE3158X: (0.0, 3.472878360015821e-07) from original (0.0, 3.9999997625272964e-07)
# Set new bounds for reaction RE3159X: (0.0, 2.509638719978091e-07) from original (0.0, 3.9999997625272964e-07)
# Set new bounds for reaction RE3160R: (0.0, 961.5104812106046) from original (0.0, 1000.0)
# Set new bounds for reaction RE3161C: (0.0, 770.8823104011417) from original (0.0, 849.8460021255815)
# Set new bounds for reaction RE3177M: (0.0, 4.6237419465744066e-07) from original (0.0, 4.999999206716893e-07)
# Set new bounds for reaction FAOXC122x: (0.0, 464.30552799192463) from original (0.0, 499.9998360522257)
# Set new bounds for reaction FAOXC123C102m: (0.0, 445.01195392723787) from original (0.0, 634.6664007398249)
# Set new bounds for reaction FAOXC123x: (0.0, 373.3017669652118) from original (0.0, 402.0000000600001)
# Set new bounds for reaction FAOXC120100m: (0.0, 762.0313979143482) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC12C12OHm: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC12DCTc: (-860.4928802498437, 4.302463778969575e-07) from original (-1000.0, 4.999999276833478e-07)
# Set new bounds for reaction FAOXC141C121m: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC141C121x: (0.0, 210.18225529460162) from original (0.0, 335.00000002916664)
# Set new bounds for reaction FAOXC142C142OHm: (0.0, 2.500000277905201e-07) from original (0.0, 2.500000277905201e-07)
# Set new bounds for reaction FAOXC140120x: (0.0, 420.36451058920323) from original (0.0, 670.0000000583333)
# Set new bounds for reaction FAOXC14DCC12DCx: (0.0, 351.9060148850184) from original (0.0, 560.8870969221775)
# Set new bounds for reaction FAOXC15C13m: (0.0, 2.500000918331352e-07) from original (0.0, 2.500000918331352e-07)
# Set new bounds for reaction FAOXC15NADPx: (0.0, 2.489575028827769e-07) from original (0.0, 2.500000918331352e-07)
# Set new bounds for reaction FAOXC162C142m: (0.0, 915.2080008622812) from original (0.0, 915.2080008622812)
# Set new bounds for reaction FAOXC163C143m: (0.0, 634.666400709825) from original (0.0, 634.666400709825)
# Set new bounds for reaction FAOXC163GC142m: (0.0, 915.2080008872814) from original (0.0, 915.2080008872814)
# Set new bounds for reaction FAOXC164GC163m: (0.0, 915.2080008872812) from original (0.0, 915.2080008872812)
# Set new bounds for reaction FAOXC16Brx: (0.0, 133.81175052812205) from original (0.0, 1000.0)
# Set new bounds for reaction FAOXC160140m: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction ALAB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ARGB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ASNB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction BETBGTtc: (-0.0, 0.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction CYSB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction ESTROSABCCte: (0.0, 399.2072427021541) from original (0.0, 1000.0)
# Set new bounds for reaction FOLOAT1tc: (-0.0, 0.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction FOLOATPtc: (-329.8027258174012, 329.8027258174012) from original (-1000.0, 1000.0)
# Set new bounds for reaction GLNB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction GSNt2: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction LEUKABCtc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction PHEB0AT3tc: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction PSHSABCtc: (0.0, 739.147168763059) from original (0.0, 1000.0)
# Set new bounds for reaction THCHOLSTOICt: (-0.0, 0.0) from original (-1000.0, 100.0)
# Set new bounds for reaction XOL7AH3ATP: (0.0, 108.84843283767704) from original (0.0, 1000.0)
# Set new bounds for reaction XOL7AH3t: (-0.0, 0.0) from original (-1000.0, 100.0)
# Set new bounds for reaction XOL7AONEt: (-0.0, 0.0) from original (-1000.0, 100.0)
# Set new bounds for reaction XOLDIOLONEATP: (0.0, 10.884843283767703) from original (0.0, 100.0)
# Set new bounds for reaction 7KILTCHOLt: (-0.0, 0.0) from original (-1000.0, 100.0)
# Set new bounds for reaction ACACt2: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADK1: (-821.6738265136294, 821.6738265136294) from original (-1000.0, 1000.0)
# Set new bounds for reaction ADPT: (0.0, 906.2836787726152) from original (0.0, 1000.0)
# Set new bounds for reaction ADSS: (0.0, 702.6901218307156) from original (0.0, 1000.0)
# Set new bounds for reaction ALAR: (-3.7157998609000567e-07, 928.9498854304785) from original (-4.000000343590271e-07, 1000.0)
# Set new bounds for reaction PHPYRte: (-98.3509046265288, 2.6226932432838437e-07) from original (-100.0, 2.6666691610444104e-07)
# Set new bounds for reaction CE4970te: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction CE2026te: (0.0, 0.0) from original (0.0, 100.0)
# Set new bounds for reaction VANILPYRc: (0.0, 64.12789927295415) from original (0.0, 100.0)
# Set new bounds for reaction HMR_0614: (0.0, 923.9334587376594) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0625: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0634: (0.0, 498.6761372504223) from original (0.0, 842.7686659224684)
# Set new bounds for reaction HMR_0642: (0.0, 759.758153571235) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0678: (0.0, 789.5513013642484) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0750: (0.0, 594.3568576036029) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0758: (0.0, 594.3568576036029) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0761: (0.0, 1000.0) from original (0.0, 1000.0)
# Set new bounds for reaction SBPP3: (0.0, 742.0857053013568) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0793: (0.0, 51.7010224565454) from original (0.0, 999.9997984438068)
# Set new bounds for reaction HMR_0795: (0.0, 732.2359859505622) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_2736: (0.0, 117.30090868868172) from original (0.0, 451.1080218566413)
# Set new bounds for reaction HMR_2738: (-312.45715493815, 0.0) from original (-451.10802185087, 0.0)
# Set new bounds for reaction HMR_2739: (0.0, 136.52567074917394) from original (0.0, 525.0413313315921)
# Set new bounds for reaction HMR_2740: (0.0, 295.5616543139368) from original (0.0, 525.0413313315921)
# Set new bounds for reaction HMR_2741: (-363.6666001550421, 0.0) from original (-525.041331319957, 0.0)
# Set new bounds for reaction HMR_2772: (0.0, 222.48760283973806) from original (0.0, 395.231199632118)
# Set new bounds for reaction HMR_2774: (0.0, 117.30090868894527) from original (0.0, 451.1080218576549)
# Set new bounds for reaction HMR_2775: (0.0, 253.9423570262333) from original (0.0, 451.1080218576549)
# Set new bounds for reaction HMR_2817: (0.0, 330.36743813955087) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_2821: (-330.36743813955087, 330.36743813955087) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2852: (-667.4003942332777, 667.4003942332777) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2857: (0.0, 330.36743813955087) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_2862: (-667.4003942332777, 667.4003942332777) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2866: (-667.4003942332777, 667.4003942332777) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2890: (-667.4003942332777, 667.4003942332777) from original (-1000.0, 1000.0)
# Set new bounds for reaction HMR_2945: (0.0, 957.5783374104518) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_3113: (0.0, 926.2467545546025) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_9719: (0.0, 710.0901380573696) from original (0.0, 787.9399467951641)
# Set new bounds for reaction HMR_9801: (0.0, 5.717808483811018e-08) from original (0.0, 1.5000042695683076e-07)
# Set new bounds for reaction HMR_9805: (0.0, 0.0) from original (0.0, 999.997415546422)
# Set new bounds for reaction HMR_2957: (0.0, 976.6175878401516) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_6580: (0.0, 611.794821443509) from original (0.0, 1000.0)
# Set new bounds for reaction HMR_0980: (-88.61183768092977, 0.0) from original (-100.0, 0.0)
# Set new bounds for reaction HMR_4816: (0.0, 1.2671776255769411) from original (0.0, 200.0)
# Set new bounds for reaction HMR_4772: (0.0, 100.0) from original (0.0, 100.0)
# Set new bounds for reaction 12DHCHOLt: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction 12DHCHOLt2: (0.0, 170.7656994704147) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHCDCHOLabc: (0.0, 528.2558302169286) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHCDCHOLt: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction 3DHCDCHOLt2: (0.0, 170.7656994704147) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHDCAS: (0.0, 0.0) from original (0.0, 1000.0)
# Set new bounds for reaction 3DHDCAt: (-1000.0, 1000.0) from original (-1000.0, 1000.0)
# Set new bounds for reaction 3DHLCAt: (-1000.0, 1000.0) from original (-1000.0, 1000.0)

# %% [markdown]
# # Flux comparison

# %% [markdown]
# In FIG. 4 , the authors compared subsystems by selecting the most de-regulated reactions across cell types (LG and HG). I think They optimized to max biomass each of the 7 models  (they generated 7 FBA solutions) and then they computed the average of each flux across cell lines of the same family.
#
# However, they selected one of the many solutions that respect max biomass growth. I suggest to:
#
# 1. Impose biomass at its upper bound for each model (LB = UB*0.90 to avoid solver numerical issues)
# 2. Run flux sampling with OPTGP (cobrapy) with thinning = 100 and 1k samples per cell line
# 3. DO not 'summarize' flux probability distributions with a simple average, but use more advanced methods. The objective here is to identify the most different reactions across the two cancer families. You could run non parametric statistical tests such as mann-whitney to check if two probability distributions are significantly different or not. You have 3 cells vs 2 cells (all pair combinations), so you could perform this test only on reactions belonging to core subsystems such as glycolysis, TCA cycle pentophosphate etc.. in order to redure the number of compared distribution per cell couple.
# 4. Once you identified the top-n most different probability distributions (reaction fluxes) across cells of different type, you could plot them with boxplots as the authors did
# 5. It might be interesting to check if we have 'less differences' in distributions of cells belonging to the same family.

# %% [markdown]
# # Gene essentiality

# %% [markdown]
# The authors perfomed a gene essentiality analysis to find which genes are important to still enable growth of the cells. Check how  they identified them.
#
# Check gene knockouts on COBRApy docs to identify this important genes per cell line.
#
# Compare your results. The authors compared their results with in-vitro data for validation (this would be very nice to do).
